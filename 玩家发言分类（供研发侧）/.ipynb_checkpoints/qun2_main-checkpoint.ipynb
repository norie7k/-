# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl
from model_classifyV1_Copy1 import postprocess_excel_by_topic

# %%
## 研发字典
speaker_map = {
    "16186514":   "peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
    "2726067525": "茗山",
}
## 客服字典
MAPPING_FILE = "mapping地球2.xlsx"

##QQ的txt文件
pathtxt   = "1120《欢迎来到地球》测试2群.txt"

# 设定时间范围
start_time = "2025-11-19 00:00:00"
end_time   = "2025-11-20 00:00:00"


# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01)
# Out:
# 5297 lines
# ['{"发言日期": "2025-11-19", "发言时间": "10:06:53", "客服ID": "薏米(1090838043)", "客服消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:11", "玩家ID": "小王(2971418140)", "玩家消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:13", "玩家ID": "W.J(240050456)", "玩家消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:21", "客服ID": "青瓷游戏客服-菜头(2850663405)", "客服消息": "别闹"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:23", "玩家ID": "H(2190422538)", "玩家消息": "有系统吗"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:29", "客服ID": "青瓷游戏客服-菜头(2850663405)", "客服消息": "怎么都是自己进来的没人私聊我"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:37", "玩家ID": "W.J(240050456)", "玩家消息": "哪里下载"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:37", "玩家ID": "Sakamoto(2429896870)", "玩家消息": "何意味"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:40", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:49", "玩家ID": "十(1210777972)", "玩家消息": "怎么下啊"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:52", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@W.J @W.J等下午 13.50左右会发下载链接"}', '{"发言日期": "2025-11-19", "发言时间": "10:07:55", "玩家ID": "Sakamoto(2429896870)", "玩家消息": "你喜欢我，我喜欢你"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:08", "玩家ID": "1118(2358435713)", "玩家消息": "我瞅瞅怎么事"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:10", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@十 等下午发链接哦"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:15", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "然后是14点开服测试"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:20", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:24", "玩家ID": "1118(2358435713)", "玩家消息": "不是，牢怎么也在"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:26", "玩家ID": "W.J(240050456)", "玩家消息": "还在玩老号呢！"}', '{"发言日期": "2025-11-19", "发言时间": "10:08:43", "玩家ID": "假意(3210055137)", "玩家消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:11:58", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "我要玩新游戏"}', '{"发言日期": "2025-11-19", "发言时间": "10:11:59", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "奥利给"}', '{"发言日期": "2025-11-19", "发言时间": "10:12:13", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "蜗牛五年老粉"}', '{"发言日期": "2025-11-19", "发言时间": "10:12:19", "玩家ID": "十(1210777972)", "玩家消息": "这游戏是先下先得吗，看名额只有200-300"}', '{"发言日期": "2025-11-19", "发言时间": "10:12:22", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:12:44", "玩家ID": "W.J(240050456)", "玩家消息": "群里面满300个就不要了应该"}', '{"发言日期": "2025-11-19", "发言时间": "10:12:53", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@宇宙无敌机灵大魔王   @宇宙无敌机灵大魔王 [图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:13:33", "玩家ID": "十(1210777972)", "玩家消息": "看着画风不错不过感觉很难超越蜗牛了"}', '{"发言日期": "2025-11-19", "发言时间": "10:13:39", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@十 对  名额不多"}', '{"发言日期": "2025-11-19", "发言时间": "10:13:49", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@十 @十下午开服 可以试试~"}', '{"发言日期": "2025-11-19", "发言时间": "10:13:52", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:04", "玩家ID": "十(1210777972)", "玩家消息": "[图片]"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:13", "玩家ID": "斗诡(2374417760)", "玩家消息": "@青瓷游戏客服-哼唧 @青瓷游戏客服-哼唧 哼唧猪"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:16", "玩家ID": "W.J(240050456)", "玩家消息": "就喜欢玩青瓷的游戏，平民和氪金大佬都有好的体验"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:17", "研发ID": "茗山(2726067525)", "研发消息": "@宇宙无敌机灵大魔王 背包＋走格子，题材是末世，不过游戏内容就比较抽象了，兄弟，来玩SM"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:28", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "欢迎来到地球启动！"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:33", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "@茗山 有具体的攻略吗"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:34", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@十 P图师呢 给我P成地球启动@十"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:36", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "我还没玩过"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:51", "玩家ID": "无敌贝利亚(2821684104)", "玩家消息": "像那种攻略合集类的"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:52", "玩家ID": "斗诡(2374417760)", "玩家消息": "有好玩的？"}', '{"发言日期": "2025-11-19", "发言时间": "10:14:52", "客服ID": "青瓷游戏客服-哼唧(3008694133)", "客服消息": "@斗诡 我不是猪"}', '{"发言日期" ...

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：对保留内容进行 5 类意图分类（输出带“意图分类”的 JSON 行）
- 结果按 sheet（体感反馈/疑惑不解和问题询问/玩家建议和灵感/情绪输出/问题反馈）写入 Excel
"""
from model_classifyV1_Copy1 import (
    load_system_prompt,
    build_user_prompt_filter, build_user_prompt_classify,build_user_prompt_classify2,
    call_ark_chat_completions,
    jsonl_to_dataframe_with_intent,
    create_intent_excel_styled, append_json_to_excel_by_cat_and_tag,load_whitelist,
    extract_clusters_from_output, update_and_save_whitelist, build_user_prompt_cluster_correct
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md")      # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("提示词2.md")      # 模型#2 system 提示词（做分类）
PROMPT_MD_PATH03 = Path ("提示词5.md")     # 模型#3 system 提示词（做话提簇）
PROMPT_MD_PATH04 = Path ("话提簇校正提示词.md")     # 模型#3 system 提示词（做话提簇修正）

EXCEL_FILE       = Path("11192群.xlsx")   # 输出 Excel
BATCH_SIZE       = 100
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做分类
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03) # 做话提簇
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04) # 做话提簇

create_intent_excel_styled(EXCEL_FILE)


# 植入白名单 #
# --- 白名单初始化 ---
WHITE_LIST_PATH = Path("话题簇白名单.jsonl")
if not WHITE_LIST_PATH.exists():
    WHITE_LIST_PATH.write_text("", encoding="utf-8")  # 自动创建空文件
whitelist = load_whitelist(WHITE_LIST_PATH)  # 首批为空或加载已有



total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        # --- 模型 #2：分类 ---
        user_prompt2 = build_user_prompt_classify(output_filter)
        output_classify = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_classify:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        # --- 模型 #3：二级标签 ---
        user_prompt3 = build_user_prompt_classify2(output_classify)
        output_classify2 = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt03,
            user_prompt=user_prompt3,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        # --- 模型 #4：话提簇校正 ---
        user_prompt4 = build_user_prompt_cluster_correct(output_classify2, whitelist)
        output_classify3 = call_ark_chat_completions(
        api_url=API_URL,
        api_key=API_KEY,
        model=V3_1_MODEL_ID,
        system_prompt=system_prompt04,  # 模型#4 提示词
        user_prompt=user_prompt4,
        temperature=TEMPERATURE,
        max_tokens=MAX_TOKENS,
        timeout=TIMEOUT_SEC,
        retries=RETRIES,
        )
        try:
            new_clusters = extract_clusters_from_output(output_classify3)
            if new_clusters:
                whitelist = update_and_save_whitelist(WHITE_LIST_PATH, whitelist, new_clusters)
            else:
                tqdm.write(f"[批次 {b+1}] ⚪ 本批次无新增话题簇。")
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠️ 白名单更新出错：{e}")

        # 转 DataFrame
        df_batch = jsonl_to_dataframe_with_intent(output_classify3)
        if df_batch is None or df_batch.empty:
            tqdm.write(f"[批次 {b+1}] ⚠️ 无可写入数据（空 DataFrame）。")
            continue

        # ✅ 关键：转为 list[dict] 再写入
        records = df_batch.to_dict(orient="records")
        append_json_to_excel_by_cat_and_tag(records, EXCEL_FILE)

        batch_written = len(records)
        written_total += batch_written
        tqdm.write(f"[批次 {b+1}] ✅ 写入 {batch_written} 条。")
        
  
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        
        continue

    time.sleep(SLEEP_BETWEEN)
postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=60, nat_policy="skip")

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# ✅ 创建并套样式：11192群.xlsx
# 准备处理 5297 条，共 53 批（每批 100 条）。
# 🔥 批处理进度:   0%|                                                                                                                                    | 0/53 [04:40<?, ?批/s]
# ⚪ 无新增话题簇
# [批次 1] ✅ 写入 28 条。
# 🔥 批处理进度:   4%|████▌                                                                                                                    | 2/53 [05:11<1:53:35, 133.63s/批]
# [批次 2] ⚪ 本批次无新增话题簇。
# [批次 2] ⚠️ 无可写入数据（空 DataFrame）。
# 🔥 批处理进度:   4%|████▌                                                                                                                    | 2/53 [09:30<1:53:35, 133.63s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 3] ✅ 写入 24 条。
# 🔥 批处理进度:   6%|██████▊                                                                                                                  | 3/53 [17:57<2:39:18, 191.17s/批]
# ✅ 新增 3 条话题簇至白名单
# [批次 4] ✅ 写入 56 条。
# 🔥 批处理进度:   8%|█████████▏                                                                                                               | 4/53 [20:58<4:17:54, 315.80s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 5] ✅ 写入 18 条。
# 🔥 批处理进度:   9%|███████████▍                                                                                                             | 5/53 [27:18<3:33:58, 267.47s/批]
# ⚪ 无新增话题簇
# [批次 6] ✅ 写入 38 条。
# 🔥 批处理进度:  11%|█████████████▋                                                                                                           | 6/53 [32:07<3:59:20, 305.54s/批]
# ⚪ 无新增话题簇
# [批次 7] ✅ 写入 32 条。
# ⚪ 无新增话题簇
# 🔥 批处理进度:  13%|███████████████▉                                                                                                         | 7/53 [34:02<3:50:04, 300.10s/批]
# [批次 8] ✅ 写入 9 条。
# 🔥 批处理进度:  15%|██████████████████▎                                                                                                      | 8/53 [35:18<3:00:51, 241.15s/批]
# ✅ 新增 1 条话题簇至白名单
# [批次 9] ✅ 写入 6 条。
# 🔥 批处理进度:  17%|████████████████████▌                                                                                                    | 9/53 [40:38<2:19:01, 189.58s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 10] ✅ 写入 29 条。
# 🔥 批处理进度:  19%|██████████████████████▋                                                                                                 | 10/53 [41:33<2:44:40, 229.78s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 11] ✅ 写入 4 条。
# 🔥 批处理进度:  21%|████████████████████████▉                                                                                               | 11/53 [45:38<2:03:34, 176.53s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 12] ✅ 写入 26 条。
# 🔥 批处理进度:  23%|███████████████████████████▏                                                                                            | 12/53 [46:20<2:14:48, 197.29s/批]
# ⚪ 无新增话题簇
# [批次 13] ✅ 写入 2 条。
# 🔥 批处理进度:  25%|█████████████████████████████▍                                                                                          | 13/53 [47:53<1:40:10, 150.27s/批]
# ⚪ 无新增话题簇
# [批次 14] ✅ 写入 7 条。
# 🔥 批处理进度:  26%|███████████████████████████████▋                                                                                        | 14/53 [48:31<1:26:21, 132.86s/批]
# ⚪ 无新增话题簇
# [批次 15] ✅ 写入 1 条。
# 🔥 批处理进度:  28%|█████████████████████████████████▉                                                                                      | 15/53 [52:00<1:06:02, 104.27s/批]
# ⚪ 无新增话题簇
# [批次 16] ✅ 写入 18 条。
# 🔥 批处理进度:  30%|████████████████████████████████████▏                                                                                   | 16/53 [54:03<1:23:41, 135.71s/批]
# ✅ 新增 2 条话题簇至白名单
# [批次 17] ✅ 写入 8 条。
# 🔥 批处理进度:  32%|██████████████████████████████████████▍                                                                                 | 17/53 [54:41<1:19:14, 132.06s/批]
# ✅ 新增 1 条话题簇至白名单
# [批次 18] ✅ 写入 3 条。
# 🔥 批处理进度:  34%|████████████████████████████████████████▊                                                                               | 18/53 [55:32<1:00:30, 103.73s/批]
# ⚪ 无新增话题簇
# [批次 19] ✅ 写入 2 条。
# 🔥 批处理进度:  38%|██████████████████████████████████████████████▍                                                                            | 20/53 [55:58<38:01, 69.14s/批]
# ⚪ 无新增话题簇
# [批次 20] ⚠️ 无可写入数据（空 DataFrame）。
# ✅ 新增 11 条话题簇至白名单
# 🔥 批处理进度:  38%|█████████████████████████████████████████████▋                                                                           | 20/53 [1:00:28<38:01, 69.14s/批]
# [批次 21] ✅ 写入 31 条。
# 🔥 批处理进度:  40%|██████████████████████████████████████████████▊                                                                       | 21/53 [1:05:18<1:09:11, 129.73s/批]
# ✅ 新增 4 条话题簇至白名单
# [批次 22] ✅ 写入 34 条。
# 🔥 批处理进度:  42%|████████████████████████████████████████████████▉                                                                     | 22/53 [1:05:19<1:31:50, 177.77s/批]
# ⚪ 无新增话题簇
# 🔥 批处理进度:  42%|████████████████████████████████████████████████▉                                                                     | 22/53 [1:12:23<1:31:50, 177.77s/批]
# [批次 23] ✅ 写入 57 条。
# 🔥 批处理进度:  43%|███████████████████████████████████████████████████▏                                                                  | 23/53 [1:12:24<2:06:02, 252.09s/批]
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  43%|███████████████████████████████████████████████████▏                                                                  | 23/53 [1:21:51<2:06:02, 252.09s/批]
# [批次 24] ✅ 写入 68 条。
# 🔥 批处理进度:  45%|█████████████████████████████████████████████████████▍                                                                | 24/53 [1:21:52<2:47:37, 346.83s/批]
# ✅ 新增 5 条话题簇至白名单
# 🔥 批处理进度:  45%|█████████████████████████████████████████████████████▍                                                                | 24/53 [1:30:56<2:47:37, 346.83s/批]
# [批次 25] ✅ 写入 39 条。
# 🔥 批处理进度:  47%|███████████████████████████████████████████████████████▋                                                              | 25/53 [1:30:57<3:09:35, 406.26s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  47%|███████████████████████████████████████████████████████▋                                                              | 25/53 [1:37:47<3:09:35, 406.26s/批]
# [批次 26] ✅ 写入 41 条。
# 🔥 批处理进度:  49%|█████████████████████████████████████████████████████████▉                                                            | 26/53 [1:37:48<3:03:21, 407.47s/批]
# ⚪ 无新增话题簇
# 🔥 批处理进度:  49%|█████████████████████████████████████████████████████████▉                                                            | 26/53 [1:40:52<3:03:21, 407.47s/批]
# [批次 27] ✅ 写入 14 条。
# 🔥 批处理进度:  51%|████████████████████████████████████████████████████████████                                                          | 27/53 [1:40:53<2:27:44, 340.96s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  51%|████████████████████████████████████████████████████████████                                                          | 27/53 [1:43:34<2:27:44, 340.96s/批]
# [批次 28] ✅ 写入 15 条。
# 🔥 批处理进度:  53%|██████████████████████████████████████████████████████████████▎                                                       | 28/53 [1:43:35<1:59:36, 287.08s/批]
# ⚪ 无新增话题簇
# 🔥 批处理进度:  53%|██████████████████████████████████████████████████████████████▎                                                       | 28/53 [1:49:24<1:59:36, 287.08s/批]
# [批次 29] ✅ 写入 37 条。
# 🔥 批处理进度:  57%|██████████████████████████████████████████████████████████████████▊                                                   | 30/53 [1:49:42<1:24:02, 219.24s/批]
# [批次 30] ⚪ 本批次无新增话题簇。
# [批次 30] ❌ 出错：boolean value of NA is ambiguous
# ⚪ 无新增话题簇
# 🔥 批处理进度:  57%|██████████████████████████████████████████████████████████████████▊                                                   | 30/53 [1:50:05<1:24:02, 219.24s/批]
# [批次 31] ✅ 写入 1 条。
# 🔥 批处理进度:  58%|██████████████████████████████████████████████████████████████████████▏                                                 | 31/53 [1:50:06<58:54, 160.64s/批]
# ⚪ 无新增话题簇
# 🔥 批处理进度:  58%|██████████████████████████████████████████████████████████████████████▏                                                 | 31/53 [1:51:00<58:54, 160.64s/批]
# [批次 32] ✅ 写入 1 条。
# 🔥 批处理进度:  60%|████████████████████████████████████████████████████████████████████████▍                                               | 32/53 [1:51:01<45:12, 129.17s/批]
# ⚪ 无新增话题簇
# 🔥 批处理进度:  60%|████████████████████████████████████████████████████████████████████████▍                                               | 32/53 [1:51:52<45:12, 129.17s/批]
# [批次 33] ✅ 写入 4 条。
# 🔥 批处理进度:  64%|█████████████████████████████████████████████████████████████████████████████▌                                           | 34/53 [1:52:11<25:10, 79.52s/批]
# ⚪ 无新增话题簇
# [批次 34] ⚠️ 无可写入数据（空 DataFrame）。
# 🔥 批处理进度:  66%|███████████████████████████████████████████████████████████████████████████████▉                                         | 35/53 [1:52:33<18:40, 62.24s/批]
# ⚪ 无新增话题簇
# [批次 35] ⚠️ 无可写入数据（空 DataFrame）。
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  66%|███████████████████████████████████████████████████████████████████████████████▉                                         | 35/53 [1:53:20<18:40, 62.24s/批]
# [批次 36] ✅ 写入 4 条。
# 🔥 批处理进度:  68%|██████████████████████████████████████████████████████████████████████████████████▏                                      | 36/53 [1:53:21<16:27, 58.08s/批]
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  68%|██████████████████████████████████████████████████████████████████████████████████▏                                      | 36/53 [1:54:09<16:27, 58.08s/批]
# [批次 37] ✅ 写入 3 条。
# 🔥 批处理进度:  70%|████████████████████████████████████████████████████████████████████████████████████▍                                    | 37/53 [1:54:10<14:42, 55.19s/批]
# ✅ 新增 2 条话题簇至白名单
# 🔥 批处理进度:  70%|████████████████████████████████████████████████████████████████████████████████████▍                                    | 37/53 [1:55:38<14:42, 55.19s/批]
# [批次 38] ✅ 写入 9 条。
# 🔥 批处理进度:  72%|██████████████████████████████████████████████████████████████████████████████████████▊                                  | 38/53 [1:55:39<16:23, 65.56s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  72%|██████████████████████████████████████████████████████████████████████████████████████▊                                  | 38/53 [2:00:29<16:23, 65.56s/批]
# [批次 39] ✅ 写入 30 条。
# 🔥 批处理进度:  74%|████████████████████████████████████████████████████████████████████████████████████████▎                               | 39/53 [2:00:30<31:03, 133.11s/批]
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  74%|████████████████████████████████████████████████████████████████████████████████████████▎                               | 39/53 [2:05:51<31:03, 133.11s/批]
# [批次 40] ✅ 写入 35 条。
# 🔥 批处理进度:  75%|██████████████████████████████████████████████████████████████████████████████████████████▌                             | 40/53 [2:05:52<41:08, 189.85s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  75%|██████████████████████████████████████████████████████████████████████████████████████████▌                             | 40/53 [2:13:47<41:08, 189.85s/批]
# [批次 41] ✅ 写入 34 条。
# 🔥 批处理进度:  77%|████████████████████████████████████████████████████████████████████████████████████████████▊                           | 41/53 [2:13:48<55:08, 275.71s/批]
# ✅ 新增 14 条话题簇至白名单
# 🔥 批处理进度:  77%|████████████████████████████████████████████████████████████████████████████████████████████▊                           | 41/53 [2:22:33<55:08, 275.71s/批]
# [批次 42] ✅ 写入 54 条。
# 🔥 批处理进度:  79%|█████████████████████████████████████████████████████████████████████████████████████████████▌                        | 42/53 [2:22:34<1:04:18, 350.73s/批]
# ✅ 新增 6 条话题簇至白名单
# 🔥 批处理进度:  79%|█████████████████████████████████████████████████████████████████████████████████████████████▌                        | 42/53 [2:28:29<1:04:18, 350.73s/批]
# [批次 43] ✅ 写入 36 条。
# 🔥 批处理进度:  81%|█████████████████████████████████████████████████████████████████████████████████████████████████▎                      | 43/53 [2:28:30<58:43, 352.39s/批]
# ✅ 新增 10 条话题簇至白名单
# 🔥 批处理进度:  81%|█████████████████████████████████████████████████████████████████████████████████████████████████▎                      | 43/53 [2:35:08<58:43, 352.39s/批]
# [批次 44] ✅ 写入 46 条。
# 🔥 批处理进度:  83%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                    | 44/53 [2:35:09<54:55, 366.19s/批]
# ✅ 新增 2 条话题簇至白名单
# 🔥 批处理进度:  83%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                    | 44/53 [2:42:01<54:55, 366.19s/批]
# [批次 45] ✅ 写入 43 条。
# 🔥 批处理进度:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████▉                  | 45/53 [2:42:02<50:42, 380.25s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████▉                  | 45/53 [2:51:04<50:42, 380.25s/批]
# [批次 46] ✅ 写入 63 条。
# 🔥 批处理进度:  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 46/53 [2:51:05<50:02, 428.98s/批]
# ✅ 新增 2 条话题簇至白名单
# 🔥 批处理进度:  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 46/53 [3:00:26<50:02, 428.98s/批]
# [批次 47] ✅ 写入 59 条。
# 🔥 批处理进度:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▍             | 47/53 [3:00:27<46:54, 469.15s/批]
# ✅ 新增 4 条话题簇至白名单
# 🔥 批处理进度:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▍             | 47/53 [3:09:42<46:54, 469.15s/批]
# [批次 48] ✅ 写入 29 条。
# 🔥 批处理进度:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▋           | 48/53 [3:09:43<41:15, 495.08s/批]
# ✅ 新增 6 条话题簇至白名单
# 🔥 批处理进度:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▋           | 48/53 [3:19:23<41:15, 495.08s/批]
# [批次 49] ✅ 写入 69 条。
# 🔥 批处理进度:  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉         | 49/53 [3:19:24<34:43, 520.79s/批]
# ✅ 新增 2 条话题簇至白名单
# 🔥 批处理进度:  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉         | 49/53 [3:25:13<34:43, 520.79s/批]
# [批次 50] ✅ 写入 38 条。
# 🔥 批处理进度:  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 50/53 [3:25:14<23:28, 469.66s/批]
# ✅ 新增 5 条话题簇至白名单
# 🔥 批处理进度:  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 50/53 [3:34:52<23:28, 469.66s/批]
# [批次 51] ✅ 写入 73 条。
# 🔥 批处理进度:  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍    | 51/53 [3:34:53<16:44, 502.35s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍    | 51/53 [3:46:41<16:44, 502.35s/批]
# [批次 52] ✅ 写入 90 条。
# 🔥 批处理进度:  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 52/53 [3:46:42<09:24, 564.41s/批]
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 52/53 [3:56:42<09:24, 564.41s/批]
# [批次 53] ✅ 写入 68 条。
# 🔥 批处理进度: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53/53 [3:56:43<00:00, 267.99s/批]
# ✅ 已完成后处理：11192群.xlsx（gap=60min, NaT策略=skip）
#
# ✅ 全部批次处理完成！
# 输入总数：5297
# 写入总数：1436
