# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl
from model_classifyV1_Copy1 import postprocess_excel_by_topic

# %%
## 研发字典
speaker_map = {
    "16186514":   "peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
    "2726067525": "milissa",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt   = "1222《欢迎来到地球》测试1群.txt"

# 设定时间范围
start_time = "2025-12-19 00:00:00"
end_time   = "2025-12-22 00:00:00"


# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 2818 lines
# {"发言日期": "2025-12-19", "发言时间": "00:05:07", "玩家ID": "天地化生(1442744709)", "玩家消息": "[图片]"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：对保留内容进行 5 类意图分类（输出带“意图分类”的 JSON 行）
- 结果按 sheet（体感反馈/疑惑不解和问题询问/玩家建议和灵感/情绪输出/问题反馈）写入 Excel
"""
from model_classifyV1_Copy1 import (
    load_system_prompt,
    build_user_prompt_filter, build_user_prompt_classify,build_user_prompt_classify2,
    call_ark_chat_completions,
    jsonl_to_dataframe_with_intent,
    create_intent_excel_styled, append_json_to_excel_by_cat_and_tag,load_whitelist,
    extract_clusters_from_output, update_and_save_whitelist, build_user_prompt_cluster_correct
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点
                 
PROMPT_MD_PATH01 = Path("提示词1.md")      # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("提示词2.md")      # 模型#2 system 提示词（做分类）
PROMPT_MD_PATH03 = Path ("提示词5.md")     # 模型#3 system 提示词（做话提簇）
PROMPT_MD_PATH04 = Path ("话提簇白名单q1.md")     # 模型#3 system 提示词（做话提簇修正）

EXCEL_FILE       = Path("12181群.xlsx")   # 输出 Excel
BATCH_SIZE       = 200
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做分类
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03) # 做话提簇
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04) # 做话提簇

create_intent_excel_styled(EXCEL_FILE)


# 植入白名单 #
# --- 白名单初始化 ---
WHITE_LIST_PATH = Path("话题簇白名单q11.jsonl")
if not WHITE_LIST_PATH.exists():
    WHITE_LIST_PATH.write_text("", encoding="utf-8")  # 自动创建空文件
whitelist = load_whitelist(WHITE_LIST_PATH)  # 首批为空或加载已有



total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        # --- 模型 #2：分类 ---
        user_prompt2 = build_user_prompt_classify(output_filter)
        output_classify = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_classify:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        # --- 模型 #3：二级标签 ---
        user_prompt3 = build_user_prompt_classify2(output_classify)
        output_classify2 = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt03,
            user_prompt=user_prompt3,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        # --- 模型 #4：话提簇校正 ---
        user_prompt4 = build_user_prompt_cluster_correct(output_classify2, whitelist)
        output_classify3 = call_ark_chat_completions(
        api_url=API_URL,
        api_key=API_KEY,
        model=V3_1_MODEL_ID,
        system_prompt=system_prompt04,  # 模型#4 提示词
        user_prompt=user_prompt4,
        temperature=TEMPERATURE,
        max_tokens=MAX_TOKENS,
        timeout=TIMEOUT_SEC,
        retries=RETRIES,
        )
        try:
            new_clusters = extract_clusters_from_output(output_classify3)
            if new_clusters:
                whitelist = update_and_save_whitelist(WHITE_LIST_PATH, whitelist, new_clusters)
            else:
                tqdm.write(f"[批次 {b+1}] ⚪ 本批次无新增话题簇。")
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠️ 白名单更新出错：{e}")

        # 转 DataFrame
        df_batch = jsonl_to_dataframe_with_intent(output_classify3)
        if df_batch is None or df_batch.empty:
            tqdm.write(f"[批次 {b+1}] ⚠️ 无可写入数据（空 DataFrame）。")
            continue

        # ✅ 关键：转为 list[dict] 再写入
        records = df_batch.to_dict(orient="records")
        append_json_to_excel_by_cat_and_tag(records, EXCEL_FILE)

        batch_written = len(records)
        written_total += batch_written
        tqdm.write(f"[批次 {b+1}] ✅ 写入 {batch_written} 条。")
        
  
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        
        continue

    time.sleep(SLEEP_BETWEEN)
postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=60, nat_policy="skip")

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# ✅ 创建并套样式：12181群.xlsx
# 准备处理 1305 条，共 7 批（每批 200 条）。
# 🔥 批处理进度:   0%|                                                                                                                                      | 0/7 [06:11<?, ?批/s]
# ✅ 新增 10 条话题簇至白名单
# [批次 1] ✅ 写入 27 条。
# 🔥 批处理进度:  14%|█████████████████▊                                                                                                           | 1/7 [25:34<37:15, 372.56s/批]
# ✅ 新增 19 条话题簇至白名单
# [批次 2] ✅ 写入 126 条。
# 🔥 批处理进度:  29%|███████████████████████████████████▏                                                                                       | 2/7 [36:52<1:09:47, 837.44s/批]
# ✅ 新增 5 条话题簇至白名单
# [批次 3] ✅ 写入 28 条。
# 🔥 批处理进度:  43%|█████████████████████████████████████████████████████▌                                                                       | 3/7 [36:53<50:58, 764.62s/批]
# ✅ 新增 2 条话题簇至白名单
# 🔥 批处理进度:  43%|█████████████████████████████████████████████████████▌                                                                       | 3/7 [55:54<50:58, 764.62s/批]
# [批次 4] ✅ 写入 125 条。
# 🔥 批处理进度:  57%|██████████████████████████████████████████████████████████████████████▎                                                    | 4/7 [1:00:51<45:40, 913.63s/批]
# ✅ 新增 1 条话题簇至白名单
# [批次 5] ✅ 写入 1 条。
# 🔥 批处理进度:  71%|███████████████████████████████████████████████████████████████████████████████████████▊                                   | 5/7 [1:00:52<23:02, 691.12s/批]
# ✅ 新增 8 条话题簇至白名单
# 🔥 批处理进度:  71%|███████████████████████████████████████████████████████████████████████████████████████▊                                   | 5/7 [1:24:28<23:02, 691.12s/批]
# [批次 6] ✅ 写入 163 条。
# 🔥 批处理进度:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 6/7 [1:24:29<15:38, 938.01s/批]
# ✅ 新增 14 条话题簇至白名单
# 🔥 批处理进度:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 6/7 [1:30:55<15:38, 938.01s/批]
# [批次 7] ✅ 写入 47 条。
# 🔥 批处理进度: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [1:30:56<00:00, 779.51s/批]
# ✅ 已完成后处理：12181群.xlsx（gap=60min, NaT策略=skip）
#
# ✅ 全部批次处理完成！
# 输入总数：1305
# 写入总数：517

# %%
        
print(whitelist)
# Out:
# [{'话题簇名称': '游戏卡顿', '相关描述': '游戏运行卡顿与重登问题'}, {'话题簇名称': '游戏内容', '相关描述': '游戏内角色与内容差异'}, {'话题簇名称': '版本更新', '相关描述': '游戏版本更新相关内容'}, {'话题簇名称': '关卡进度', '相关描述': '游戏关卡进度与体验'}, {'话题簇名称': '资源获取', '相关描述': '游戏内资源获取效率'}, {'话题簇名称': '抽卡结果', '相关描述': '抽卡出货结果展示'}, {'话题簇名称': '系统维护', '相关描述': '游戏系统维护与重启'}, {'话题簇名称': '物品位置', '相关描述': '游戏内物品位置询问'}, {'话题簇名称': '系统机制', '相关描述': '游戏内特定功能等级说明'}, {'话题簇名称': '版本内容', '相关描述': '新版本内容期待'}, {'话题簇名称': '强化上限', '相关描述': '系统强化等级上限'}, {'话题簇名称': '测试命名', '相关描述': '测试版本名称含义'}, {'话题簇名称': '版本问题', '相关描述': '版本更新后的问题'}, {'话题簇名称': '测试类型', '相关描述': '测试版本类型说明'}, {'话题簇名称': '反馈处理', '相关描述': '玩家反馈处理情况'}, {'话题簇名称': '版本公告', '相关描述': '版本更新公告发布'}, {'话题簇名称': '运营互动', '相关描述': '与运营人员互动表达'}, {'话题簇名称': '角色外观', '相关描述': '游戏角色外观评价'}, {'话题簇名称': '系统优化', '相关描述': '游戏系统功能优化建议'}, {'话题簇名称': '测试资格', '相关描述': '测试资格获取方式'}, {'话题簇名称': '角色获取', '相关描述': '游戏角色获取方式'}, {'话题簇名称': '角色设定', '相关描述': '游戏角色背景设定'}, {'话题簇名称': '开发进度', '相关描述': '游戏开发进度评价'}, {'话题簇名称': '反馈方式', '相关描述': '玩家反馈方式建议'}, {'话题簇名称': '开发质量', '相关描述': '游戏开发质量评价'}, {'话题簇名称': '责任归属', '相关描述': '问题责任归属询问'}, {'话题簇名称': '驾驶员管理', '相关描述': '驾驶员替换与清空机制'}, {'话题簇名称': '殖装格子', '相关描述': '出战格子分配与限制'}, {'话题簇名称': '挂机功能', '相关描述': '自动挂机机制疑问'}, {'话题簇名称': '殖装机制', '相关描述': '殖装与驾驶员绑定关系'}, {'话题簇名称': '殖装选择', '相关描述': '殖装等级选择策略'}, {'话题簇名称': '殖装属性', '相关描述': '不同等级殖装属性对比'}, {'话题簇名称': '殖装功能', '相关描述': '不同殖装的特殊功能'}, {'话题簇名称': '殖装设计', '相关描述': '高级殖装存在意义疑问'}, {'话题簇名称': '殖装解锁', '相关描述': '殖装解锁条件与要求'}, {'话题簇名称': '玩家经验', '相关描述': '玩家游戏经验水平'}, {'话题簇名称': '通关进度', '相关描述': '关卡通关完成度'}, {'话题簇名称': '玩家交流', '相关描述': '玩家间互助交流'}, {'话题簇名称': '殖装策略', '相关描述': '殖装使用策略规划'}, {'话题簇名称': '游戏策略', '相关描述': '游戏玩法策略选择'}, {'话题簇名称': '殖装平衡', '相关描述': '高级殖装实用性评价'}, {'话题簇名称': '殖装体验', '相关描述': '殖装系统使用感受'}, {'话题簇名称': '养成策略', '相关描述': '角色培养与发展路线'}, {'话题簇名称': '版本规划', '相关描述': '未来更新内容预期'}, {'话题簇名称': '付费机制', '相关描述': '充值系统与商业化'}, {'话题簇名称': '收集玩法', '相关描述': '物品收集与获取方式'}, {'话题簇名称': '游戏类型', '相关描述': '游戏核心玩法定位'}, {'话题簇名称': '开服状态', '相关描述': '服务器开放与登录情况'}, {'话题簇名称': '装备机制', '相关描述': '武器类型与功能说明'}, {'话题簇名称': '背包容量', '相关描述': '物品占用空间问题'}, {'话题簇名称': '玩法体验', '相关描述': '游戏内容趣味性评价'}, {'话题簇名称': '装备获取', '相关描述': '稀有装备获得难度'}, {'话题簇名称': '战斗策略', '相关描述': '武器使用与伤害优化'}, {'话题簇名称': '装备强度', '相关描述': '武器性能对比评价'}, {'话题簇名称': '探索进度', '相关描述': '地图完成度统计'}, {'话题簇名称': '系统升级', '相关描述': '游戏内系统等级提升'}, {'话题簇名称': '抽卡机制', '相关描述': '抽奖系统体验反馈'}, {'话题簇名称': '角色能力', '相关描述': '角色属性与战斗表现'}, {'话题簇名称': '技能效果', '相关描述': '角色技能性能评价'}, {'话题簇名称': '系统功能', '相关描述': '游戏机制实现状态'}, {'话题簇名称': '游戏进度', '相关描述': '玩家游戏完成阶段'}, {'话题簇名称': '资源数量', '相关描述': '特定物品持有量'}, {'话题簇名称': '官方公告', '相关描述': '游戏公告发布情况'}, {'话题簇名称': '版本平衡', '相关描述': '游戏数值调整内容'}, {'话题簇名称': '角色新增', '相关描述': '新角色类型介绍'}, {'话题簇名称': '探索奖励', '相关描述': '地图完成度奖励获取'}, {'话题簇名称': '版本内容消耗', '相关描述': '更新节奏与玩法重复度'}, {'话题簇名称': '更新奖励建议', '相关描述': '版本福利发放标准'}, {'话题簇名称': '抽卡池内容', '相关描述': '卡池角色更新情况'}, {'话题簇名称': '抽卡掉落体验', '相关描述': '抽卡概率与出货情况'}, {'话题簇名称': '游戏数值平衡', '相关描述': '战斗与养成数值设计'}, {'话题簇名称': '游戏初期体验', '相关描述': '新手期开局体验'}, {'话题簇名称': '抽卡池优化', '相关描述': '卡池结构调整建议'}, {'话题簇名称': '装备培养系统', '相关描述': '殖装进阶与材料消耗'}, {'话题簇名称': '建筑升级系统', '相关描述': '奇迹柱子升级选择'}, {'话题簇名称': '游戏体验反馈', '相关描述': '整体游戏体验评价'}, {'话题簇名称': '社交系统机制', '相关描述': '群聊等级维护规则'}, {'话题簇名称': '收集系统价值', '相关描述': '图鉴收集奖励效果'}, {'话题簇名称': '活动强度', '相关描述': '更新后任务量与完成节奏'}, {'话题簇名称': '进度效率', '相关描述': '游戏周目与升级速度'}, {'话题簇名称': '玩家称赞', '相关描述': '对其他玩家的认可与赞扬'}, {'话题簇名称': '速通技巧', '相关描述': '快速通关方法与技巧分享'}, {'话题簇名称': '重置机制', '相关描述': '游戏重置条件与规则'}, {'话题簇名称': '技能选择', '相关描述': '技能加点与搭配建议'}, {'话题簇名称': '游戏节奏', '相关描述': '个人游玩速度与风格'}, {'话题簇名称': '玩法研究', '相关描述': '特定玩法组合与策略'}, {'话题簇名称': '新手指导', '相关描述': '新手入门与基础教学'}, {'话题簇名称': '玩法类型', '相关描述': '游戏玩法模式分类'}, {'话题簇名称': '删档机制', '相关描述': '游戏删档规则与风险'}, {'话题簇名称': '游戏对比', '相关描述': '与其他游戏的相似性比较'}, {'话题簇名称': '测试阶段', '相关描述': '游戏测试轮次与状态'}, {'话题簇名称': '账号问题', '相关描述': '账号登录与使用问题'}, {'话题簇名称': '付费系统', '相关描述': '游戏内充值与消费机制'}, {'话题簇名称': '殖装获取', '相关描述': '装备熔炼与投放机制'}, {'话题簇名称': '核心玩法', '相关描述': '游戏基础玩法类型'}, {'话题簇名称': '数据继承', '相关描述': '账号数据迁移与保存'}, {'话题簇名称': '下载渠道', '相关描述': '游戏获取与安装方式'}, {'话题簇名称': '战斗机制', '相关描述': '战斗系统与宠物协同'}, {'话题簇名称': '游戏画面', '相关描述': '游戏视觉表现展示'}, {'话题簇名称': '战斗流派', '相关描述': '特定战斗流派体验'}, {'话题簇名称': '测 ...

# %%
from pathlib import Path

print("CWD:", Path.cwd())
print("WHITE_LIST_PATH:", WHITE_LIST_PATH)
print("ABS:", WHITE_LIST_PATH.resolve())
print("EXISTS:", WHITE_LIST_PATH.exists())
if WHITE_LIST_PATH.exists():
    print("FILE SIZE:", WHITE_LIST_PATH.stat().st_size)
    print("FIRST 5 LINES:")
    with open(WHITE_LIST_PATH, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if i >= 5: break
            print(line.rstrip())
# Out:
# CWD: E:\项目\玩家社群分析智能体\玩家发言分类（供研发侧）
# WHITE_LIST_PATH: 话题簇白名单.jsonl
# ABS: E:\项目\玩家社群分析智能体\玩家发言分类（供研发侧）\话题簇白名单.jsonl
# EXISTS: True
# FILE SIZE: 290642
# FIRST 5 LINES:
# {"话题簇名称": "游戏卡顿", "相关描述": "游戏运行卡顿与重登问题"}
# {"话题簇名称": "游戏内容", "相关描述": "游戏内角色与内容差异"}
# {"话题簇名称": "版本更新", "相关描述": "游戏版本更新相关内容"}
# {"话题簇名称": "关卡进度", "相关描述": "游戏关卡进度与体验"}
# {"话题簇名称": "资源获取", "相关描述": "游戏内资源获取效率"}
