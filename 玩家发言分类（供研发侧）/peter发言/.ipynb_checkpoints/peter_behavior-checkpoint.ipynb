# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path 
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import _read_text_auto,build_jsonl_for_range, _normalize_date

# %%
##QQ的txt文件
pathtxt   = "Peter发言_测试1群(纯净版）.txt"




# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 1108 lines
# {"发言日期": "2025-07-02", "发言时间": "18:18:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@淬 @淬 还真有"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：对保留内容进行 5 类意图分类（输出带“意图分类”的 JSON 行）
- 结果按 sheet（体感反馈/疑惑不解和问题询问/玩家建议和灵感/情绪输出/问题反馈）写入 Excel
"""
from model_classifyV1_Copy1 import (
    load_system_prompt,build_user_prompt_single_speaker_behavior,extract_valid_json_lines,call_ark_chat_completions
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点
                 
PROMPT_MD_PATH01 = Path("提示词1.md")      # 模型#1 system 提示词（筛相关）

BATCH_SIZE       = 300
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time
system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)


total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：分析（或筛相关）---
        user_prompt1 = build_peter_behavior(batch_lines)
        output_behavior = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )

        # ✅ 修正：检查 output_behavior
        if not output_behavior or not str(output_behavior).strip():
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue

        # ✅ 这里你至少要做：解析 + 写入 + 计数
        # 举例：如果你最终要写入文件/Excel，写入成功后累加
        # write_results(output_behavior)
        written_total += 1  # 先用“批次级计数”兜底，后续可改成“行级计数”

    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    time.sleep(SLEEP_BETWEEN)

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# 准备处理 1108 条，共 4 批（每批 300 条）。
# 🔥 批处理进度: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [25:20<00:00, 380.24s/批]
# ✅ 全部批次处理完成！
# 输入总数：1108
# 写入总数：4

# %%
print(output_behavior)
# Out:
# ```json
# {"发言日期": "2025-09-14", "发言时间": "16:40:05", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@香草大炮 @香草大炮 局外并不直接提升战斗力"}
# {"发言日期": "2025-09-14", "发言时间": "16:40:28", "玩家ID": "Peter本尊(16186514)", "玩家消息": "会影响一些重开的东西"}
# {"发言日期": "2025-09-14", "发言时间": "16:40:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "比如魔方石柱初始等级、自选第一宫"}
# {"发言日期": "2025-09-14", "发言时间": "16:40:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "等等"}
# {"发言日期": "2025-09-14", "发言时间": "16:41:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 是呀"}
# {"发言日期": "2025-09-14", "发言时间": "16:41:25", "玩家ID": "Peter本尊(16186514)", "玩家消息": "攻防目前定义为后期属性"}
# {"发言日期": "2025-09-14", "发言时间": "16:41:34", "玩家ID": "Peter本尊(16186514)", "玩家消息": "pvp光靠投掷推不动"}
# {"发言日期": "2025-09-14", "发言时间": "16:42:38", "玩家ID": "Peter本尊(16186514)", "玩家消息": "在自己的地图，可以拿到序列3的源质石板"}
# {"发言日期": "2025-09-14", "发言时间": "16:42:52", "玩家ID": "Peter本尊(16186514)", "玩家消息": "然后去公共图，会有序列2"}
# {"发言日期": "2025-09-14", "发言时间": "16:43:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "然后序列1就是有限的"}
# {"发言日期": "2025-09-14", "发言时间": "16:43:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "3个序列1，成神"}
# {"发言日期": "2025-09-14", "发言时间": "16:43:22", "玩家ID": "Peter本尊(16186514)", "玩家消息": "比如3个朊病毒序列1"}
# {"发言日期": "2025-09-14", "发言时间": "16:57:42", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@Nefertari @Nefertari 好麻烦啊，那个等国庆之后再弄"}
# {"发言日期": "2025-09-14", "发言时间": "16:58:12", "玩家ID": "Peter本尊(16186514)", "玩家消息": "铲子的问题"}
# {"发言日期": "2025-09-14", "发言时间": "16:58:20", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我已经从根源上拔出了"}
# {"发言日期": "2025-09-14", "发言时间": "16:58:35", "玩家ID": "Peter本尊(16186514)", "玩家消息": "有，但不多"}
# {"发言日期": "2025-09-14", "发言时间": "16:59:04", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@枫火 @枫火 好的"}
# {"发言日期": "2025-09-14", "发言时间": "16:59:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "没有，本来游戏就有数据监控，发现产出和消耗不对劲儿的、都会优化"}
# {"发言日期": "2025-09-14", "发言时间": "17:00:12", "玩家ID": "Peter本尊(16186514)", "玩家消息": "跟举报与否没关系"}
# {"发言日期": "2025-09-14", "发言时间": "17:04:10", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@枫火 @枫火 不会的，地球是治愈风小游戏，主打一个交朋友"}
# {"发言日期": "2025-09-14", "发言时间": "17:04:30", "玩家ID": "Peter本尊(16186514)", "玩家消息": "希望把游戏社区建立成有爱、互助、和谐的避风港"}
# {"发言日期": "2025-09-14", "发言时间": "17:04:40", "玩家ID": "Peter本尊(16186514)", "玩家消息": "在这个物欲横流的社会中"}
# {"发言日期": "2025-09-14", "发言时间": "17:04:51", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还能有这么一处小小的港湾"}
# {"发言日期": "2025-09-14", "发言时间": "17:05:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@迷迷糊糊. @迷迷糊糊. 蜗牛不是动作游戏么"}
# {"发言日期": "2025-09-14", "发言时间": "17:05:36", "玩家ID": "Peter本尊(16186514)", "玩家消息": "蜗牛不是比微操么"}
# {"发言日期": "2025-09-14", "发言时间": "17:07:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "蜗牛那种昧良心的游戏，不在这个群的讨论范围"}
# {"发言日期": "2025-09-14", "发言时间": "17:07:26", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我21年就没管蜗牛了，知道毛线啊"}
# {"发言日期": "2025-09-14", "发言时间": "17:09:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "如果要整氪，我会明确说，蜗牛最初的公告就是我写的"}
# {"发言日期": "2025-09-14", "发言时间": "17:09:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "地球这边，目前真没这个打算"}
# {"发言日期": "2025-09-14", "发言时间": "17:10:23", "玩家ID": "Peter本尊(16186514)", "玩家消息": "比阳寿也是不错的"}
# {"发言日期": "2025-09-14", "发言时间": "17:11:39", "玩家ID": "Peter本尊(16186514)", "玩家消息": "驾驶员是走玩家交易，这个是肯定的"}
# {"发言日期": "2025-09-14", "发言时间": "17:11:59", "玩家ID": "Peter本尊(16186514)", "玩家消息": "殖装抽卡氪金，这也是订好的"}
# {"发言日期": "2025-09-14", "发言时间": "17:12:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "皮肤懒得做，太累了"}
# {"发言日期": "2025-09-14", "发言时间": "17:13:49", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这游戏我最想做的，其实就是随机精神病大世界"}
# {"发言日期": "2025-09-14", "发言时间": "17:14:36", "玩家ID": "Peter本尊(16186514)", "玩家消息": "一上来甚至可能都在steam先上"}
# {"发言日期": "2025-09-14", "发言时间": "17:14:53", "玩家ID": "Peter本尊(16186514)", "玩家消息": "卖鸡毛皮肤啊，你看地球这调性"}
# {"发言日期": "2025-09-14", "发言时间": "17:15:39", "玩家ID": "Peter本尊(16186514)", "玩家消息": "deck可以"}
# {"发言日期": "2025-09-14", "发言时间": "17:15:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "手机可能晚些上"}
# {"发言日期": "2025-09-14", "发言时间": "17:15:55", "玩家ID": "Peter本尊(16186514)", "玩家消息": "具体都还没想好"}
# {"发言日期": "2025-09-14", "发言时间": "17:15:59", "玩家ID": "Peter本尊(16186514)", "玩家消息": "以后的事"}
# {"发言日期": "2025-09-14", "发言时间": "17:16:06", "玩家ID": "Peter本尊(16186514)", "玩家消息": "今年先堆内容"}
# {"发言日期": "2025-09-14", "发言时间": "17:16:18", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在还在搭建环境"}
# {"发言日期": "2025-09-14", "发言时间": "17:16:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在游戏情绪太稳定了，我先把疯逼元素堆进去"}
# {"发言日期": "2025-09-14", "发言时间": "17:19:23", "玩家ID": "Peter本尊(16186514)", "玩家消息": "发疯后进入的源质世界，还在设计概念"}
# {"发言日期": "2025-09-14", "发言时间": "17:20:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "五种源质，每个对应一种源质世界；彩虹比较特殊"}
# {"发言日期": "2025-09-14", "发言时间": "17:25:54", "玩家ID": "Peter本尊(16186514)", "玩家消息": "突然想起个灵感"}
# {"发言日期": "2025-09-14", "发言时间": "17:25:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我先忙事情了"}
# {"发言日期": "2025-09-14", "发言时间": "17:26:00", "玩家ID": "Peter本尊(16186514)", "玩家消息": "回聊"}
# {"发言日期": "2025-09-19", "发言时间": "13:39:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@枫火 @枫火 发生甚么事了？！"}
# {"发言日期": "2025-09-19", "发言时间": "13:39:59", "玩家ID": "Peter本尊(16186514)", "玩家消息": "什么铭文"}
# {"发言日期": "2025-09-19", "发言时间": "13:41:25", "玩家ID": "Peter本尊(16186514)", "玩家消息": "哦哦哦…A级的词条都是寂寞"}
# {"发言日期": "2025-09-19", "发言时间": "13:41:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "畸变点下个或者下下个版本实装"}
# {"发言日期": "2025-09-19", "发言时间": "13:42:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@沧海之蓝 @沧海之蓝 当然可以"}
# {"发言日期": "2025-09-19", "发言时间": "13:42:44", "玩家ID": "Peter本尊(16186514)", "玩家消息": "图鉴现在随便弄的，局外成长还没认真怼"}
# {"发言日期": "2025-09-19", "发言时间": "13:43:27", "玩家ID": "Peter本尊(16186514)", "玩家消息": "每个区域小图鉴满80，可以设定该地图为重启开局图"}
# {"发言日期": "2025-09-19", "发言时间": "13:45:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 单个邮票满80，就可以设置了"}
# {"发言日期": "2025-09-19", "发言时间": "13:45:22", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这不才刚开始么"}
# {"发言日期": "2025-09-19", "发言时间": "13:45:30", "玩家ID": "Peter本尊(16186514)", "玩家消息": "一下子就40了"}
# {"发言日期": "2025-09-19", "发言时间": "13:45:40", "玩家ID": "Peter本尊(16186514)", "玩家消息": "别说80了，800都指日可待"}
# {"发言日期": "2025-09-19", "发言时间": "13:48:43", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这次抓宠貌似有bug"}
# {"发言日期": "2025-09-19", "发言时间": "13:48:51", "玩家ID": "Peter本尊(16186514)", "玩家消息": "居然把500的都抓了"}
# {"发言日期": "2025-09-19", "发言时间": "13:49:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在就放了30低级科技球，按道理上限是60+100"}
# {"发言日期": "2025-09-19", "发言时间": "13:49:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "2倍还是3倍等级+100吧"}
# {"发言日期": "2025-09-19", "发言时间": "13:49:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "具体我也不清楚"}
# {"发言日期": "2025-09-19", "发言时间": "13:50:00", "玩家ID": "Peter本尊(16186514)", "玩家消息": "后期有很多乱七八糟的科技球"}
# {"发言日期": "2025-09-19", "发言时间": "13:50:14", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还有很多隐藏设定"}
# {"发言日期": "2025-09-19", "发言时间": "13:50:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "有专门献祭的科技球，还有抓活人当驾驶员的"}
# {"发言日期": "2025-09-19", "发言时间": "13:51:37", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还有抓来做精神病研究的"}
# {"发言日期": "2025-09-19", "发言时间": "13:51:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 下下个版本，这种可以组成套装"}
# {"发言日期": "2025-09-19", "发言时间": "13:56:13", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 以后幼崽可以进化"}
# {"发言日期": "2025-09-19", "发言时间": "13:57:54", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这些幼崽，喂它们吃人肉，也就是人类残肢"}
# {"发言日期": "2025-09-19", "发言时间": "13:57:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "就可以进化"}
# {"发言日期": "2025-09-19", "发言时间": "13:58:18", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不同的幼崽吃的东西不一样"}
# {"发言日期": "2025-09-19", "发言时间": "13:58:25", "玩家ID": "Peter本尊(16186514)", "玩家消息": "大多数都吃人类残肢"}
# {"发言日期": "2025-09-19", "发言时间": "13:58:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "有些像三叶虫，就吃大便"}
# {"发言日期": "2025-09-19", "发言时间": "13:59:12", "玩家ID": "Peter本尊(16186514)", "玩家消息": "要救"}
# {"发言日期": "2025-09-19", "发言时间": "13:59:14", "玩家ID": "Peter本尊(16186514)", "玩家消息": "慢慢来"}
# {"发言日期": "2025-09-19", "发言时间": "13:59:46", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 之后这种认知障碍，可以组成逆天套装"}
# {"发言日期": "2025-09-19", "发言时间": "14:01:39", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@楠枫 @楠枫 之后每次重启，会随机生成一个存档"}
# {"发言日期": "2025-09-19", "发言时间": "14:01:54", "玩家ID": "Peter本尊(16186514)", "玩家消息": "里面会随机包含一些精神病、携带物"}
# {"发言日期": "2025-09-19", "发言时间": "14:01:59", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不过是随机的"}
# {"发言日期": "2025-09-19", "发言时间": "14:02:10", "玩家ID": "Peter本尊(16186514)", "玩家消息": "好的存档要慢慢刷"}
# {"发言日期": "2025-09-19", "发言时间": "14:02:31", "玩家ID": "Peter本尊(16186514)", "玩家消息": "然后消耗品，每个存档用一次也就废"}
# {"发言日期": "2025-09-19", "发言时间": "14:02:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 都说了这是保洁阿姨随手定的"}
# {"发言日期": "2025-09-19", "发言时间": "14:03:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还没实装"}
# {"发言日期": "2025-09-19", "发言时间": "14:05:53", "玩家ID": "Peter本尊(16186514)", "玩家消息": "科技球之后分为：精神类球、研究类球、观赏类球、献祭类球、奴隶类球、RBQ类球等等"}
# {"发言日期": "2025-09-19", "发言时间": "14:06:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "抓了之后可以为所欲为"}
# {"发言日期": "2025-09-19", "发言时间": "14:06:26", "玩家ID": "Peter本尊(16186514)", "玩家消息": "比如@枫火 你这种宝可梦大师"}
# {"发言日期": "2025-09-19", "发言时间": "14:06:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "就可以捉一只阿法齿负鼠做RBQ"}
# {"发言日期": "2025-09-19", "发言时间": "14:06:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "开不开心"}
# {"发言日期": "2025-09-19", "发言时间": "14:08:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "阿法齿负鼠和人类有生殖隔离"}
# {"发言日期": "2025-09-19", "发言时间": "14:08:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "是我的知识阻碍了艺术的创作"}
# {"发言日期": "2025-09-19", "发言时间": "14:16:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "就是6个阵营啊"}
# {"发言日期": "2025-09-19", "发言时间": "14:17:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "除了B级驾驶员是根正苗红的救世军"}
# {"发言日期": "2025-09-19", "发言时间": "14:18:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "另外5类A级都是其它势力"}
# {"发言日期": "2025-09-19", "发言时间": "14:18:28", "玩家ID": "Peter本尊(16186514)", "玩家消息": "然后S级都是特殊造型，荒野英雄"}
# {"发言日期": "2025-09-19", "发言时间": "14:19:03", "玩家ID": "Peter本尊(16186514)", "玩家消息": "以后A级退役之后，可以在飞船里的精神病房进行政审"}
# {"发言日期": "2025-09-19", "发言时间": "14:19:37", "玩家ID": "Peter本尊(16186514)", "玩家消息": "政审可以审出来一堆私藏物资"}
# {"发言日期": "2025-09-19", "发言时间": "14:20:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "然后流放或处决"}
# {"发言日期": "2025-09-19", "发言时间": "14:20:18", "玩家ID": "Peter本尊(16186514)", "玩家消息": "反正驾驶员的下场都很惨"}
# {"发言日期": "2025-09-19", "发言时间": "14:20:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "B级都是悄悄的做成殖装原料"}
# {"发言日期": "2025-09-19", "发言时间": "14:21:17", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@皮特抱干大炮 @皮特抱干大炮 救世军本身就是革命军啊"}
# {"发言日期": "2025-09-19", "发言时间": "14:21:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "属于名门正派"}
# {"发言日期": "2025-09-19", "发言时间": "14:21:34", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在邪恶的门派都还没出山呢"}
# {"发言日期": "2025-09-19", "发言时间": "14:22:27", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我都说了，我做这游戏主打一个道心通达"}
# {"发言日期": "2025-09-19", "发言时间": "14:22:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "你们居然还一天到晚质疑我氪不氪金"}
# {"发言日期": "2025-09-19", "发言时间": "14:23:09", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我特么在背离版号的道路上，都渐行渐远了"}
# {"发言日期": "2025-09-19", "发言时间": "14:23:12", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还特么氪金"}
# {"发言日期": "2025-09-19", "发言时间": "14:23:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "如果有一天"}
# {"发言日期": "2025-09-19", "发言时间": "14:23:52", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这游戏突然变正常了，或者突然氪金了"}
# {"发言日期": "2025-09-19", "发言时间": "14:24:07", "玩家ID": "Peter本尊(16186514)", "玩家消息": "就说明我要么出局了"}
# {"发言日期": "2025-09-19", "发言时间": "14:24:26", "玩家ID": "Peter本尊(16186514)", "玩家消息": "要么救不回来了"}
# {"发言日期": "2025-09-19", "发言时间": "14:25:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这游戏当然是我一言堂，我发起疯来连狗都害怕"}
# {"发言日期": "2025-09-19", "发言时间": "14:25:13", "玩家ID": "Peter本尊(16186514)", "玩家消息": "踩到狗屎都会让狗屎后悔"}
# {"发言日期": "2025-09-19", "发言时间": "14:26:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "马桶没做好"}
# {"发言日期": "2025-09-19", "发言时间": "14:26:07", "玩家ID": "Peter本尊(16186514)", "玩家消息": "没感觉"}
# {"发言日期": "2025-09-19", "发言时间": "14:26:23", "玩家ID": "Peter本尊(16186514)", "玩家消息": "本来我想的是另一些东西挂接马桶"}
# {"发言日期": "2025-09-19", "发言时间": "14:26:30", "玩家ID": "Peter本尊(16186514)", "玩家消息": "但是大家觉得太恶心了"}
# {"发言日期": "2025-09-19", "发言时间": "14:26:34", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我想了想，也是"}
# {"发言日期": "2025-09-19", "发言时间": "14:32:00", "玩家ID": "Peter本尊(16186514)", "玩家消息": "地球目前的画风，主要还是偏治愈系"}
# {"发言日期": "2025-09-19", "发言时间": "14:32:10", "玩家ID": "Peter本尊(16186514)", "玩家消息": "只是加了一些小乐趣"}
# {"发言日期": "2025-09-19", "发言时间": "14:32:33", "玩家ID": "Peter本尊(16186514)", "玩家消息": "游戏的基调还是没变"}
# {"发言日期": "2025-09-19", "发言时间": "14:32:37", "玩家ID": "Peter本尊(16186514)", "玩家消息": "治愈系小游戏"}
# {"发言日期": "2025-09-19", "发言时间": "14:33:10", "玩家ID": "Peter本尊(16186514)", "玩家消息": "主打清新治愈，当牛马们劳累一天，玩玩地球，就能忆苦思甜"}
# {"发言日期": "2025-09-19", "发言时间": "14:34:29", "玩家ID": "Peter本尊(16186514)", "玩家消息": "那要不我再限制久一点"}
# {"发言日期": "2025-09-19", "发言时间": "14:34:35", "玩家ID": "Peter本尊(16186514)", "玩家消息": "72小时重生"}
# {"发言日期": "2025-09-19", "发言时间": "14:35:19", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不会，正式上线我肯定要控制肝度"}
# {"发言日期": "2025-09-19", "发言时间": "14:35:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "太累了不大好"}
# {"发言日期": "2025-09-19", "发言时间": "14:35:36", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@， @， 是的"}
# {"发言日期": "2025-09-19", "发言时间": "14:35:43", "玩家ID": "Peter本尊(16186514)", "玩家消息": "你就说到点子上"}
# {"发言日期": "2025-09-19", "发言时间": "14:36:15", "玩家ID": "Peter本尊(16186514)", "玩家消息": "本来我的打算是，局内随便玩玩，根据强度，大家可以选择不同的pvp副本"}
# {"发言日期": "2025-09-19", "发言时间": "14:36:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "进去干一波，然后重生"}
# {"发言日期": "2025-09-19", "发言时间": "14:37:38", "玩家ID": "Peter本尊(16186514)", "玩家消息": "图鉴那个不是硬刷到，以后1000个地图"}
# {"发言日期": "2025-09-19", "发言时间": "14:37:49", "玩家ID": "Peter本尊(16186514)", "玩家消息": "想刷什么，根本随缘"}
# {"发言日期": "2025-09-19", "发言时间": "14:38:37", "玩家ID": "Peter本尊(16186514)", "玩家消息": "通行证其实是随机的"}
# {"发言日期": "2025-09-19", "发言时间": "14:38:51", "玩家ID": "Peter本尊(16186514)", "玩家消息": "26张塔罗牌，奖励也不一样"}
# {"发言日期": "2025-09-19", "发言时间": "14:39:04", "玩家ID": "Peter本尊(16186514)", "玩家消息": "那是因为星星简单，没去做特殊化的道具"}
# {"发言日期": "2025-09-19", "发言时间": "14:39:14", "玩家ID": "Peter本尊(16186514)", "玩家消息": "内容还没拼装"}
# {"发言日期": "2025-09-19", "发言时间": "14:40:22", "玩家ID": "Peter本尊(16186514)", "玩家消息": "那是因为其它牌奖励特殊"}
# {"发言日期": "2025-09-19", "发言时间": "14:40:26", "玩家ID": "Peter本尊(16186514)", "玩家消息": "功能还没做"}
# {"发言日期": "2025-09-19", "发言时间": "14:40:50", "玩家ID": "Peter本尊(16186514)", "玩家消息": "最强的是愚者和世界"}
# {"发言日期": "2025-09-19", "发言时间": "14:41:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "到时候我让乌贼过来给我占个台"}
# {"发言日期": "2025-09-19", "发言时间": "14:41:17", "玩家ID": "Peter本尊(16186514)", "玩家消息": "星星和月亮最垃圾、就给点精炼模组"}
# {"发言日期": "2025-09-19", "发言时间": "14:41:27", "玩家ID": "Peter本尊(16186514)", "玩家消息": "因为最简单，所以就先做了"}
# {"发言日期": "2025-09-19", "发言时间": "14:42:39", "玩家ID": "Peter本尊(16186514)", "玩家消息": "重启石板也有几十种随机的"}
# {"发言日期": "2025-09-19", "发言时间": "14:42:43", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不但能重启"}
# {"发言日期": "2025-09-19", "发言时间": "14:42:50", "玩家ID": "Peter本尊(16186514)", "玩家消息": "中途还有用"}
# {"发言日期": "2025-09-19", "发言时间": "14:43:07", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还能一不小心重启到魔方内部"}
# {"发言日期": "2025-09-19", "发言时间": "14:43:30", "玩家ID": "Peter本尊(16186514)", "玩家消息": "算了，不扯了，这些东西明年估计才能做完"}
# {"发言日期": "2025-10-01", "发言时间": "9:00:44", "玩家ID": "Peter本尊(16186514)", "玩家消息": "马勒戈壁，国庆前竟然更新版本了"}
# {"发言日期": "2025-10-01", "发言时间": "9:01:03", "玩家ID": "Peter本尊(16186514)", "玩家消息": "谁特么把中间版本放出去的…"}
# {"发言日期": "2025-10-01", "发言时间": "9:02:08", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我擦，这个版本改到一半，被发出去了"}
# {"发言日期": "2025-10-01", "发言时间": "9:02:58", "玩家ID": "Peter本尊(16186514)", "玩家消息": "都特么改到一半"}
# {"发言日期": "2025-10-01", "发言时间": "9:03:14", "玩家ID": "Peter本尊(16186514)", "玩家消息": "本来国庆节，延后更新的"}
# {"发言日期": "2025-10-01", "发言时间": "9:04:32", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在有些东西没改完，殖装背包和挂机应该是改到一半的中间版本"}
# {"发言日期": "2025-10-01", "发言时间": "9:04:53", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我特么…"}
# {"发言日期": "2025-10-01", "发言时间": "9:05:25", "玩家ID": "Peter本尊(16186514)", "玩家消息": "下次树上再吊几个"}
# {"发言日期": "2025-10-01", "发言时间": "9:05:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "最近我在国外考察，暂时回不来"}
# {"发言日期": "2025-10-01", "发言时间": "9:05:53", "玩家ID": "Peter本尊(16186514)", "玩家消息": "没注意盯"}
# {"发言日期": "2025-10-01", "发言时间": "9:07:03", "玩家ID": "Peter本尊(16186514)", "玩家消息": "放假了啊"}
# {"发言日期": "2025-10-01", "发言时间": "9:07:22", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@ 梦~游  @ 梦~游  重启吧"}
# {"发言日期": "2025-10-01", "发言时间": "9:08:38", "玩家ID": "Peter本尊(16186514)", "玩家消息": "群里居然不能发原文件"}
# {"发言日期": "2025-10-01", "发言时间": "9:08:45", "玩家ID": "Peter本尊(16186514)", "玩家消息": "只能发压缩的视频"}
# {"发言日期": "2025-10-01", "发言时间": "9:09:10", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这游戏才刚开始，问题比鸡还多"}
# {"发言日期": "2025-10-01", "发言时间": "9:09:36", "玩家ID": "Peter本尊(16186514)", "玩家消息": "国内的有开除，国外的策划换岗就行了"}
# {"发言日期": "2025-10-01", "发言时间": "9:09:51", "玩家ID": "Peter本尊(16186514)", "玩家消息": "缅北劳动力不好搞"}
# {"发言日期": "2025-10-01", "发言时间": "9:09:59", "玩家ID": "Peter本尊(16186514)", "玩家消息": "换去其它部门"}
# {"发言日期": "2025-10-01", "发言时间": "9:11:19", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@Peter本尊 里面源质世界没放，其它现在游戏里都有吧"}
# {"发言日期": "2025-10-01", "发言时间": "9:11:42", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这游戏完成度贼鸡儿低下"}
# {"发言日期": "2025-10-01", "发言时间": "9:11:52", "玩家ID": "Peter本尊(16186514)", "玩家消息": "视频都是临时边角料随便剪"}
# {"发言日期": "2025-10-01", "发言时间": "9:12:06", "玩家ID": "Peter本尊(16186514)", "玩家消息": "还要做很久"}
# {"发言日期": "2025-10-01", "发言时间": "9:12:50", "玩家ID": "Peter本尊(16186514)", "玩家消息": "肯定蜗牛啊"}
# {"发言日期": "2025-10-01", "发言时间": "9:13:03", "玩家ID": "Peter本尊(16186514)", "玩家消息": "蜗牛那种坑爹游戏，比这个好做多了"}
# {"发言日期": "2025-10-01", "发言时间": "9:13:23", "玩家ID": "Peter本尊(16186514)", "玩家消息": "蜗牛做起来比较简单"}
# {"发言日期": "2025-10-01", "发言时间": "9:13:52", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这个游戏目前只是搭建环境"}
# {"发言日期": "2025-10-01", "发言时间": "9:14:34", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不是用脚填的，脚都绑着铁镣"}
# {"发言日期": "2025-10-01", "发言时间": "9:14:42", "玩家ID": "Peter本尊(16186514)", "玩家消息": "应该不太方便"}
# {"发言日期": "2025-10-01", "发言时间": "9:17:06", "玩家ID": "Peter本尊(16186514)", "玩家消息": "咋"}
# {"发言日期": "2025-10-01", "发言时间": "9:17:46", "玩家ID": "Peter本尊(16186514)", "玩家消息": "洞窟里的boss"}
# {"发言日期": "2025-10-01", "发言时间": "9:17:53", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我想想是谁负责的"}
# {"发言日期": "2025-10-01", "发言时间": "9:17:57", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我把它拖出来"}
# {"发言日期": "2025-10-01", "发言时间": "9:18:08", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@Peter的小号"}
# {"发言日期": "2025-10-01", "发言时间": "9:18:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "这货"}
# {"发言日期": "2025-10-01", "发言时间": "9:18:16", "玩家ID": "Peter本尊(16186514)", "玩家消息": "你们鞭策它吧"}
# {"发言日期": "2025-10-01", "发言时间": "9:18:33", "玩家ID": "Peter本尊(16186514)", "玩家消息": "格子是我老人家做的…"}
# {"发言日期": "2025-10-01", "发言时间": "9:18:43", "玩家ID": "Peter本尊(16186514)", "玩家消息": "因为殖装没做完"}
# {"发言日期": "2025-10-01", "发言时间": "9:19:19", "玩家ID": "Peter本尊(16186514)", "玩家消息": "对，因为我后面要塞一堆稀奇古怪的容器"}
# {"发言日期": "2025-10-01", "发言时间": "9:19:30", "玩家ID": "Peter本尊(16186514)", "玩家消息": "要给之后留空间"}
# {"发言日期": "2025-10-01", "发言时间": "9:19:54", "玩家ID": "Peter本尊(16186514)", "玩家消息": "殖装在做另一方面的增强"}
# {"发言日期": "2025-10-01", "发言时间": "9:20:05", "玩家ID": "Peter本尊(16186514)", "玩家消息": "本来打算国庆后更新的"}
# {"发言日期": "2025-10-01", "发言时间": "9:20:37", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在精神分裂和认知障碍"}
# {"发言日期": "2025-10-01", "发言时间": "9:20:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "可以凑套装"}
# {"发言日期": "2025-10-01", "发言时间": "9:21:04", "玩家ID": "Peter本尊(16186514)", "玩家消息": "都说了殖装没做完"}
# {"发言日期": "2025-10-01", "发言时间": "9:21:09", "玩家ID": "Peter本尊(16186514)", "玩家消息": "没做完"}
# {"发言日期": "2025-10-01", "发言时间": "9:21:25", "玩家ID": "Peter本尊(16186514)", "玩家消息": "之后每个殖装有专属的精神病"}
# {"发言日期": "2025-10-01", "发言时间": "9:21:34", "玩家ID": "Peter本尊(16186514)", "玩家消息": "一大堆"}
# {"发言日期": "2025-10-01", "发言时间": "9:22:06", "玩家ID": "Peter本尊(16186514)", "玩家消息": "有暴露癖"}
# {"发言日期": "2025-10-01", "发言时间": "9:22:11", "玩家ID": "Peter本尊(16186514)", "玩家消息": "开不开心"}
# {"发言日期": "2025-10-01", "发言时间": "9:22:42", "玩家ID": "Peter本尊(16186514)", "玩家消息": "充能马上要干掉了"}
# {"发言日期": "2025-10-01", "发言时间": "9:22:50", "玩家ID": "Peter本尊(16186514)", "玩家消息": "以后没有充能了"}
# {"发言日期": "2025-10-01", "发言时间": "9:23:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@姜昊毅 @姜昊毅 道诡世界跟地球不匹配啊"}
# {"发言日期": "2025-10-01", "发言时间": "9:25:20", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@陈璐 @陈璐 对"}
# {"发言日期": "2025-10-01", "发言时间": "9:25:48", "玩家ID": "Peter本尊(16186514)", "玩家消息": "魔方什么升级奖励"}
# {"发言日期": "2025-10-01", "发言时间": "9:26:19", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@姜昊毅 @姜昊毅 后面狐尾会帮忙做一些设定"}
# {"发言日期": "2025-10-01", "发言时间": "9:26:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@枫火 @枫火 哦哦哦，那个再说"}
# {"发言日期": "2025-10-01", "发言时间": "9:31:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@沧海之蓝 @沧海之蓝 这个应该是可以领才对"}
# {"发言日期": "2025-10-01", "发言时间": "9:31:56", "玩家ID": "Peter本尊(16186514)", "玩家消息": "否则升级反而还不划算，肯定是不对的"}
# {"发言日期": "2025-10-01", "发言时间": "9:32:50", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@姜昊毅 @姜昊毅 心灵迷宫里那段话，就是狐尾出的主意"}
# {"发言日期": "2025-10-01", "发言时间": "9:33:31", "玩家ID": "Peter本尊(16186514)", "玩家消息": "现在很多东西，都只是先搭环境占个坑，还没往里面填内容"}
# {"发言日期": "2025-10-01", "发言时间": "9:35:09", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@剑雪汐焱 @剑雪汐焱 对"}
# {"发言日期": "2025-10-01", "发言时间": "9:35:16", "玩家ID": "Peter本尊(16186514)", "玩家消息": "本来想多做一些的"}
# {"发言日期": "2025-10-01", "发言时间": "9:35:31", "玩家ID": "Peter本尊(16186514)", "玩家消息": "兔子尾巴、狐狸尾巴、猪尾巴"}
# {"发言日期": "2025-10-01", "发言时间": "9:36:46", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@楠枫 不对吧，局部危机级的殖装，应该都是第一回合放技能@楠枫"}
# {"发言日期": "2025-10-01", "发言时间": "9:36:55", "玩家ID": "Peter本尊(16186514)", "玩家消息": "估计没改完就放出去了"}
# {"发言日期": "2025-10-01", "发言时间": "9:38:08", "玩家ID": "Peter本尊(16186514)", "玩家消息": "估计没做完的缘故"}
# {"发言日期": "2025-10-01", "发言时间": "9:38:16", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我先闪了"}
# {"发言日期": "2025-10-01", "发言时间": "9:38:28", "玩家ID": "Peter本尊(16186514)", "玩家消息": "等会其他人醒了，又要来喷我"}
# {"发言日期": "2025-10-01", "发言时间": "9:38:51", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我先自己把束缚带穿上"}
# {"发言日期": "2025-10-01", "发言时间": "9:39:18", "玩家ID": "Peter本尊(16186514)", "玩家消息": "@Sakamoto @Sakamoto 老夫来满足你"}
# {"发言日期": "2025-10-01", "发言时间": "9:40:27", "玩家ID": "Peter本尊(16186514)", "玩家消息": "大便认知障碍一套，超强大"}
# {"发言日期": "2025-10-01", "发言时间": "9:43:02", "玩家ID": "Peter本尊(16186514)", "玩家消息": "最顶上那个绿色的就是春姬"}
# {"发言日期": "2025-10-01", "发言时间": "9:43:06", "玩家ID": "Peter本尊(16186514)", "玩家消息": "飞船顶上"}
# {"发言日期": "2025-10-01", "发言时间": "9:43:19", "玩家ID": "Peter本尊(16186514)", "玩家消息": "新手剧情会出现"}
# {"发言日期": "2025-10-01", "发言时间": "9:43:26", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我先闪了"}
# {"发言日期": "2025-10-01", "发言时间": "9:48:40", "玩家ID": "Peter本尊(16186514)", "玩家消息": "pvp以后再说"}
# {"发言日期": "2025-10-01", "发言时间": "9:49:08", "玩家ID": "Peter本尊(16186514)", "玩家消息": "弱点攻击有上限的"}
# {"发言日期": "2025-10-01", "发言时间": "9:49:24", "玩家ID": "Peter本尊(16186514)", "玩家消息": "不行了"}
# {"发言日期": "2025-10-01", "发言时间": "9:49:27", "玩家ID": "Peter本尊(16186514)", "玩家消息": "我要闪了"}
# {"发言日期": "2025-10-01", "发言时间": "9:49:41", "玩家ID": "Peter本尊(16186514)", "玩家消息": "888888888"}
# {"发言日期": "2025-10-31", "发言时间": "12:40:44", "玩家ID": "Peter本尊(16186514)", "玩家消息": "[图片]"}
# {"发言日期": "2025-10-31", "发言时间": "12:41:01", "玩家ID": "Peter本尊(16186514)", "玩家消息": "道爷我成了~"}
# {"发言日期": "2025-10-31", "发言时间": "12:44:47", "玩家ID": "Peter本尊(16186514)", "玩家消息": "先治病"}
# ```
