# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl

# %%
## 研发字典
speaker_map = {
    "16186514":   "peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
    "2726067525": "milissa",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt   = "1209《欢迎来到地球》测试1群.txt"

# 设定时间范围
start_time = "2025-12-03 14:00:00"
end_time   = "2025-12-03 14:30:00"


# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 195 lines
# {"发言日期": "2025-12-03", "发言时间": "14:00:00", "玩家ID": "何方路人甲(978617207)", "玩家消息": "我第一次玩就是跟怪诞虫和残肢"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：提取高讨论的发言并分析
- 结果按word格式文档输出
"""
from testimport import (
    load_system_prompt,
    build_user_prompt_filter,build_user_prompt_clsuter,build_user_prompt_classify,build_user_prompt_cluster_correct,call_ark_chat_completions,
    extract_valid_json_lines,jsonl_to_dataframe_with_intent,
    load_whitelist,extract_clusters_from_output, update_and_save_whitelist,attach_cluster_to_messages,
    parse_clusters_from_output,attach_cluster_to_batch,build_class_map_from_text,
    create_intent_excel_styled,append_json_to_excel_by_cat_and_tag,postprocess_excel_by_topic
    
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md") # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("提示词2.md") # 模型#2 system 提示词（做分类）
PROMPT_MD_PATH03 = Path("2话题分类.md") # 模型#2 system 提示词（分话题）
PROMPT_MD_PATH04 = Path("test话提簇校正.md") # 模型#3 system 提示词（日聚合）
EXCEL_FILE       = Path("test群.xlsx") 
BATCH_SIZE       = 300
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time
import json
from pathlib import Path

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做话提簇
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03)
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04)


create_intent_excel_styled(EXCEL_FILE)



# 植入白名单 #
# --- 白名单初始化 ---
WHITE_LIST_PATH = Path("话题簇白名单.jsonl")
if not WHITE_LIST_PATH.exists():
    WHITE_LIST_PATH.write_text("", encoding="utf-8")  # 自动创建空文件
whitelist = load_whitelist(WHITE_LIST_PATH)  # 首批为空或加载已有


total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0


for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        
        # --- 模型 #2：分类 ---
        user_prompt2 = build_user_prompt_classify(output_filter)
        output_class = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        print(output_class)
        if not output_class:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        # --- 模型 #3：话题簇划分 ---
        user_prompt3 = build_user_prompt_clsuter(output_class)
        output_cluster = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt03,
            user_prompt=user_prompt3,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
      # --- 模型 #4：话提簇校正 ---
        user_prompt4 = build_user_prompt_cluster_correct(output_cluster, whitelist)
        output_classify = call_ark_chat_completions(
        api_url=API_URL,
        api_key=API_KEY,
        model=V3_MODEL_ID,
        system_prompt=system_prompt04,  # 模型#4 提示词
        user_prompt=user_prompt4,
        temperature=TEMPERATURE,
        max_tokens=MAX_TOKENS,
        timeout=TIMEOUT_SEC,
        retries=RETRIES,
        )
        
        # ② 白名单更新
        try:
            new_clusters = extract_clusters_from_output(output_classify)
            if new_clusters:
                whitelist = update_and_save_whitelist(
                    WHITE_LIST_PATH, whitelist, new_clusters
                )
            else:
                tqdm.write(f"[批次 {b+1}] ⚪ 本批次无新增话题簇。")
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠️ 白名单更新出错：{e}")

        cls_map = build_class_map_from_text(output_class)
        cluster_list = parse_clusters_from_output(output_classify)
        if not cluster_list:
            tqdm.write(f"[批次 {b+1}] ⚠️ parse_clusters_from_output 解析结果为空，本批次跳过。")
            continue
        final_records = attach_cluster_to_batch(
            cluster_list=cluster_list,
            batch_raw_lines=batch_lines,
            cls_map=cls_map,
        )


       append_json_to_excel_by_cat_and_tag(final_records, EXCEL_FILE)

        batch_written = len(final_records)
        written_total += batch_written
        tqdm.write(f"[批次 {b+1}] ✅ 写入 {batch_written} 条。")
        
  
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        
        continue

    time.sleep(SLEEP_BETWEEN)
postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=60, nat_policy="skip")

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# 准备处理 195 条，共 1 批（每批 300 条）。
# 🔥 批处理进度:   0%|                                                                                                                                                       | 0/1 [00:00<?, ?批/s]
# {"发言日期": "2025-12-03", "发言时间": "14:00:00", "玩家ID": "何方路人甲(978617207)", "玩家消息": "我第一次玩就是跟怪诞虫和残肢", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:09", "玩家ID": "何方路人甲(978617207)", "玩家消息": "那时候还不会摆道具", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:17", "玩家ID": "枫火(276465118)", "玩家消息": "又是玩球", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:30", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "又是西洋剑", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:39", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "[图片]", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:48", "玩家ID": "空(3316920376)", "玩家消息": "啊要重新下载", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14:00:53", "玩家ID": "尘(3411480843)", "玩家消息": "开PVP了", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:00:59", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "还要不要人活", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14:01:04", "玩家ID": "枫桥(854411209)", "玩家消息": "好了寄了", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14:01:10", "玩家ID": "枫桥(854411209)", "玩家消息": "开局赏金令", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:01:11", "玩家ID": "尘(3411480843)", "玩家消息": "告别单机", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:01:15", "玩家ID": "枫桥(854411209)", "玩家消息": "寄", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14:01:28", "玩家ID": "K(273077367)", "玩家消息": "黑帮台球", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:01:53", "玩家ID": "K(273077367)", "玩家消息": "[图片]", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:01:56", "玩家ID": "七叶°(858839356)", "玩家消息": "新图", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:02:02", "玩家ID": "K(273077367)", "玩家消息": "转钞票 不让重启？", "分类标签": 2}
# {"发言日期": "2025-12-03", "发言时间": "14:02:06", "玩家ID": "何方路人甲(978617207)", "玩家消息": "手枪开局", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:02:09", "玩家ID": "何方路人甲(978617207)", "玩家消息": "有福了", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14:02:42", "玩家ID": "千墓流沙(919072537)", "玩家消息": "[图片]", "分类标签": 2}
# {"发言日期": "2025-12-03", "发言时间": "14:02:44", "玩家ID": "千墓流沙(919072537)", "玩家消息": "我这是？", "分类标签": 2}
# {"发言日期": "2025-12-03", "发言时间": "14:02:47", "玩家ID": "枫火(276465118)", "玩家消息": "[图片]", "分类标签": 2}
# {"发言日期": "2025-12-03", "发言时间": "14:02:51", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "手枪无解", "分类标签": 1}
# {"发言日期": "2025-12-03", "发言时间": "14:02:51", "玩家ID": "枫火(276465118)", "玩家消息": "这啥", "分类标签": 2}
# {"发言日期": "2025-12-03", "发言时间": "14:02:54", "玩家ID": "枫火(276465118)", "玩家消息": "精神污染都来了", "分类标签": 4}
# {"发言日期": "2025-12-03", "发言时间": "14
", "玩家消息": "[图片]", "一级分类": 2, "话题簇": "格子需求问题"}
# {"发言日期": "2025-12-03", "发言时间": "14:20:55", "玩家ID": "闪.(2940944533)", "玩家消息": "这几个都需要一格", "一级分类": 2, "话题簇": "格子需求问题"}
# {"发言日期": "2025-12-03", "发言时间": "14:20:57", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "发现bug了，殖装被卡掉了@青瓷客服-大炮", "一级分类": 5, "话题簇": "格子需求问题"}
# {"发言日期": "2025-12-03", "发言时间": "14:21:06", "玩家ID": "闪.(2940944533)", "玩家消息": "这一种情况是不是只能重开了", "一级分类": 2, "话题簇": "格子需求问题"}
# {"发言日期": "2025-12-03", "发言时间": "14:21:09", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "我蝴蝶无了", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:21:23", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "@只哈哈大王 @只哈哈大王", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:21:34", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "明天不思议迷宫九周年你不玩迷宫在这里干什么", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:21:52", "玩家ID": null, "玩家消息": null, "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:07", "玩家ID": "艺术家(3117818599)", "玩家消息": "为什么我把东西放完 退出来就显示没放了", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:29", "玩家ID": "枫火(276465118)", "玩家消息": "我隔壁有个10001", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:29", "玩家ID": "黎姐万岁(396063411)", "玩家消息": "奇虾护盾没了", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:32", "玩家ID": "枫火(276465118)", "玩家消息": "是不是薏米", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:35", "玩家ID": null, "玩家消息": null, "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:44", "玩家ID": "枫火(276465118)", "玩家消息": "也是爆米花", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:48", "玩家ID": "闪.(2940944533)", "玩家消息": "@青瓷客服-大炮 @青瓷客服-大炮 怪已经打完了", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:52", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:22:57", "玩家ID": "黎姐万岁(396063411)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:20", "玩家ID": "只哈哈大王(417272543)", "玩家消息": "@Peter的魔丸 @Peter的魔丸 2016.12.8开服的", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:22", "玩家ID": "甲乙丙丁(449511)", "玩家消息": "180级的，打锤子", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:34", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "不管", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:37", "玩家ID": "艺术家(3117818599)", "玩家消息": "@青瓷客服-大炮 @青瓷客服-大炮 重进有显示了", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:40", "玩家ID": "艺术家(3117818599)", "玩家消息": "但是丢了一个", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:43", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "明天九周年庆典开启", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:45", "玩家ID": "艺术家(3117818599)", "玩家消息": "[图片]", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:48", "玩家ID": "只哈哈大王(417272543)", "玩家消息": "@艺术家 你不准玩", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:49", "玩家ID": "一青方觉夏深(755867025)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:51", "玩家ID": "哦哦(247577405)", "玩家消息": "好多直装技能都变了", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:51", "玩家ID": "艺术家(3117818599)", "玩家消息": "我本来放了两个绿瓶子", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:58", "玩家ID": "艺术家(3117818599)", "玩家消息": "就剩一个了 另一个背包里也没有", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:23:59", "玩家ID": "哦哦(247577405)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:00", "玩家ID": "哦哦(247577405)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:01", "玩家ID": "哦哦(247577405)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:10", "玩家ID": "枫火(276465118)", "玩家消息": "下面", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:15", "玩家ID": "只哈哈大王(417272543)", "玩家消息": "@青瓷客服-大炮 我问一下，这测删档吗", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:18", "玩家ID": "枫火(276465118)", "玩家消息": "你是马桶？", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:24", "玩家ID": "只哈哈大王(417272543)", "玩家消息": "是时候不删档了叫我", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:29", "玩家ID": null, "玩家消息": null, "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:30", "玩家ID": "艺术家(3117818599)", "玩家消息": "@只哈哈大王 @只哈哈大王 你不准嗦话", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:36", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "就是先用a的角色上，然后招募一个b角色，角色a零时待命然后点出发用b级角色，然后游戏就卡了然后重开游戏进去蝴蝶殖装就没了@青瓷客服-大炮", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:37", "玩家ID": "徒手(247674950)", "玩家消息": "@只哈哈大王 @只哈哈大王 不是一直不删档吗？", "一级分类": null, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:40", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "[图片]", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:48", "玩家ID": "宿江.(1571860278)", "玩家消息": "[图片]", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:51", "玩家ID": "宿江.(1571860278)", "玩家消息": "这什么鬼", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:54", "玩家ID": "艺术家(3117818599)", "玩家消息": "@Peter的魔丸 @Peter的魔丸 测服早开了", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:24:58", "玩家ID": "🐾L(241175920)", "玩家消息": "本来就是不删档啊。。只是帮你强制结算。。", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:25:04", "玩家ID": "等等(1375016418)", "玩家消息": "@艺术家 @艺术家 你不许搬屎", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:25:08", "玩家ID": "Peter的魔丸(3317171096)", "玩家消息": "这谁啊", "一级分类": 2, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:26:45", "玩家ID": "风筱Sam(1277959668)", "玩家消息": "我擦[图片]", "一级分类": 4, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:27:19", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "[图片]", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:27:29", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "这是原来玩的有殖装", "一级分类": 1, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:27:42", "玩家ID": "ۣۖิ戏ۣۖิ子(1046996232)", "玩家消息": "@青瓷客服-大炮", "一级分类": 5, "话题簇": "殖装丢失BUG"}
# {"发言日期": "2025-12-03", "发言时间": "14:28:36", "玩家ID": "枫火(276465118)", "玩家消息": "糖果应该很小", "一级分类": 1, "话题簇": "糖果大小推测"}
# 🔥 批处理进度: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [08:49<00:00, 529.53s/批]
# ✅ 全部批次处理完成！
# 输入总数：195
# 输出总数：177

# %%
print(final_records)
# Out:
# [{'发言日期': '2025-12-03', '发言时间': '14:00:00', '玩家ID': '何方路人甲(978617207)', '玩家消息': '我第一次玩就是跟怪诞虫和残肢', '一级分类': 1, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:07', '玩家ID': '千墓流沙(919072537)', '玩家消息': '启动！', '一级分类': None, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:09', '玩家ID': '何方路人甲(978617207)', '玩家消息': '那时候还不会摆道具', '一级分类': 1, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:15', '玩家ID': '何方路人甲(978617207)', '玩家消息': '一直疯', '一级分类': None, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:17', '玩家ID': '璃奈(511808399)', '玩家消息': 'go', '一级分类': None, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:17', '玩家ID': '枫火(276465118)', '玩家消息': '又是玩球', '一级分类': 1, '话题簇': '怪诞虫开局体验'}, {'发言日期': '2025-12-03', '发言时间': '14:00:30', '玩家ID': '甲乙丙丁(449511)', '玩家消息': '又是西洋剑', '一级分类': 1, '话题簇': '台球开局讨论'}, {'发言日期': '2025-12-03', '发言时间': '14:00:39', '玩家ID': '甲乙丙丁(449511)', '玩家消息': '[图片]', '一级分类': 1, '话题簇': '西洋剑开局讨论'}, {'发言日期': '2025-12-03', '发言时间': '14:00:48', '玩家ID': '空(3316920376)', '玩家消息': '啊要重新下载', '一级分类': 4, '话题簇': '西洋剑开局讨论'}, {'发言日期': '2025-12-03', '发言时间': '14:00:53', '玩家ID': '尘(3411480843)', '玩家消息': '开PVP了', '一级分类': 1, '话题簇': 'PVP模式开启'}, {'发言日期': '2025-12-03', '发言时间': '14:00:53', '玩家ID': '甲乙丙丁(449511)', '玩家消息': '擦', '一级分类': None, '话题簇': 'PVP模式开启'}, {'发言日期': '2025-12-03', '发言时间': '14:00:59', '玩家ID': '甲乙丙丁(449511)', '玩家消息': '还要不要人活', '一级分类': 4, '话题簇': 'PVP模式开启'}, {'发言日期': '2025-12-03', '发言时间': '14:01:04', '玩家ID': '枫桥(854411209)', '玩家消息': '好了寄了', '一级分类': 4, '话题簇': 'PVP模式开启'}, {'发言日期': '2025-12-03', '发言时间': '14