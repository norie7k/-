# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from collections import defaultdict
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl
from model_classifyV1_Copy1_Copy1 import add_index_to_jsonl_lines

# %%
## 研发字典
speaker_map = {
    "16186514":   "peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
    "2726067525": "milissa",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt   = "0107《欢迎来到地球》测试2群.txt"

# 设定时间范围
start_time = "2025-12-08 00:00:00"
end_time   = "2025-12-09 00:00:00"


# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)
print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 1270 lines
# {"发言日期": "2025-12-08", "发言时间": "00:06:54", "玩家ID": "你吹你的牛 我抱我的熊(3100704086)", "玩家消息": "[图片]"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：提取高讨论的发言并分析
- 结果按word格式文档输出
"""
from model_classifyV1_Copy1_Copy1 import (
    load_system_prompt,
    build_user_prompt_filter,build_user_prompt_clsuter,call_ark_chat_completions,
    extract_valid_json_lines,add_index_to_jsonl_lines,count_output_filter_stats,get_covered_indices_from_cluster_output,
    aggregate_cluster_outputs,build_user_prompt_cluster_agg,assign_global_cluster_ids,
    extract_top5_heat_clusters,attach_discussion_points_day,attach_discussion_points_all,extract_cluster_stats,append_daily_top5_to_version_jsonl,infer_date_for_batch,
    build_user_prompt_subcluster_opinion,
    print_mech_time_from_top5,get_dialogs_lines_by_fayan_time_debug,merge_top5_with_opinions_numbered,parse_opinion_output_to_list,
    ensure_time_axis_key,ensure_subcluster_list_key,match_dialogs_by_time, parse_jsonl_text,parse_model2_output_to_json_list,parse_jsonl_text_safe,
    normalize_model3_clusters,enrich_subclusters_with_datetime,refill_cluster_fayan_time
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md") # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("2话题分类.md") # 模型#2 system 提示词（分话题）
PROMPT_MD_PATH03 = Path("3日聚合.md") # 模型#3 system 提示词（日聚合）
PROMPT_MD_PATH04 = Path("2话题分类和总结.md") #模型#4 system 提示词（观点分析）
VERSION_TOP5_JSONL_day = "12311群.jsonl"
VERSION_TOP5_JSONL_all = "test_top5.jsonl"
BATCH_SIZE       = 300
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 1.检验每日话提簇分类输出

# %% [markdown]
# ## 加讨论观点分析的版本测试

# %%
from tqdm import tqdm
import time
import json
from pathlib import Path
from collections import defaultdict

# --- 前置：系统提示、初始化等 ---
system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做话提簇
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03)  # 日话题簇聚合
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04)  # 玩家观点分析（模型4）

batch_cluster_outputs = []   # 模型2所有批次簇，用于日聚合
all_opinions = []            # 模型4观点结果汇总

total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

# ====================================================
# 模型 #1 + 模型 #2：筛相关 + 话题簇划分
# ====================================================
for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue

        filter_count = sum(1 for line in output_filter.splitlines() if line.strip())
        tqdm.write(f"[批次 {b+1}] 模型#1 筛后保留 {filter_count} 条")
        written_total += filter_count

        # --- 模型 #2：话题簇划分 ---
        user_prompt2 = build_user_prompt_clsuter(output_filter)
        output_cluster = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )

        if not output_cluster:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
      
       # ---------- ✅ 新的 JSON 解析 + _cluster_id 部分 ----------
        try:
            # 1) 先用修复解析器，把模型#2输出变成 list[dict]
            cluster_json_list = parse_model2_output_to_json_list(
                output_cluster,
                batch_idx=b+1,
            )

            if not cluster_json_list:
                tqdm.write(f"[批次 {b+1}] ⚠ 本批次未解析出任何合法 JSON 对象，跳过。")
                continue
            
            
            # 2) 从该批次中推断日期（你自己的逻辑）
            date_str = infer_date_for_batch(cluster_json_list, batch_lines)
            batch_id = f"B{b+1}"

            # 3) 分配全局 _cluster_id：日期 + 批次号 + 序号 ...
            cluster_json_list = assign_global_cluster_ids(
                cluster_json_list,
                date_str,
                batch_id,
            )

            # 4) 再转成 jsonl 文本（供后续 aggregate_cluster_outputs 使用）
            output_cluster_with_ids = "\n".join(
                json.dumps(c, ensure_ascii=False) for c in cluster_json_list
            )
            batch_cluster_outputs.append(output_cluster_with_ids)
           
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠ 添加 _cluster_id 失败：{e}")
            continue
        # ---------- JSON 解析部分结束 ----------

    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    time.sleep(SLEEP_BETWEEN)
# ====================================================
# 模型 #3：日话题簇聚合 & Top5
# ====================================================

# --- 聚合当天所有批次的话题簇 jsonl ---
all_cluster = aggregate_cluster_outputs(batch_cluster_outputs)

# --- 模型 #3：日话题簇聚合 ---
user_prompt3 = build_user_prompt_cluster_agg(all_cluster)
output_cluster_agg = call_ark_chat_completions(
    api_url=API_URL,
    api_key=API_KEY,
    model=V3_1_MODEL_ID,
    system_prompt=system_prompt03,
    user_prompt=user_prompt3,
    temperature=TEMPERATURE,
    max_tokens=MAX_TOKENS,
    timeout=TIMEOUT_SEC,
    retries=RETRIES,
)

# 1) 先解析子话题簇
parsed_subclusters = parse_jsonl_text(all_cluster)
parsed_clusters, parsed_subclusters_enriched = normalize_model3_clusters(output_cluster_agg, parsed_subclusters)



# 兜底修 key（时间轴 / 子话题簇列表）
fixed_cnt = 0
fixed_sub_cnt = 0
for c in parsed_clusters:
    if ensure_time_axis_key(c, verbose=False):
        fixed_cnt += 1
    if ensure_subcluster_list_key(c):
        fixed_sub_cnt += 1
print(f"✅ 已自动补齐/修复 时间轴 的聚合簇数量：{fixed_cnt}")
print(f"✅ 已自动补齐/修复 子话题簇列表 的聚合簇数量：{fixed_sub_cnt}")

# 计算每日讨论热度 Top5
top5_results = extract_top5_heat_clusters(parsed_clusters, jsonl_lines01, top_k=5)
# 4) attach 讨论点：日版建议用“已补齐”的 parsed_subclusters
final_result_day = attach_discussion_points_day(top5_results, parsed_subclusters)

# 5) 全版本版用你 normalize 返回的 enriched（也可以）
final_result_all = attach_discussion_points_all(top5_results, parsed_subclusters_enriched)

# ====================================================
# 模型 #4：根据 Top5 回溯原文，做观点共识分析
# ====================================================

rows = print_mech_time_from_top5(final_result_day, all_cluster)  # 输出含 核心对象/机制 + 发言时间

all_opinions = []

for idx, r in enumerate(rows, start=1):
    mech = r.get("核心对象/机制") or ""
    full_time = (r.get("发言时间") or "").strip()

    if not mech or not full_time:
        print(f"⚠ 第 {idx} 条缺少 核心对象/机制 或 发言时间，原始行：{r}")
        continue

    # full_time 形如："2025-12-02 14:01:57-14:42:21"
    if " " not in full_time:
        print(f"⚠ 第 {idx} 条发言时间格式异常，无法拆分日期和时间轴：{full_time}")
        continue

    fayan_date, fayan_time = full_time.split(" ", 1)

    dialogs_lines = get_dialogs_lines_by_fayan_time_debug(
        jsonl_lines01,
        fayan_date,
        fayan_time,
        debug=True,
    )

    if not dialogs_lines:
        print(f"⚠ 该时间段内没有原文，跳过：{mech} | {fayan_date} {fayan_time}")
        continue

    # --- 模型 #4：分析玩家共识 ---
    user_prompt4 = build_user_prompt_subcluster_opinion(
        discussion_point=mech,
        json_lines=dialogs_lines,
    )

    try:
        opinion_output = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt04,
            user_prompt=user_prompt4,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
    except Exception as e:
        print("❌ 调用模型4出错:", e)
        continue

    opinions_this_mech = parse_opinion_output_to_list(opinion_output)

    # ⭐ 强制把当前 discussion_point 写回每个 opinion 的「讨论点」字段
    for op in opinions_this_mech:
        op["讨论点"] = mech
    
    all_opinions.extend(opinions_this_mech)

# 合并模型4观点结果回 Top5
merged_top5 = merge_top5_with_opinions_numbered(final_result_day, all_opinions)

for row in merged_top5:
    print(json.dumps(row, ensure_ascii=False, indent=2))

#如要把带观点版写入版本 jsonl，可以用 merged_top5；如果只要热度+讨论点，就用 final_result_day
append_daily_top5_to_version_jsonl(
merged_top5,
version_jsonl_path=VERSION_TOP5_JSONL_day
)
#整个版本
append_daily_top5_to_version_jsonl(
final_result_all,
version_jsonl_path=VERSION_TOP5_JSONL_all
)
# Out:
# 准备处理 1601 条，共 6 批（每批 300 条）。
# 🔥 批处理进度:   0%|                                                                                                                                                               | 0/6 [07:03<?, ?批/s]
# [批次 1] 模型#1 筛后保留 262 条
# 🔥 批处理进度:  17%|█████████████████████████                                                                                                                             | 1/6 [10:03<40:04, 480.93s/批]
# [批次 2] 模型#1 筛后保留 74 条
# 🔥 批处理进度:  33%|██████████████████████████████████████████████████                                                                                                    | 2/6 [16:06<19:05, 286.36s/批]
# [批次 3] 模型#1 筛后保留 199 条
# 🔥 批处理进度:  50%|███████████████████████████████████████████████████████████████████████████                                                                           | 3/6 [25:18<16:57, 339.33s/批]
# [批次 4] 模型#1 筛后保留 295 条
# 🔥 批处理进度:  67%|████████████████████████████████████████████████████████████████████████████████████████████████████                                                  | 4/6 [29:53<14:11, 425.91s/批]
# [批次 5] 模型#1 筛后保留 122 条
# 🔥 批处理进度:  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                         | 5/6 [32:23<05:53, 353.72s/批]
# [批次 6] 模型#1 筛后保留 73 条
# 🔥 批处理进度: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [32:36<00:00, 326.14s/批]
# ✅ 已自动补齐/修复 时间轴 的聚合簇数量：0
# ✅ 已自动补齐/修复 子话题簇列表 的聚合簇数量：0
# ✅ merge 命中=26, missing=0, leftover_unused_opinions=0
# {
#   "聚合话题簇": "客服互动与社交氛围",
#   "日期": "2026-01-06",
#   "时间轴": "18:09:04-18:13:55、19:27:04-20:11:29、22:33:00-22:50:41",
#   "发言玩家总数": 18,
#   "发言总数": 131,
#   "热度评分": 206.02,
#   "讨论点列表": [
#     {
#       "讨论点1": "玩家与客服菜头的互动调侃和社交氛围",
#       "玩家观点": [
#         "1：玩家喜欢通过调侃客服菜头的名字来互动，营造轻松氛围",
#         "2：玩家对客服菜头表现出友好和亲近的态度",
#         "3：玩家与客服菜头的互动中带有幽默和玩笑的成分"
#       ],
#       "代表性玩家发言示例": [
#         "@青瓷游戏客服-菜头 就不会是因为你菜吗",
#         "@青瓷游戏客服-菜头 而且还是菜鸡的头",
#         "@青瓷游戏客服-菜头 小代晚上好哦"
#       ]
#     },
#     {
#       "讨论点2": "玩家与客服哼唧的社交互动与娱乐化请求",
#       "玩家观点": [
#         "1：多名玩家以昵称或特定称呼（如“丽丽公主”、“大王”）与客服哼唧互动，表现出对客服的亲近感和娱乐化交流倾向",
#         "2：若干玩家通过@客服哼唧并发送图片或表情，试图引起客服注意并建立更个性化的互动",
#         "3：个别玩家表达了对客服哼唧的期待或不满，如要求唱歌、抱怨客服敷衍或忘记自己",
#         "4：少数玩家通过幽默或调侃的方式与客服哼唧互动，如“欠我一首歌”、“冷漠无情的女人”"
#       ],
#       "代表性玩家发言示例": [
#         "@青瓷游戏客服-哼唧 丽丽公主！",
#         "@青瓷游戏客服-哼唧 欠我一首歌",
#         "@青瓷游戏客服-哼唧 敷衍我",
#         "你这个冷漠无情的女人"
#       ]
#     },
#     {
#       "讨论点3": "关于客服哼唧的社群调侃与互动",
#       "玩家观点": [
#         "1：玩家对哼唧形象进行调侃和恶搞，并希望客服菜头也参与其中",
#         "2：玩家将哼唧作为社群互动的话题点，试图通过哼唧拉近与客服的距离"
#       ],
#       "代表性玩家发言示例": [
#         "@青瓷游戏客服-菜头 有人恶搞哼唧",
#         "快去请哼唧大王",
#         "@青瓷游戏客服-菜头 哼唧都用上了，你要跟上潮流"
#       ]
#     }
#   ]
# }
# {
#   "聚合话题簇": "装备配置与性能讨论",
#   "日期": "2026-01-06",
#   "时间轴": "14:45:07-14:47:08、14:47:45-14:47:45、14:50:54-14:52:00、14:52:51-14:53:30、14:54:00-14:54:35、14:55:00-14:55:00、14:55:06-14:59:37、14:57:25-14:57:42、14:58:10-14:59:24、15:01:40-15:02:07、15:03:01-15:03:01、15:07:14-15:16:52、15:17:14-15:17:14、15:17:58-15:25:26、15:20:34-15:24:58、15:24:33-15:24:43、16:17:13-16:17:29、16:29:45-16:29:45、16:44:14-16:47:21、23:27:49-23:34:17",
#   "发言玩家总数": 10,
#   "发言总数": 112,
#   "热度评分": 105.83,
#   "讨论点列表": [
#     {
#       "讨论点1": "保龄球道具效果解析与装备配置建议",
#       "玩家观点": [
#         "1：玩家对保龄球道具的效果存在疑问，希望了解其具体作用",
#         "2：玩家认为保龄球道具可以增加伤害",
#         "3：玩家观察到其他玩家普遍使用保龄球道具，认为其效果值得尝试"
#       ],
#       "代表性玩家发言示例": [
#         "保龄球的效果是什么",
#         "+伤",
#         "他们好像都要保龄球这套"
#       ]
#     },
#     {
#       "讨论点2": "健身器材装备核心部件缺失问题反馈",
#       "玩家观点": [
#         "1：玩家认为健身器材缺少核心部件"
#       ],
#       "代表性玩家发言示例": [
#         "健身器材是不是少了核心"
#       ]
#     },
#     {
#       "讨论点3": "幻想宠物销毁处理与装备位置优化建议",
#       "玩家观点": [
#         "1：玩家认为幻想宠物可以销毁以腾出装备位置",
#         "2：玩家建议在装备位置不足时优先销毁幻想宠物"
#       ],
#       "代表性玩家发言示例": [
#         "那两个宠物是幻想的是吧，找个时机送死换下去，占位置",
#         "@晓晨 忘了幻想物可以直接销毁",
#         "销毁掉，别占位置"
#       ]
#     },
#     {
#       "讨论点4": "床头饰品装备加成效果与配置分析",
#       "玩家观点": [
#         "1：玩家对床头饰品的加成效果存在疑问，希望了解具体作用"
#       ],
#       "代表性玩家发言示例": [
#         "这个效果是什么",
#         "应该是挂那几个床头饰品加成的"
#       ]
#     },
#     {
#       "讨论点5": "40盾装备与玩具装备的防御加成效果分析",
#       "玩家观点": [
#         "1：玩家在讨论40盾装备与玩具装备的防御加成效果，但具体观点不明确"
#       ],
#       "代表性玩家发言示例": [
#         "@晓晨 40盾",
#         "然后边上有玩具",
#         "+3盾"
#       ]
#     },
#     {
#       "讨论点6": "大盾投掷装备性能与使用体验",
#       "玩家观点": [
#         "1：个别玩家提及大盾投掷装备，但未明确表达具体观点"
#       ],
#       "代表性玩家发言示例": [
#         "@晓晨 @晓晨 大盾投掷"
#       ]
#     },
#     {
#       "讨论点7": "装备配置优化方案与伤害输出提升效果验证",
#       "玩家观点": [
#         "1：部分玩家认为通过销毁特定宠物和增加攻击类装备可以显著提升伤害输出",
#         "2：有玩家指出某些装备组合（如健身器材）虽然能提升攻击力但会带来过多负面效果",
#         "3：个别玩家展示高攻击力配置（如68投掷+121攻击）可以克服装备负面效果"
#       ],
#       "代表性玩家发言示例": [
#         "@圣洁珠光护手 @圣洁珠光护手 把那两个宠物销毁，再看看还有哪些投掷物或者加攻击的",
#         "健身器材的负面效果太多了",
#         "我68的投掷。121的攻击都怼过去了"
#       ]
#     },
#     {
#       "讨论点8": "健身器材装备负面效果（减精神、减防御）实战体验",
#       "玩家观点": [
#         "1：多名玩家认为健身器材的负面效果（如减精神、减防御）在实战中影响过大，导致生存能力下降"
#       ],
#       "代表性玩家发言示例": [
#         "@圣洁珠光护手 你这套死的快",
#         "健身器材的负面效果太多了"
#       ]
#     },
#     {
#       "讨论点9": "68投掷与121攻击数值下的地图开拓进度体验",
#       "玩家观点": [
#         "1：玩家认为68投掷和121攻击数值下可以完成地图开拓，但需要多次尝试",
#         "2：玩家认为300的攻击数值可能更容易完成地图开拓"
#       ],
#       "代表性玩家发言示例": [
#         "我68的投掷。121的攻击都怼过去了",
#         "这也就300的功",
#         "怼了十条命",
#         "把地图全开了"
#       ]
#     },
#     {
#       "讨论点10": "装备重新配置后战力不升反降问题反馈",
#       "玩家观点": [
#         "1：装备重新配置后战力下降导致战斗能力减弱",
#         "2：特定装备配置对某些敌人有效但对Boss无效"
#       ],
#       "代表性玩家发言示例": [
#         "我艹更打不过了",
#         "刚才扣60滴",
#         "Boss是一点打不了"
#       ]
#     },
#     {
#       "讨论点11": "举重装备在高玩群体中的使用体验",
#       "玩家观点": [
#         "1：部分玩家认为举重装备是大佬专属，普通玩家难以企及"
#       ],
#       "代表性玩家发言示例": [
#         "连个举重这就是大佬得世界吗"
#       ]
#     },
#     {
#       "讨论点12": "多种游戏玩法思路探讨与装备配置求助",
#       "玩家观点": [
#         "1：玩家在寻求多种游戏玩法思路",
#         "2：玩家在请求装备配置帮助",
#         "3：玩家表示自己是新手，只能提供建议"
#       ],
#       "代表性玩家发言示例": [
#         "还有别的思路吗",
#         "@小青蛙 求救",
#         "我新手"
#       ]
#     },
#     {
#       "讨论点13": "劲量瓶子与球类装备链接配置方案建议",
#       "玩家观点": [
#         "1：玩家建议将劲量瓶子链接到球类装备上"
#       ],
#       "代表性玩家发言示例": [
#         "@圣洁珠光护手 劲量瓶子链接一个球上"
#       ]
#     },
#     {
#       "讨论点14": "婴儿床装备性能评估与使用体验讨论",
#       "玩家观点": [
#         "1：玩家认为婴儿床装备性能优秀，使用体验良好",
#         "2：玩家指出举重技能会消耗防御属性，影响婴儿床的使用效果"
#       ],
#       "代表性玩家发言示例": [
#         "@圣洁珠光护手 婴儿床不香吗",
#         "我觉得香啊",
#         "举重都把防御吃没了"
#       ]
#     },
#     {
#       "讨论点15": "举重装备对防御属性的消耗问题体验",
#       "玩家观点": [
#         "1：玩家认为举重装备对防御属性的消耗过大，影响了游戏体验"
#       ],
#       "代表性玩家发言示例": [
#         "举重都把防御吃没了",
#         "举重太吃盾了"
#       ]
#     },
#     {
#       "讨论点16": "挂件装备在车辆上的配置方案与投掷时机讨论",
#       "玩家观点": [
#         "1：玩家认为挂件应该挂在车上",
#         "2：玩家认为挂件应该在第一回合投掷"
#       ],
#       "代表性玩家发言示例": [
#         "挂件挂车上",
#         "都是第一回合投掷"
#       ]
#     },
#     {
#       "讨论点17": "低配置装备硬怼九眼关卡的通关能力展示",
#       "玩家观点": [
#         "1：玩家展示低配置装备也能通关九眼关卡"
#       ],
#       "代表性玩家发言示例": [
#         "我用这垃圾都能硬怼九眼"
#       ]
#     },
#     {
#       "讨论点18": "装备链接功能对属性加成的效果讨论",
#       "玩家观点": [],
#       "代表性玩家发言示例": []
#     },
#     {
#       "讨论点19": "不同装备（废品、魔方、护具、弹药）的加成效果对比分析",
#       "玩家观点": [
#         "1：玩家注意到护具装备可以提供额外防御加成，尤其是装备四件时效果更明显",
#         "2：玩家发现弹药装备在三件时可以提供额外伤害加成",
#         "3：玩家认为废品和魔方装备需要特殊类型或高星级才能发挥更好效果"
#       ],
#       "代表性玩家发言示例": [
#         "我一个是装备护具额外增加防御，有四件还额外增加防御，另一个是弹药，装备三件就有额外增加伤害",
#         "得搞特殊废品和魔方石块",
#         "我等高星再用"
#       ]
#     },
#     {
#       "讨论点20": "装备属性搭配（格挡、回血、伤害）与实战表现",
#       "玩家观点": [
#         "1：多名玩家认为回血属性在实战中效果不佳，尤其是面对高级怪时无法提供有效帮助",
#         "2：个别玩家提到格挡与伤害属性组合在初期表现良好，可以快速清理小怪",
#         "3：若干玩家抱怨装备属性搭配不合理导致战斗困难，特别是缺乏伤害属性时"
#       ],
#       "代表性玩家发言示例": [
#         "回血最没用",
#         "高级怪秒不掉",
#         "我开局还行，格挡加伤害倒是可以，基本上小怪一下秒",
#         "就蒸馏器有一百伤害"
#       ]
#     }
#   ]
# }
# {
#   "聚合话题簇": "奇迹点收取遗漏问题",
#   "日期": "2026-01-06",
#   "时间轴": "18:56:39-19:58:54",
#   "发言玩家总数": 12,
#   "发言总数": 68,
#   "热度评分": 98.95,
#   "讨论点列表": [
#     {
#       "讨论点1": "奇迹点收集后忘记收取导致的资源损失问题",
#       "玩家观点": [
#         "1：玩家因忘记收取奇迹点导致资源损失感到沮丧",
#         "2：玩家对奇迹点收集机制存在误解，认为可以等待重启前统一收取",
#         "3：玩家对资源损失的影响程度存在不同看法"
#       ],
#       "代表性玩家发言示例": [
#         "少收一个奇迹点",
#         "忘记了直接填充了",
#         "就是你打完眼之后没直接去收，想等着重启前一起收，结果给忘了？[表情]"
#       ]
#     }
#   ]
# }
# {
#   "聚合话题簇": "护盾显示数值异常BUG",
#   "日期": "2026-01-06",
#   "时间轴": "22:14:27-22:59:37",
#   "发言玩家总数": 9,
#   "发言总数": 119,
#   "热度评分": 98.18,
#   "讨论点列表": [
#     {
#       "讨论点1": "开局护盾显示数值与实际护盾量不一致的bug",
#       "玩家观点": [
#         "1：玩家发现开局时右上角显示的护盾数值与实际护盾量不一致，需要受到攻击后才会显示正确数值",
#         "2：玩家推测可能是游戏未正确计算某些装备提供的护盾值"
#       ],
#       "代表性玩家发言示例": [
#         "@青瓷游戏客服-菜头 实际上护盾量是没问题的，就是开局右上角显示的护盾要少，等挨一次打以后就变得正常了。开局血条下面显示的护盾是20，右上角护盾显示是6，挨打一下就变成13就正常了",
#         "@青瓷游戏客服-菜头 可能最开始的时候，右上角那儿没计算大蓝闪蝶的护盾",
#         "那两个红脸谱是10护盾，白脸谱是5护盾，所以开局的时候右上角显示25@青瓷游戏客服-菜头"
#       ]
#     }
#   ]
# }
# {
#   "聚合话题簇": "开局输出不足问题反馈",
#   "日期": "2026-01-06",
#   "时间轴": "11:49:10-12:39:10",
#   "发言玩家总数": 11,
#   "发言总数": 67,
#   "热度评分": 90.04,
#   "讨论点列表": [
#     {
#       "讨论点1": "新开局输出不足与二图通关困难问题",
#       "玩家观点": [
#         "1：新开局的输出严重不足，导致游戏体验不佳",
#         "2：第二张图通关困难，需要堆命才能通过"
#       ],
#       "代表性玩家发言示例": [
#         "新开的一把压根没有输出",
#         "全靠平a",
#         "二图我都要堆命打了"
#       ]
#     }
#   ]
# }
# ✅ 已将当日 Top5（含 _idx 和 _daily_top_id）追加写入: 12311群.jsonl
# ✅ 已将当日 Top5（含 _idx 和 _daily_top_id）追加写入: banben.jsonl

# %%
rows
# Out:
# [{'核心对象/机制': '背包重新排列后的殖装搭配策略优化', '发言时间': '2026-01-01 09:27:19-09:27:19'},
#  {'核心对象/机制': '锤子殖装在四图的获取方式与地鼠殖装搭配问题', '发言时间': '2026-01-01 09:27:55-09:29:36'},
#  {'核心对象/机制': '运动器材类殖装（哑铃等）的搭配策略与使用效果', '发言时间': '2026-01-01 09:35:35-09:42:53'},
#  {'核心对象/机制': '精神病殖装的配置方案与等级要求（15级前后差异）',
#   '发言时间': '2026-01-01 09:41:39-09:57:39'},
#  {'核心对象/机制': '开局角色选择强度问题，涉及肿头龙、蝴蝶等具体殖装的强度对比',
#   '发言时间': '2026-01-01 15:45:18-15:52:57'},
#  {'核心对象/机制': '闪蝶殖装的实战性能评估与培养成本分析', '发言时间': '2026-01-01 16:52:40-16:56:33'},
#  {'核心对象/机制': '秃鹫、土拨鼠等殖装的前期套装搭配效果与推荐', '发言时间': '2026-01-01 17:59:22-18:00:31'},
#  {'核心对象/机制': '不同殖装装备的性能比较与选择建议', '发言时间': '2026-01-01 22:23:04-22:25:06'},
#  {'核心对象/机制': '1-4号位殖装分工、投掷物使用与BOSS战阵容搭配',
#   '发言时间': '2026-01-01 22:32:01-22:51:43'},
#  {'核心对象/机制': '游戏重启机制对见闻、殖装等级、积分点数的保留规则',
#   '发言时间': '2026-01-01 08:13:25-08:26:12'},
#  {'核心对象/机制': '999魔方获取条件、重启后魔方S等级清空规则、高要求殖装开局限制',
#   '发言时间': '2026-01-01 08:51:07-09:04:41'},
#  {'核心对象/机制': '殖装下阵限制与重启周目机制说明', '发言时间': '2026-01-01 10:29:09-10:34:15'},
#  {'核心对象/机制': '重启周目时殖装装备的保留规则与异常情况反馈', '发言时间': '2026-01-01 10:33:39-10:52:02'},
#  {'核心对象/机制': '重启契约书在石币商店的获取途径', '发言时间': '2026-01-01 10:53:54-10:55:34'},
#  {'核心对象/机制': '七个魔方之眼达成后的重启机制确认', '发言时间': '2026-01-01 15:57:16-15:57:36'},
#  {'核心对象/机制': '七眼后重启开新周目的条件、资源重置规则与殖装保留机制',
#   '发言时间': '2026-01-01 16:57:03-17:08:57'},
#  {'核心对象/机制': '死亡25次与100格子+契约书两种重启条件的区别与执行方式',
#   '发言时间': '2026-01-01 17:18:06-17:18:56'},
#  {'核心对象/机制': '重启的最佳时机选择、石币数量要求与畸变点优先级',
#   '发言时间': '2026-01-01 18:05:40-18:09:57'},
#  {'核心对象/机制': '重启后战略物资、殖装、飞船内容等资源的保留范围',
#   '发言时间': '2026-01-01 18:39:02-18:40:16'},
#  {'核心对象/机制': '重启契约的获取途径及商店购买条件', '发言时间': '2026-01-01 21:02:43-21:05:30'},
#  {'核心对象/机制': 'SAN值回复物品（烟头、酒、草、花束、章鱼丸子）的效果和使用策略',
#   '发言时间': '2026-01-01 16:29:22-16:33:21'},
#  {'核心对象/机制': '携带多个精神力回复道具对战斗能力的影响与格子利用率讨论',
#   '发言时间': '2026-01-01 16:48:59-16:51:38'},
#  {'核心对象/机制': '理智值（san值）机制，包括其含义、恢复方式及对游戏进程的影响',
#   '发言时间': '2026-01-01 18:53:27-19:52:24'},
#  {'核心对象/机制': '驾驶员作为消耗品与殖装本体的关系认知', '发言时间': '2026-01-01 09:46:31-09:47:12'},
#  {'核心对象/机制': 'B级驾驶员耗尽后的游戏机制影响', '发言时间': '2026-01-01 09:50:50-09:51:32'},
#  {'核心对象/机制': '驾驶员系统的更换机制，包括重启换殖装和专属驾驶员匹配',
#   '发言时间': '2026-01-01 15:50:36-15:57:16'},
#  {'核心对象/机制': '二号位殖装驾驶员死亡后的复活成本与策略选择', '发言时间': '2026-01-01 16:04:44-16:15:18'},
#  {'核心对象/机制': '精神值降低的影响、恢复物品使用及驾驶员作为消耗品的特性',
#   '发言时间': '2026-01-01 17:55:09-17:57:39'},
#  {'核心对象/机制': '驾驶员死亡后的更换条件、数量限制与复活机制', '发言时间': '2026-01-01 18:22:18-18:25:17'},
#  {'核心对象/机制': '通过精神力归零方式更换驾驶员的执行方法与注意事项',
#   '发言时间': '2026-01-01 18:34:03-18:34:48'},
#  {'核心对象/机制': '驾驶员更换机制及属性/装备的保留规则', '发言时间': '2026-01-01 19:39:00-19:40:11'},
#  {'核心对象/机制': '每日抽卡资源获取量与300抽/500抽积累规划',
#   '发言时间': '2026-01-01 11:29:51-11:45:09'},
#  {'核心对象/机制': '300抽与999抽的奖励机制（满9送1）', '发言时间': '2026-01-01 11:37:32-11:39:37'},
#  {'核心对象/机制': '资源获取方式（积分兑换、金币购买）和驾驶员抽奖概率机制',
#   '发言时间': '2026-01-01 15:52:19-15:55:49'},
#  {'核心对象/机制': '使用未熔炼物质进行抽奖的获取方式与奖励内容', '发言时间': '2026-01-01 18:03:04-18:04:28'},
#  {'核心对象/机制': '等级突破机制及所需抽奖物质的获取方式', '发言时间': '2026-01-01 19:58:31-20:05:06'}]
