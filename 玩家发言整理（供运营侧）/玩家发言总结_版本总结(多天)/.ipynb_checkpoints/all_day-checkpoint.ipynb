# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests

from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl

# %%
## 研发字典
speaker_map = {
    "16186514":   "peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
    "2726067525": "milissa",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt   = "1209《欢迎来到地球》测试2群.txt"

# 设定时间范围
start_time = "2025-12-06 00:00:00"
end_time   = "2025-12-07 00:00:00"


# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 1766 lines
# {"发言日期": "2025-12-06", "发言时间": "00:00:22", "玩家ID": "青瓷游戏客服-夕漫(2850593006)", "玩家消息": "地图界面左上角那个分数里"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：提取高讨论的发言并分析
- 结果按word格式文档输出
"""
from model_classifyV1_Copy1_Copy1 import (
    load_system_prompt,
    build_user_prompt_filter,build_user_prompt_clsuter,call_ark_chat_completions,
    extract_valid_json_lines,add_index_to_jsonl_lines,count_output_filter_stats,get_covered_indices_from_cluster_output,
    aggregate_cluster_outputs,build_user_prompt_cluster_agg,assign_global_cluster_ids,
    extract_top5_heat_clusters,attach_discussion_points,extract_cluster_stats,append_daily_top5_to_version_jsonl,infer_date_for_batch,
    match_dialogs_by_time,build_user_prompt_subcluster_opinion,extract_time_axis_from_title,
    parse_and_normalize_opinion_output,build_daily_top5_opinion_records,build_user_prompt_version_agg,parse_model2_output_to_json_list,parse_jsonl_text_safe
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md") # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("2话题分类.md") # 模型#2 system 提示词（分话题）
PROMPT_MD_PATH03 = Path("3日聚合.md") # 模型#3 system 提示词（日聚合）
PROMPT_MD_PATH04 = Path("版本聚合.md") #模型#4 system 提示词（观点分析）
VERSION_TOP5_JSONL = "test_top5.jsonl"
BATCH_SIZE       = 300
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 1.检验每日话提簇分类输出

# %%
import json
import time
from tqdm import tqdm



# ===========================================================
# =============== 主循环：模型#1 + 模型#2 ====================
# ===========================================================

# 读取系统提示
system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做话题簇
# 1⃣ 给原始 jsonl 每条加 _idx
jsonl_lines01_indexed = add_index_to_jsonl_lines(jsonl_lines01)

total = len(jsonl_lines01_indexed)

PRINT_UNCLUSTERED = False
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

# 统计总量用的（可选）
total_filtered_lines = 0         # 模型#1 输出总行数之和（含客服）
total_filtered_player_lines = 0  # 模型#1 输出玩家行数之和
total_covered_idx = 0            # 被话题簇覆盖的原始发言总数（按 _idx 去重）


for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    # 本批原始发言（已带 _idx）
    batch_lines = jsonl_lines01_indexed[start:end]

    # 本批原始 _idx 集合，用来和话题簇覆盖做差集
    batch_original_idx = set()
    for line in batch_lines:
        try:
            obj = json.loads(line)
            batch_original_idx.add(int(obj["_idx"]))
        except Exception:
            continue

    try:
        # ========== 模型 #1：筛相关 ==========
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue

        # 统计筛相关之后的行数：总行数 & 玩家行数
        filter_total_lines, filter_player_lines = count_output_filter_stats(output_filter)
        total_filtered_lines += filter_total_lines
        total_filtered_player_lines += filter_player_lines

        tqdm.write(
            f"[批次 {b+1}] 模型#1 输出总行数：{filter_total_lines}，"
            f"其中玩家发言：{filter_player_lines} 条（不去重）"
        )

        # ========== 模型 #2：话题簇 ==========
        user_prompt2 = build_user_prompt_clsuter(output_filter)
        output_cluster = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_cluster:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue

        # 打印本批的话题簇输出（原样）
        print(f"\n===== 批次 {b+1}/{total_batches} 话题簇输出 =====")
        print(output_cluster)
        print("===========================================\n")

        # 计算：本批有哪些 _idx 被话题簇覆盖（从“发言行号列表”解析）
        covered_idx = get_covered_indices_from_cluster_output(output_cluster)
        total_covered_idx += len(covered_idx)

        # 和“本批原始发言 _idx 集合”做差集，看有哪些没被覆盖
        unclustered_idx = batch_original_idx - covered_idx

        tqdm.write(
            f"[批次 {b+1}] 话题簇覆盖原始发言条数：{len(covered_idx)}，"
            f"未被覆盖条数：{len(unclustered_idx)}"
        )

        # ⭐⭐ 新增：打印“未被话题簇覆盖”的发言信息（最多前 20 条）
        if PRINT_UNCLUSTERED and unclustered_idx:
            # 先把这一批中未覆盖的发言对象捞出来
            unclustered_records = []
            for line in batch_lines:
                try:
                    obj = json.loads(line)
                except Exception:
                    continue
                idx_val = obj.get("_idx")
                try:
                    idx_int = int(idx_val)
                except Exception:
                    continue
                if idx_int in unclustered_idx:
                    unclustered_records.append(obj)

            # 按 _idx 排序，避免乱序
            unclustered_records.sort(key=lambda x: int(x.get("_idx", 0)))

            print(f"\n[批次 {b+1}] 未被话题簇覆盖的原始发言（最多前20条）：")
            for rec in unclustered_records[:20]:
                idx = rec.get("_idx")
                date = rec.get("发言日期") or rec.get("日期") or ""
                t = rec.get("发言时间") or rec.get("时间") or ""
                speaker = rec.get("发言人ID") or rec.get("玩家ID") or rec.get("角色ID") or ""
                msg = (
                    rec.get("玩家消息")
                    or rec.get("发言内容")
                    or rec.get("玩家发言")
                    or rec.get("消息")
                    or ""
                )
                print(f"- _idx={idx} [{date} {t}] {speaker}: {msg}")
            print()  # 换行分隔一下

    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    # 防止 QPS 过高
    time.sleep(SLEEP_BETWEEN)

print("\n✅ 全部批次处理完成！")
print(f"原始输入总数：{total}")
print(f"模型#1 筛相关后总行数：{total_filtered_lines}，其中玩家发言：{total_filtered_player_lines} 条")
print(f"模型#2 话题簇累计覆盖原始发言条数：{total_covered_idx}")
# Out:
# 准备处理 141 条，共 1 批（每批 300 条）。
# 🔥 批处理进度:   0%|                                                                                                                                     | 0/1 [02:39<?, ?批/s]
# [批次 1] 模型#1 输出总行数：89，其中玩家发言：89 条（不去重）
# 🔥 批处理进度:   0%|                                                                                                                                     | 0/1 [02:46<?, ?批/s]
# ===== 批次 1/1 话题簇输出 =====
# {"话题簇":"停服维护补偿讨论（2025-11-19 15:02:03-15:11:27）","核心对象/机制":"停服维护补偿机制，玩家讨论维护时长与补偿期望（100抽、50抽、石币、代币等）"}
# {"话题簇":"游戏下载与安装问题（2025-11-19 15:02:22-15:13:20）","核心对象/机制":"游戏安装包下载与更新机制，玩家询问下载链接、是否需要重新下载等问题"}
# {"话题簇":"角色技能更新讨论（2025-11-19 15:02:58-15:04:02）","核心对象/机制":"猛犸象和仙人掌角色的PTSD与强迫症被动技能更新实装情况"}
# {"话题簇":"客服互动与调侃（2025-11-19 15:07:27-15:14:50）","核心对象/机制":"客服服务体验，玩家与客服薏米、蓝桉的互动调侃及无关游戏内容的闲聊"}
# ===========================================
#
# [批次 1] 话题簇覆盖原始发言条数：0，未被覆盖条数：141
# 🔥 批处理进度: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [02:47<00:00, 167.86s/批]
# ✅ 全部批次处理完成！
# 原始输入总数：141
# 模型#1 筛相关后总行数：89，其中玩家发言：89 条
# 模型#2 话题簇累计覆盖原始发言条数：0

# %% [markdown]
# ## 加讨论观点分析的版本测试

# %%
from tqdm import tqdm
import time
import json
from pathlib import Path

# --- 前置：系统提示、初始化等 ---
system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做话提簇
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03)  # 日话题簇聚合
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04)  # 版本聚合（模型4）

batch_cluster_outputs = []  # 用于存放当天所有批次的话题簇 JSON 行（给模型#3用）

total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

# ====================================================
# 模型 #1 + 模型 #2：筛相关 + 话题簇划分（按批处理）
# ====================================================
for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue

        filter_count = sum(1 for line in output_filter.splitlines() if line.strip())
        tqdm.write(f"[批次 {b+1}] 模型#1 筛后保留 {filter_count} 条")
        written_total += filter_count

        # --- 模型 #2：话题簇划分 ---
        user_prompt2 = build_user_prompt_clsuter(output_filter)
        output_cluster = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )

        if not output_cluster:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue

        # ---------- ✅ 新的 JSON 解析 + _cluster_id 部分 ----------
        try:
            # 1) 先用修复解析器，把模型#2输出变成 list[dict]
            cluster_json_list = parse_model2_output_to_json_list(
                output_cluster,
                batch_idx=b+1,
            )

            if not cluster_json_list:
                tqdm.write(f"[批次 {b+1}] ⚠ 本批次未解析出任何合法 JSON 对象，跳过。")
                continue

            # 2) 从该批次中推断日期（你自己的逻辑）
            date_str = infer_date_for_batch(cluster_json_list, batch_lines)
            batch_id = f"B{b+1}"

            # 3) 分配全局 _cluster_id：日期 + 批次号 + 序号 ...
            cluster_json_list = assign_global_cluster_ids(
                cluster_json_list,
                date_str,
                batch_id,
            )

            # 4) 再转成 jsonl 文本（供后续 aggregate_cluster_outputs 使用）
            output_cluster_with_ids = "\n".join(
                json.dumps(c, ensure_ascii=False) for c in cluster_json_list
            )
            batch_cluster_outputs.append(output_cluster_with_ids)

        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠ 添加 _cluster_id 失败：{e}")
            continue
        # ---------- JSON 解析部分结束 ----------

    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    time.sleep(SLEEP_BETWEEN)
            

# ====================================================
# 模型 #3：日话题簇聚合
# ====================================================

# --- 聚合当天所有批次的话题簇 jsonl ---
all_cluster = aggregate_cluster_outputs(batch_cluster_outputs)

# --- 模型 #3：日话题簇聚合 ---
user_prompt3 = build_user_prompt_cluster_agg(all_cluster)
output_cluster_agg = call_ark_chat_completions(
    api_url=API_URL,
    api_key=API_KEY,
    model=V3_1_MODEL_ID,           # 智能体3用的模型
    system_prompt=system_prompt03,  # 日话题簇聚合提示词
    user_prompt=user_prompt3,
    temperature=TEMPERATURE,
    max_tokens=MAX_TOKENS,
    timeout=TIMEOUT_SEC,
    retries=RETRIES,
)

# 子话题簇（模型#2 输出，经 aggregate 后的 all_cluster，本身就是 jsonl）
parsed_subclusters = [
    json.loads(line.strip())
    for line in all_cluster.strip().splitlines()
    if line.strip()
]

# 聚合簇（模型#3 输出，如果不太干净，可以用 parse_jsonl_text 包一下）
parsed_clusters = parse_jsonl_text_safe(output_cluster_agg, label="模型#3聚合输出")

# ====================================================
# 计算 Top5 & 写入版本 jsonl
# ====================================================

top5_results = extract_top5_heat_clusters(parsed_clusters, jsonl_lines01, top_k=5)
final_result = attach_discussion_points(top5_results, parsed_subclusters)

# 输出检查（可暂时打开）
# for row in final_result:
#     print(json.dumps(row, ensure_ascii=False, indent=2))

append_daily_top5_to_version_jsonl(
    final_result,
    version_jsonl_path=VERSION_TOP5_JSONL,  # 这个路径你可以按版本号动态改
)

# ====================================================
# （可选）模型 #4：版本聚合
# ====================================================

if RUN_VERSION_AGG:
    try:
        version_path = Path(VERSION_TOP5_JSONL)
        if not version_path.exists():
            print(f"[模型#4] 找不到版本 top5 文件：{VERSION_TOP5_JSONL}，跳过版本聚合。")
        else:
            version_jsonl_text = version_path.read_text(encoding="utf-8")
            if not version_jsonl_text.strip():
                print(f"[模型#4] 版本 top5 文件为空，跳过版本聚合。")
            else:
                user_prompt4 = build_user_prompt_version_agg(version_jsonl_text)
                output_version_agg = call_ark_chat_completions(
                    api_url=API_URL,
                    api_key=API_KEY,
                    model=V3_1_MODEL_ID,     # 你给模型4选的模型
                    system_prompt=system_prompt04,
                    user_prompt=user_prompt4,
                    temperature=TEMPERATURE,
                    max_tokens=MAX_TOKENS,
                    timeout=TIMEOUT_SEC,
                    retries=RETRIES,
                )

                print("[模型#4] 版本聚合输出：")
                print(output_version_agg)
    except Exception as e:
        print(f"[模型#4] 版本聚合出错：{e}")
# Out:
# 准备处理 1766 条，共 6 批（每批 300 条）。
# 🔥 批处理进度:   0%|                                                                                 | 0/6 [04:22<?, ?批/s]
# [批次 1] 模型#1 筛后保留 161 条
# 🔥 批处理进度:  17%|████████████                                                            | 1/6 [08:48<24:18, 291.68s/批]
# [批次 2] 模型#1 筛后保留 140 条
# 🔥 批处理进度:  33%|████████████████████████                                                | 2/6 [12:07<18:03, 270.91s/批]
# [批次 3] 模型#1 筛后保留 101 条
# 🔥 批处理进度:  50%|████████████████████████████████████                                    | 3/6 [16:16<11:46, 235.54s/批]
# [批次 4] 模型#1 筛后保留 146 条
# 🔥 批处理进度:  67%|████████████████████████████████████████████████                        | 4/6 [24:42<08:04, 242.50s/批]
# [批次 5] 模型#1 筛后保留 297 条
# 🔥 批处理进度:  83%|████████████████████████████████████████████████████████████            | 5/6 [28:47<05:43, 343.49s/批]
# [批次 6] 模型#1 筛后保留 135 条
# 🔥 批处理进度: 100%|████████████████████████████████████████████████████████████████████████| 6/6 [29:21<00:00, 293.54s/批]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 143
#     135 parsed_subclusters = [
#     136     json.loads(line.strip())
#     137     for line in all_cluster.strip().splitlines()
#     138     if line.strip()
#     139 ]
#     141 # 聚合簇（模型#3 输出，如果不太干净，可以用 parse_jsonl_text 包一下）
#     142 parsed_clusters = [
# --> 143     json.loads(line.strip())
#     144     for line in output_cluster_agg.strip().splitlines()
#     145     if line.strip()
#     146 ]
#     148 # ====================================================
#     149 # 计算 Top5 & 写入版本 jsonl
#     150 # ====================================================
#     152 top5_results = extract_top5_heat_clusters(parsed_clusters, jsonl_lines01, top_k=5)
#
# File E:\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File E:\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File E:\anaconda3\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 89 (char 88)

# %%
print(output_cluster_agg)
# Out:
# {"话题簇": "地图界面功能询问", "子话题簇列表": ["2025-12-06_B1_01"], "日期": "2025-12-06", "时间轴": "00:00:22-00:01:14"}
# {"话题簇": "序列石板系统维物品更改功能需求", "子话题簇列表": ["2025-12-06_B1_02"], "日期": "2025-12-06", "时间轴": "00:01:58-00:02:16"}
# {"话题簇": "第一图净化格数与开局卡门问题", "子话题簇列表": ["2025-12-06_B1_03"], "日期": "2025-12-06", "时间轴": "00:04:55-00:05:12"}
# {"话题簇": "新手教程完善需求", "子话题簇列表": ["2025-12-06_B1_04"], "日期": "2025-12-06", "时间轴": "00:16:29-00:16:42"}
# {"话题簇": "转主力玩法难度体验", "子话题簇列表": ["2025-12-06_B1_05"], "日期": "2025-12-06", "时间轴": "00:22:27-00:22:43"}
# {"话题簇": "魔方重启机制操作与购买", "子话题簇列表": ["2025-12-06_B1_06"], "日期": "2025-12-06", "时间轴": "00:28:20-00:32:25"}
# {"话题簇": "局外进阶功能获取与殖装抽奖关联", "子话题簇列表": ["2025-12-06_B1_07"], "日期": "2025-12-06", "时间轴": "00:37:59-00:42:56"}
# {"话题簇": "机器人系统奖励内容", "子话题簇列表": ["2025-12-06_B1_08"], "日期": "2025-12-06", "时间轴": "00:56:56"}
# {"话题簇": "新周目快捷功能保留需求", "子话题簇列表": ["2025-12-06_B1_09"], "日期": "2025-12-06", "时间轴": "01:42:31"}
# {"话题簇": "游戏内选项决策求助", "子话题簇列表": ["2025-12-06_B1_10"], "日期": "2025-12-06", "时间轴": "07:24:54-07:26:01"}
# {"话题簇": "精神病系统幻影选择与思考泡泡使用", "子话题簇列表": ["2025-12-06_B1_11"], "日期": "2025-12-06", "时间轴": "07:26:06-07:31:40"}
# {"话题簇": "游戏卡顿与显示异常问题", "子话题簇列表": ["2025-12-06_B1_12"], "日期": "2025-12-06", "时间轴": "08:00:30-08:34:55"}
# {"话题簇": "第三周目地块解锁难度与怪物等级", "子话题簇列表": ["2025-12-06_B1_13"], "日期": "2025-12-06", "时间轴": "08:35:56-08:48:45"}
# {"话题簇": "第一图卡关与材料填充技巧", "子话题簇列表": ["2025-12-06_B1_14"], "日期": "2025-12-06", "时间轴": "09:34:12-09:47:09"}
# {"话题簇": "残肢系统连接规则与电锯可塑性改进", "子话题簇列表": ["2025-12-06_B1_15"], "日期": "2025-12-06", "时间轴": "09:36:19-09:40:25"}
# {"话题簇": "第一关龙boss战斗策略与装备要求", "子话题簇列表": ["2025-12-06_B1_16"], "日期": "2025-12-06", "时间轴": "10:13:23-10:31:41"}
# {"话题簇": "精神病系统重生保留状态", "子话题簇列表": ["2025-12-06_B1_17"], "日期": "2025-12-06", "时间轴": "10:22:15-10:22:40"}
# {"话题簇": "地图界面缩放功能可用性", "子话题簇列表": ["2025-12-06_B1_18"], "日期": "2025-12-06", "时间轴": "10:25:32-10:26:24"}
# {"话题簇": "自爆机制伤害与触发条件", "子话题簇列表": ["2025-12-06_B2_01"], "日期": "2025-12-06", "时间轴": "10:31:42-10:48:11"}
# {"话题簇": "挂机功能操作方法与界面显示", "子话题簇列表": ["2025-12-06_B2_02"], "日期": "2025-12-06", "时间轴": "11:02:59-11:13:43"}
# {"话题簇": "探索功能分类与标识区分", "子话题簇列表": ["2025-12-06_B2_03"], "日期": "2025-12-06", "时间轴": "11:43:25-11:45:31"}
# {"话题簇": "魔方之眼数量与重启条件讨论", "子话题簇列表": ["2025-12-06_B2_04"], "日期": "2025-12-06", "时间轴": "11:07:13-11:08:49"}
# {"话题簇": "游戏设备性能问题反馈", "子话题簇列表": ["2025-12-06_B2_05"], "日期": "2025-12-06", "时间轴": "11:53:59-12:49:42"}
# {"话题簇": "重启机制保留内容与等级重置规则", "子话题簇列表": ["2025-12-06_B2_06"], "日期": "2025-12-06", "时间轴": "14:02:18-14:17:39"}
# {"话题簇": "殖装后期使用策略与天赋搭配", "子话题簇列表": ["2025-12-06_B2_07"], "日期": "2025-12-06", "时间轴": "14:20:40-14:21:15"}
# {"话题簇": "魔方功能重启后重新获取问题", "子话题簇列表": ["2025-12-06_B2_08"], "日期": "2025-12-06", "时间轴": "14:28:49-14:29:19"}
# {"话题簇": "物品格子占用效率评估", "子话题簇列表": ["2025-12-06_B2_09"], "日期": "2025-12-06", "时间轴": "14:40:20-14:40:26"}
# {"话题簇": "重启时机选择与进度评估", "子话题簇列表": ["2025-12-06_B2_10"], "日期": "2025-12-06", "时间轴": "15:25:46-15:29:28"}
# {"话题簇": "重启后难度平衡性讨论", "子话题簇列表": ["2025-12-06_B2_11"], "日期": "2025-12-06", "时间轴": "15:32:02-15:37:39"}
# {"话题簇": "猫头鹰图腾后置位机制与描述问题", "子话题簇列表": ["2025-12-06_B3_01"], "日期": "2025-12-06", "时间轴": "15:57:21-16:46:18"}
# {"话题簇": "方块资源获取与填充策略", "子话题簇列表": ["2025-12-06_B3_02"], "日期": "2025-12-06", "时间轴": "16:10:02-16:22:36"}
# {"话题簇": "石板与棒棒糖选择策略对比", "子话题簇列表": ["2025-12-06_B3_03"], "日期": "2025-12-06", "时间轴": "16:26:32-16:38:00"}
# {"话题簇": "挂机地点列表界面优化建议", "子话题簇列表": ["2025-12-06_B3_04"], "日期": "2025-12-06", "时间轴": "17:17:06-17:18:00"}
# {"话题簇": "迷宫界面点击卡顿问题", "子话题簇列表": ["2025-12-06_B3_05"], "日期": "2025-12-06", "时间轴": "17:20:55-17:21:25"}
# {"话题簇": "驾驶员消耗品重生重置规则", "子话题簇列表": ["2025-12-06_B3_06"], "日期": "2025-12-06", "时间轴": "17:23:15-17:23:29"}
# {"话题簇": "游戏地块异常跳转BUG", "子话题簇列表": ["2025-12-06_B3_07"], "日期": "2025-12-06", "时间轴": "17:24:16-17:25:23"}
# {"话题簇": "黄色地块清理后跳转异常", "子话题簇列表": ["2025-12-06_B4_01"], "日期": "2025-12-06", "时间轴": "17:25:25-17:27:31"}
# {"话题簇": "邪灵龙王伤害数值与进阶难度", "子话题簇列表": ["2025-12-06_B4_02"], "日期": "2025-12-06", "时间轴": "17:44:14-17:56:37"}
# {"话题簇": "护盾叠加机制与防御build构建", "子话题簇列表": ["2025-12-06_B4_03"], "日期": "2025-12-06", "时间轴": "17:58:40-18:09:39"}
# {"话题簇": "折纸投掷武器效果与伤害机制", "子话题簇列表": ["2025-12-06_B4_04"], "日期": "2025-12-06", "时间轴": "18:09:46-18:14:54"}
# {"话题簇": "职装进阶等级要求与卡点问题", "子话题簇列表": ["2025-12-06_B4_05"], "日期": "2025-12-06", "时间轴": "18:14:54-18:16:34"}
# {"话题簇": "高等级BOSS战斗难度与策略", "子话题簇列表": ["2025-12-06_B4_06"], "日期": "2025-12-06", "时间轴": "18:21:44-18:38:53"}
# {"话题簇": "挖矿机制与多人协作资源获取", "子话题簇列表": ["2025-12-06_B4_07"], "日期": "2025-12-06", "时间轴": "18:33:16-18:42:01"}
# {"话题簇": "殖装阶位进阶系统疑问", "子话题簇列表": ["2025-12-06_B4_08"], "日期": "2025-12-06", "时间轴": "18:57:53-19:07:52"}
# {"话题簇": "殖装装备配置与全体生效机制", "子话题簇列表": ["2025-12-06_B4_09"], "日期": "2025-12-06", "时间轴": "19:19:04-19:22:40"}
# {"话题簇": "关卡格数与开局资源分配策略", "子话题簇列表": ["2025-12-06_B5_01"], "日期": "2025-12-06", "时间轴": "19:22:43-19:24:16"}
# {"话题簇": "魔方之眼建筑修复与怪物应对", "子话题簇列表": ["2025-12-06_B5_02"], "日期": "2025-12-06", "时间轴": "19:24:27-19:26:14"}
# {"话题簇": "精英怪战斗难度与应对方法", "子话题簇列表": ["2025-12-06_B5_03"], "日期": "2025-12-06", "时间轴": "19:26:24-19:28:44"}
# {"话题簇": "初始殖装与抽卡概率体验", "子话题簇列表": ["2025-12-06_B5_04"], "日期": "2025-12-06", "时间轴": "19:31:02-19:34:23"}
# {"话题簇": "挖矿时间效率与理智消耗机制", "子话题簇列表": ["2025-12-06_B5_05"], "日期": "2025-12-06", "时间轴": "19:34:33-19:39:18"}
# {"话题簇": "精神病症状触发条件与效果", "子话题簇列表": ["2025-12-06_B5_06"], "日期": "2025-12-06", "时间轴": "19:39:38-19:58:26"}
# {"话题簇": "殖装评级与T级区分标准", "子话题簇列表": ["2025-12-06_B5_07"], "日期": "2025-12-06", "时间轴": "19:42:37-19:46:23"}
# {"话题簇": "翼龙殖装性能对比分析", "子话题簇列表": ["2025-12-06_B5_08"], "日期": "2025-12-06", "时间轴": "19:47:40-19:50:47"}
# {"话题簇": "首领怪物特殊战斗机制", "子话题簇列表": ["2025-12-06_B5_09"], "日期": "2025-12-06", "时间轴": "19:48:37-19:49:20"}
# {"话题簇": "奇迹书重启功能使用方法", "子话题簇列表": ["2025-12-06_B5_10"], "日期": "2025-12-06", "时间轴": "20:04:46-20:08:03"}
# {"话题簇": "被害妄想症多维召唤物效果", "子话题簇列表": ["2025-12-06_B5_11"], "日期": "2025-12-06", "时间轴": "20:17:11-20:22:55"}
# {"话题簇": "投掷物与黑帮套装性能对比", "子话题簇列表": ["2025-12-06_B5_12"], "日期": "2025-12-06", "时间轴": "20:26:31-20:28:53"}
# {"话题簇": "殖装buff效果显示需求", "子话题簇列表": ["2025-12-06_B5_13"], "日期": "2025-12-06", "时间轴": "20:27:55-20:38:01"}
# {"话题簇": "哑铃套装buff叠加与配装策略", "子话题簇列表": ["2025-12-06_B5_14"], "日期": "2025-12-06", "时间轴": "20:37:19-20:40:42"}
# {"话题簇": "背包界面红点提示异常问题", "子话题簇列表": ["2025-12-06_B5_15"], "日期": "2025-12-06", "时间轴": "20:39:21-20:44:35"}
# {"话题簇": "地图界面缩放功能优化建议", "子话题簇列表": ["2025-12-06_B5_16"], "日期": "2025-12-06", "时间轴": "20:49:45-20:51:52"}
# {"话题簇": "降神石头属性加成效果咨询", "子话题簇列表": ["2025-12-06_B5_17"], "日期": "2025-12-06", "时间轴": "20:59:29-21:06:26"}
# {"话题簇": "面包炉陷阱伤害数值测试", "子话题簇列表": ["2025-12-06_B5_18"], "日期": "2025-12-06", "时间轴": "21:14:28"}
# {"话题簇": "麻将玩法高收益发现", "子话题簇列表": ["2025-12-06_B5_19"], "日期": "2025-12-06", "极轴": "21:22:09"}
# {"话题簇": "魔方升级选项收益对比", "子话题簇列表": ["2025-12-06_B5_20"], "日期": "2025-12-06", "时间轴": "21:23:37-21:24:22"}
# {"话题簇": "超级扭蛋碎片未上线功能说明", "子话题簇列表": ["2025-12-06_B5_21"], "日期": "2025-12-06", "时间轴": "21:28:24-21:29:12"}
# {"话题簇": "蛋糕塔版本回退问题", "子话题簇列表": ["2025-12-06_B5_22"], "日期": "2025-12-06", "时间轴": "21:30:41-21:31:03"}
# {"话题簇": "iOS版本功能完善度反馈", "子话题簇列表": ["2025-12-06_B5_23"], "日期": "2025-12-06", "时间轴": "21:37:01-21:38:59"}
# {"话题簇": "扭蛋机球瓶掉落概率与收集", "子话题簇列表": ["2025-12-06_B6_01"], "日期": "2025-12-06", "时间轴": "21:49:47-21:50:23"}
# {"话题簇": "物品链接系统操作与生效规则", "子话题簇列表": ["2025-12-06_B6_02"], "日期": "2025-12-06", "时间轴": "21:52:45-21:54:16"}
# {"话题簇": "图鉴评分系统加成机制", "子话题簇列表": ["2025-12-06_B6_03"], "日期": "2025-12-06", "时间轴": "21:54:21-21:54:35"}
# {"话题簇": "挂机功能稳定性与断连问题", "子话题簇列表": ["2025-12-06_B6_04"], "日期": "2025-12-06", "时间轴": "21:55:24-21:55:26"}
# {"话题簇": "图鉴轿车物品具体指代确认", "子话题簇列表": ["2025-12-06_B6_05"], "日期": "2025-12-06", "时间轴": "22:10:27-22:10:39"}
# {"话题簇": "残缺尸体物品功能用途询问", "子话题簇列表": ["2025-12-06_B6_06"], "日期": "2025-12-06", "时间轴": "22:15:30-22:16:20"}
# {"话题簇": "收集物品获取进度分享", "子话题簇列表": ["2025-12-06_B6_07"], "日期": "2025-12-06", "时间轴": "22:18:22-22:18:34"}
# {"话题簇": "重启机制对地块进度影响", "子话题簇列表": ["2025-12-06_B6_08"], "日期": "2025-12-06", "时间轴": "22:24:30-22:25:35"}
# {"话题簇": "问卷系统访问权限与竞争机制", "子话题簇列表": ["2025-12-06_B6_09"], "日期": "2025-12-06", "时间轴": "22:28:24-22:28:38"}
# {"话题簇": "装备与殖装系统关联性发现", "子话题簇列表": ["2025-12-06_B6_10"], "日期": "2025-12-06", "时间轴": "22:29:15-22:29:40"}
# {"话题簇": "大袋熊技能伤害数值机制分析", "子话题簇列表": ["2025-12-06_B6_11"], "日期": "2025-12-06", "时间轴": "22:30:00-22:30:32"}
# {"话题簇": "玩家地理位置与资源争夺策略", "子话题簇列表": ["2025-12-06_B6_12"], "日期": "2025-12-06", "时间轴": "极轴": "22:30:57-22:33:57"}
# {"话题簇": "台球装备伤害类型与效果评估", "子话题簇列表": ["2025-12-06_B6_13"], "日期": "2025-12-06", "时间轴": "22:34:24-极轴": "22:38:33"}
# {"话题簇": "游戏卡顿问题与重启解决方案", "子话题簇列表": ["2025-12-06_B6_14"], "日期": "2025-12-06", "时间轴": "22:39:44-22:40:47"}
# {"话题簇": "问卷链接提供与客服互动流程", "子话题簇列表": ["2025-12-06_B6_15"], "日期": "极轴": "2025-12-06", "时间轴": "22:41:58-22:42:07"}
# {"话题簇": "打野怪卡顿问题与录屏诊断", "子话题簇列表": ["2025-12-06_B6_16"], "日期": "2025-12-06", "时间轴": "22:52:27-22:54:59"}
# {"话题簇": "大袋熊技能实际伤害效果验证", "子话题簇列表": ["2025-12-06_B6_17"], "日期": "2025-12-06", "时间轴": "23:02:04-23:02:45"}
# {"话题簇": "界墙玩法邻居资源争夺机制", "子话题簇列表": ["2025-12-06_B6_18"], "日期": "2025-12-06", "时间轴": "23:09:37-23:13:13"}

# %%
import json
from json import JSONDecodeError
from typing import List, Dict, Any
def parse_jsonl_text_safe(text: str, label: str = "模型#3") -> List[Dict[str, Any]]:
    """
    尝试把 text 按行解析为 JSON 对象：
    - 每行独立尝试 json.loads
    - 解析失败时不会抛异常，而是打印出具体行号和原文，方便排查
    - 返回所有成功解析的对象列表
    """
    objs: List[Dict[str, Any]] = []
    lines = text.strip().splitlines()

    for idx, raw in enumerate(lines, start=1):
        s = (raw or "").strip()
        if not s:
            continue

        # 可选：去掉 ```json / ``` 这类代码块包裹
        if s.startswith("```"):
            # 直接跳过代码块标记行
            continue

        try:
            obj = json.loads(s)
        except JSONDecodeError as e:
            print(f"[{label}] ❌ JSON解析失败：行#{idx} -> {e}")
            print(f"[{label}] 该行原文：{s}")
            # 不 raise，继续解析后面的行
            continue

        objs.append(obj)

    return objs

# %%
parsed_clusters = parse_jsonl_text_safe(output_cluster_agg, label="模型#3聚合输出")
# Out:
# [模型#3聚合输出] ❌ JSON解析失败：行#80 -> Expecting ',' delimiter: line 1 column 89 (char 88)
# [模型#3聚合输出] 该行原文：{"话题簇": "玩家地理位置与资源争夺策略", "子话题簇列表": ["2025-12-06_B6_12"], "日期": "2025-12-06", "时间轴": "极轴": "22:30:57-22:33:57"}
# [模型#3聚合输出] ❌ JSON解析失败：行#81 -> Expecting ',' delimiter: line 1 column 98 (char 97)
# [模型#3聚合输出] 该行原文：{"话题簇": "台球装备伤害类型与效果评估", "子话题簇列表": ["2025-12-06_B6_13"], "日期": "2025-12-06", "时间轴": "22:34:24-极轴": "22:38:33"}
# [模型#3聚合输出] ❌ JSON解析失败：行#83 -> Expecting ',' delimiter: line 1 column 68 (char 67)
# [模型#3聚合输出] 该行原文：{"话题簇": "问卷链接提供与客服互动流程", "子话题簇列表": ["2025-12-06_B6_15"], "日期": "极轴": "2025-12-06", "时间轴": "22:41:58-22:42:07"}

# %% [markdown]
# ## 开始运行(不可动）

# %%
from tqdm import tqdm
import time
import json
from pathlib import Path

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做话提簇
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03)  # 话题簇聚合 / 校正（智能体4）
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04)  # 话提簇玩家观点感受分析


sub_opinion_map = {}
# 用于存放当天所有批次的话题簇 JSON 行（给智能体4用）
batch_cluster_outputs  = []
total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        filter_count = sum(1 for line in output_filter.splitlines() if line.strip())
        tqdm.write(f"[批次 {b+1}] 模型#1 筛后保留 {filter_count} 条")
        written_total += filter_count   # 如果不需要总数，可以删掉这一行
        
        # --- 模型 #2：话题簇划分 ---
        user_prompt2 = build_user_prompt_clsuter(output_filter)
        output_cluster = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        
        

        if not output_cluster:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        try:
            cluster_json_list = []
            for line in output_cluster.strip().splitlines():
                line = line.strip()
                if not line.startswith("{"):
                    continue
                obj = json.loads(line)
                # 将 "话题簇1" → "话题簇"，便于后续统一处理
                for key in list(obj.keys()):
                    if key.startswith("话题簇") and key != "话题簇":
                        obj["话题簇"] = obj.pop(key)
                cluster_json_list.append(obj)

            # 假设从输出中拿日期
            date_str = infer_date_for_batch(cluster_json_list, batch_lines)  # 你可以从上下文获得更准确值
            batch_id = f"B{b+1}"
            cluster_json_list = assign_global_cluster_ids(cluster_json_list, date_str, batch_id)
        
            output_cluster_with_ids = "\n".join(json.dumps(c, ensure_ascii=False) for c in cluster_json_list)
            batch_cluster_outputs.append(output_cluster_with_ids)
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠ 添加 _cluster_id 失败：{e}")
            continue

       
       
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    time.sleep(SLEEP_BETWEEN)



# --- 每日话提簇聚合成jsonl ---
all_cluster = aggregate_cluster_outputs(batch_cluster_outputs)

# --- 模型 #3：日话提簇聚合 ---
user_prompt3 = build_user_prompt_cluster_agg(all_cluster)
output_cluster_agg = call_ark_chat_completions(
    api_url=API_URL,
    api_key=API_KEY,
    model=V3_1_MODEL_ID,           # 或你给智能体4选的模型
    system_prompt=system_prompt03,  # 话题簇聚合/校正提示词
    user_prompt=user_prompt3,
    temperature=TEMPERATURE,
    max_tokens=MAX_TOKENS,
    timeout=TIMEOUT_SEC,
    retries=RETRIES,
)

#每日总发言转单条jonsl格式
parsed_subclusters = [
    json.loads(line.strip()) for line in all_cluster.strip().splitlines() if line.strip()
]

# 解析原始发言 jsonl，为按时间轴筛选对话用
parsed_msgs = [json.loads(line.strip()) for line in jsonl_lines01 if line.strip()]

#每日聚合后话提簇转单条jsonl格式
parsed_clusters = [json.loads(line) for line in output_cluster_agg.strip().splitlines() if line.strip()]

#计算每日讨论热度top5
top5_results = extract_top5_heat_clusters(parsed_clusters, jsonl_lines01, top_k=5)

#######提取子话提簇讨论点###########################################################
####### 建子簇索引：_cluster_id -> 子簇对象 ########
sub_map = {}
for row in parsed_subclusters:
    cid = row.get("_cluster_id")
    if isinstance(cid, str) and cid:
        sub_map[cid] = row

####### 在 Top5 循环里，对每个【子话题簇】单独跑模型#4 ########
for cluster in top5_results:
    date = cluster["日期"]
    # 聚合簇的整体时间轴（只用来兜底）
    cluster_time_axis = cluster["时间轴"]
    cid_list = cluster.get("子话题簇列表", [])

    for cid in cid_list:
        sub = sub_map.get(cid)
        if not sub:
            print(f"\n[聚合话题簇：{cluster.get('聚合话题簇')}] 子话题簇 ID：{cid}")
            print("  ⚠ 在 sub_map / parsed_subclusters 中未找到该 _cluster_id。")
            continue

        
        # ---- 1）从子话题簇【标题】里提取时间轴 ----
        sub_title = sub.get("话题簇", "") or ""
        sub_time_axis = extract_time_axis_from_title(sub_title)

        # ---- 2）按【子话提簇时间轴】从原始发言里匹配 dialogs ----
        dialogs = match_dialogs_by_time(parsed_msgs, date, sub_time_axis)

        # ---- 3）构造 discussion_point（不打印，只用来写 prompt）----
        discussion_point = (
    
            sub.get("核心对象/机制")
            or sub.get("话题簇")
            or ""
        )
        topic_id = sub.get("_cluster_id", cid)
        
        # ---- 4）模型4 玩家发言感受分析总结----
        user_prompt4 = build_user_prompt_subcluster_opinion(
            topic_id=topic_id,
            discussion_point=discussion_point,
            dialogs=dialogs,
        )
        if not isinstance(user_prompt4, str) or not user_prompt4.strip():
            print(f"  ⚠ user_prompt4 为空或非法，跳过本子话题簇：{cid}")
            continue
        opinion_output = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,             
            system_prompt=system_prompt04,   
            user_prompt=user_prompt4,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )


       
    opinion_obj = parse_and_normalize_opinion_output(
        opinion_output=opinion_output,
        topic_id=topic_id,
        discussion_point=discussion_point,
    )
    sub_opinion_map[topic_id] = opinion_obj
# ===================================
# 组装 Top5 + 观点总结，并写入 jsonl
# ===================================
# Out:
# 准备处理 2308 条，共 8 批（每批 300 条）。
# 🔥 批处理进度:   0%|                                                                                                                                                       | 0/8 [06:33<?, ?批/s]
# [批次 1] 模型#1 筛后保留 240 条
# 🔥 批处理进度:  12%|█████████████████▊                                                                                                                            | 1/8 [12:29<48:22, 414.62s/批]
# [批次 2] 模型#1 筛后保留 206 条
# 🔥 批处理进度:  25%|███████████████████████████████████▌                                                                                                          | 2/8 [20:44<38:45, 387.59s/批]
# [批次 3] 模型#1 筛后保留 283 条
# 🔥 批处理进度:  38%|█████████████████████████████████████████████████████▎                                                                                        | 3/8 [21:22<36:31, 438.36s/批]

# %%
final_top5_with_opinion = build_daily_top5_opinion_records(
    top5_results=top5_results,
    sub_opinion_map=sub_opinion_map,
)

append_daily_top5_to_version_jsonl(
    final_result=final_top5_with_opinion,
    version_jsonl_path="version_daily_top5_with_opinion.jsonl",
)
# Out:
# ✅ 已将当日 Top5（含 _idx 和 _daily_top_id）追加写入: version_daily_top5_with_opinion.jsonl

# %%
print(cid_list)
print(sub)

print(sub_title)
print(sub_time_axis)
print(discussion_point)
print(dialogs)
print(cid)
# Out:
# ['2025-12-02_B1_03', '2025-12-02_B1_14', '2025-12-02_B2_07']
# {'话题簇': '游戏物品异常问题反馈（2025-12-02 22:57:27-22:57:31）', '核心对象/机制': '游戏内物品异常消失问题的反馈与处理', '_cluster_id': '2025-12-02_B2_07'}
# 游戏物品异常问题反馈（2025-12-02 22:57:27-22:57:31）
# 22:57:27-22:57:31
# 游戏内物品异常消失问题的反馈与处理
# [{'发言日期': '2025-12-02', '发言时间': '22:57:27', '玩家ID': '无为无畏(2514177080)', '玩家消息': '[图片]'}, {'发言日期': '2025-12-02', '发言时间': '22:57:31', '玩家ID': '无为无畏(2514177080)', '玩家消息': '东西没了'}]
# 2025-12-02_B2_07

# %%
print(opinion_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(opinion_output)
#
# NameError: name 'opinion_output' is not defined

# %%
print(sub_time_axis)
