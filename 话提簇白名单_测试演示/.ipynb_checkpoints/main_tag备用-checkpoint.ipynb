# %% [markdown]
# ## 数据处理

# %%
import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl
from model_classifyV1_Copy1 import postprocess_excel_by_topic
# Out:
#   Cell In[11], line 18
#     from model_classifyV1-Copy1 import postprocess_excel_by_topic
#                          ^
# SyntaxError: invalid syntax

# %%
## 研发字典
speaker_map = {
    "16186514":   "研发peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt      = "1031《欢迎来到地球》测试1群.txt"

# 设定时间范围
start_time = "2025-10-22 00:00:00"
end_time   = "2025-10-23 00:00:00"

# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=start_time,
    end_time=end_time,
    return_str=False,   # 返回 list[str]
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 3892 lines
# {"发言日期": "2025-10-22", "发言时间": "00:00:37", "玩家ID": "阿雪(1138152183)", "玩家消息": "[图片]"}

# %% [markdown]
# ## 大模型分类

# %% [markdown]
# ## 定义

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：对保留内容进行 5 类意图分类（输出带“意图分类”的 JSON 行）
- 结果按 sheet（体感反馈/疑惑不解和问题询问/玩家建议和灵感/情绪输出/问题反馈）写入 Excel
"""
from model_classifyV1_Copy1 import (
    load_system_prompt,
    build_user_prompt_filter, build_user_prompt_classify,build_user_prompt_classify2,
    call_ark_chat_completions,
    jsonl_to_dataframe_with_intent,
    create_intent_excel_styled, append_json_to_excel_by_cat_and_tag,load_whitelist,
    extract_clusters_from_output, update_and_save_whitelist, build_user_prompt_cluster_correct
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md")      # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("提示词2.md")      # 模型#2 system 提示词（做分类）
PROMPT_MD_PATH03 = Path ("提示词5.md")     # 模型#3 system 提示词（做话提簇）
PROMPT_MD_PATH04 = Path ("话提簇校正提示词.md")     # 模型#3 system 提示词（做话提簇修正）

EXCEL_FILE       = Path("稳定话提簇1022.xlsx")   # 输出 Excel
BATCH_SIZE       = 100
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做分类
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03) # 做话提簇
system_prompt04 = load_system_prompt(PROMPT_MD_PATH04) # 做话提簇

create_intent_excel_styled(EXCEL_FILE)


# 植入白名单 #
# --- 白名单初始化 ---
WHITE_LIST_PATH = Path("话题簇白名单.jsonl")
if not WHITE_LIST_PATH.exists():
    WHITE_LIST_PATH.write_text("", encoding="utf-8")  # 自动创建空文件
whitelist = load_whitelist(WHITE_LIST_PATH)  # 首批为空或加载已有



total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        # --- 模型 #2：分类 ---
        user_prompt2 = build_user_prompt_classify(output_filter)
        output_classify = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_classify:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        # --- 模型 #3：二级标签 ---
        user_prompt3 = build_user_prompt_classify2(output_classify)
        output_classify2 = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt03,
            user_prompt=user_prompt3,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        # --- 模型 #4：话提簇校正 ---
        user_prompt4 = build_user_prompt_cluster_correct(output_classify2, whitelist)
        output_classify3 = call_ark_chat_completions(
        api_url=API_URL,
        api_key=API_KEY,
        model=V3_1_MODEL_ID,
        system_prompt=system_prompt04,  # 模型#4 提示词
        user_prompt=user_prompt4,
        temperature=TEMPERATURE,
        max_tokens=MAX_TOKENS,
        timeout=TIMEOUT_SEC,
        retries=RETRIES,
        )
        try:
            new_clusters = extract_clusters_from_output(output_classify3)
            if new_clusters:
                whitelist = update_and_save_whitelist(WHITE_LIST_PATH, whitelist, new_clusters)
            else:
                tqdm.write(f"[批次 {b+1}] ⚪ 本批次无新增话题簇。")
        except Exception as e:
            tqdm.write(f"[批次 {b+1}] ⚠️ 白名单更新出错：{e}")

        # 转 DataFrame
        df_batch = jsonl_to_dataframe_with_intent(output_classify3)
        if df_batch is None or df_batch.empty:
            tqdm.write(f"[批次 {b+1}] ⚠️ 无可写入数据（空 DataFrame）。")
            continue

        # ✅ 关键：转为 list[dict] 再写入
        records = df_batch.to_dict(orient="records")
        append_json_to_excel_by_cat_and_tag(records, EXCEL_FILE)

        batch_written = len(records)
        written_total += batch_written
        tqdm.write(f"[批次 {b+1}] ✅ 写入 {batch_written} 条。")
     
        
  
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        
        continue

    time.sleep(SLEEP_BETWEEN)
postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=60, nat_policy="skip")

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# ✅ 创建并套样式：稳定话提簇1022.xlsx
# 准备处理 3892 条，共 39 批（每批 100 条）。
# 🔥 批处理进度:   0%|                                                                                 | 0/39 [05:17<?, ?批/s]
# ✅ 新增 12 条话题簇至白名单
# [批次 1] ✅ 写入 40 条。
# 🔥 批处理进度:   3%|█▊                                                                    | 1/39 [07:16<3:21:52, 318.76s/批]
# ✅ 新增 5 条话题簇至白名单
# [批次 2] ✅ 写入 13 条。
# 🔥 批处理进度:   5%|███▌                                                                  | 2/39 [10:57<2:04:06, 201.27s/批]
# ✅ 新增 10 条话题簇至白名单
# [批次 3] ✅ 写入 25 条。
# 🔥 批处理进度:   8%|█████▍                                                                | 3/39 [19:19<2:06:07, 210.20s/批]
# ✅ 新增 21 条话题簇至白名单
# [批次 4] ✅ 写入 67 条。
# 🔥 批处理进度:  10%|███████▏                                                              | 4/39 [26:01<3:09:48, 325.39s/批]
# ✅ 新增 12 条话题簇至白名单
# [批次 5] ✅ 写入 63 条。
# 🔥 批处理进度:  13%|████████▉                                                             | 5/39 [26:02<3:19:56, 352.83s/批]
# ✅ 新增 12 条话题簇至白名单
# 🔥 批处理进度:  13%|████████▉                                                             | 5/39 [30:21<3:19:56, 352.83s/批]
# [批次 6] ✅ 写入 38 条。
# 🔥 批处理进度:  15%|██████████▊                                                           | 6/39 [34:03<2:56:43, 321.31s/批]
# ✅ 新增 13 条话题簇至白名单
# [批次 7] ✅ 写入 24 条。
# 🔥 批处理进度:  18%|████████████▌                                                         | 7/39 [40:10<2:34:10, 289.08s/批]
# ✅ 新增 17 条话题簇至白名单
# [批次 8] ✅ 写入 60 条。
# 🔥 批处理进度:  21%|██████████████▎                                                       | 8/39 [40:11<2:42:06, 313.74s/批]
# ✅ 新增 4 条话题簇至白名单
# 🔥 批处理进度:  21%|██████████████▎                                                       | 8/39 [49:25<2:42:06, 313.74s/批]
# [批次 9] ✅ 写入 75 条。
# 🔥 批处理进度:  23%|████████████████▏                                                     | 9/39 [52:13<3:14:37, 389.24s/批]
# ✅ 新增 11 条话题簇至白名单
# [批次 10] ✅ 写入 21 条。
# 🔥 批处理进度:  26%|█████████████████▋                                                   | 10/39 [52:14<2:35:05, 320.88s/批]
# ✅ 新增 10 条话题簇至白名单
# 🔥 批处理进度:  26%|█████████████████▏                                                 | 10/39 [1:01:08<2:35:05, 320.88s/批]
# [批次 11] ✅ 写入 59 条。
# 🔥 批处理进度:  28%|██████████████████▉                                                | 11/39 [1:01:09<3:00:22, 386.52s/批]
# ✅ 新增 12 条话题簇至白名单
# 🔥 批处理进度:  28%|██████████████████▉                                                | 11/39 [1:11:55<3:00:22, 386.52s/批]
# [批次 12] ✅ 写入 78 条。
# 🔥 批处理进度:  31%|████████████████████▌                                              | 12/39 [1:11:56<3:29:34, 465.74s/批]
# ✅ 新增 6 条话题簇至白名单
# 🔥 批处理进度:  31%|████████████████████▌                                              | 12/39 [1:20:42<3:29:34, 465.74s/批]
# [批次 13] ✅ 写入 72 条。
# 🔥 批处理进度:  33%|██████████████████████▎                                            | 13/39 [1:20:43<3:29:47, 484.12s/批]
# ✅ 新增 5 条话题簇至白名单
# 🔥 批处理进度:  33%|██████████████████████▎                                            | 13/39 [1:27:35<3:29:47, 484.12s/批]
# [批次 14] ✅ 写入 65 条。
# 🔥 批处理进度:  36%|████████████████████████                                           | 14/39 [1:27:36<3:12:46, 462.65s/批]
# ✅ 新增 13 条话题簇至白名单
# 🔥 批处理进度:  36%|████████████████████████                                           | 14/39 [1:35:28<3:12:46, 462.65s/批]
# [批次 15] ✅ 写入 63 条。
# 🔥 批处理进度:  38%|█████████████████████████▊                                         | 15/39 [1:35:29<3:06:16, 465.71s/批]
# ✅ 新增 6 条话题簇至白名单
# 🔥 批处理进度:  38%|█████████████████████████▊                                         | 15/39 [1:38:57<3:06:16, 465.71s/批]
# [批次 16] ✅ 写入 30 条。
# 🔥 批处理进度:  41%|███████████████████████████▍                                       | 16/39 [1:38:58<2:28:59, 388.68s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  41%|███████████████████████████▍                                       | 16/39 [1:46:31<2:28:59, 388.68s/批]
# [批次 17] ✅ 写入 22 条。
# 🔥 批处理进度:  44%|█████████████████████████████▏                                     | 17/39 [1:46:32<2:29:40, 408.19s/批]
# ✅ 新增 13 条话题簇至白名单
# 🔥 批处理进度:  44%|█████████████████████████████▏                                     | 17/39 [1:51:35<2:29:40, 408.19s/批]
# [批次 18] ✅ 写入 36 条。
# 🔥 批处理进度:  46%|██████████████████████████████▉                                    | 18/39 [1:51:36<2:11:54, 376.88s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  46%|██████████████████████████████▉                                    | 18/39 [1:56:00<2:11:54, 376.88s/批]
# [批次 19] ✅ 写入 29 条。
# 🔥 批处理进度:  49%|████████████████████████████████▋                                  | 19/39 [1:56:01<1:54:25, 343.29s/批]
# ✅ 新增 16 条话题簇至白名单
# 🔥 批处理进度:  49%|████████████████████████████████▋                                  | 19/39 [2:03:47<1:54:25, 343.29s/批]
# [批次 20] ✅ 写入 59 条。
# 🔥 批处理进度:  51%|██████████████████████████████████▎                                | 20/39 [2:03:48<2:00:26, 380.32s/批]
# ✅ 新增 14 条话题簇至白名单
# 🔥 批处理进度:  51%|██████████████████████████████████▎                                | 20/39 [2:10:20<2:00:26, 380.32s/批]
# [批次 21] ✅ 写入 52 条。
# 🔥 批处理进度:  54%|████████████████████████████████████                               | 21/39 [2:10:21<1:55:17, 384.30s/批]
# ✅ 新增 11 条话题簇至白名单
# 🔥 批处理进度:  54%|████████████████████████████████████                               | 21/39 [2:19:18<1:55:17, 384.30s/批]
# [批次 22] ✅ 写入 68 条。
# 🔥 批处理进度:  56%|█████████████████████████████████████▊                             | 22/39 [2:19:19<2:01:57, 430.44s/批]
# ✅ 新增 5 条话题簇至白名单
# 🔥 批处理进度:  56%|█████████████████████████████████████▊                             | 22/39 [2:26:34<2:01:57, 430.44s/批]
# [批次 23] ✅ 写入 30 条。
# 🔥 批处理进度:  59%|███████████████████████████████████████▌                           | 23/39 [2:26:35<1:55:11, 431.96s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  59%|███████████████████████████████████████▌                           | 23/39 [2:34:56<1:55:11, 431.96s/批]
# [批次 24] ✅ 写入 75 条。
# 🔥 批处理进度:  62%|█████████████████████████████████████████▏                         | 24/39 [2:34:57<1:53:14, 452.97s/批]
# ✅ 新增 13 条话题簇至白名单
# 🔥 批处理进度:  62%|█████████████████████████████████████████▏                         | 24/39 [2:41:46<1:53:14, 452.97s/批]
# [批次 25] ✅ 写入 65 条。
# 🔥 批处理进度:  64%|██████████████████████████████████████████▉                        | 25/39 [2:41:47<1:42:40, 440.06s/批]
# ✅ 新增 6 条话题簇至白名单
# 🔥 批处理进度:  64%|██████████████████████████████████████████▉                        | 25/39 [2:49:08<1:42:40, 440.06s/批]
# [批次 26] ✅ 写入 63 条。
# 🔥 批处理进度:  67%|████████████████████████████████████████████▋                      | 26/39 [2:49:09<1:35:30, 440.83s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  67%|████████████████████████████████████████████▋                      | 26/39 [2:57:27<1:35:30, 440.83s/批]
# [批次 27] ✅ 写入 12 条。
# 🔥 批处理进度:  69%|██████████████████████████████████████████████▍                    | 27/39 [2:57:28<1:31:39, 458.31s/批]
# ✅ 新增 14 条话题簇至白名单
# 🔥 批处理进度:  69%|██████████████████████████████████████████████▍                    | 27/39 [3:08:24<1:31:39, 458.31s/批]
# [批次 28] ✅ 写入 83 条。
# 🔥 批处理进度:  72%|████████████████████████████████████████████████                   | 28/39 [3:08:25<1:34:55, 517.74s/批]
# ✅ 新增 13 条话题簇至白名单
# 🔥 批处理进度:  72%|████████████████████████████████████████████████                   | 28/39 [3:19:55<1:34:55, 517.74s/批]
# [批次 29] ✅ 写入 88 条。
# 🔥 批处理进度:  74%|█████████████████████████████████████████████████▊                 | 29/39 [3:19:56<1:34:58, 569.82s/批]
# ✅ 新增 8 条话题簇至白名单
# 🔥 批处理进度:  74%|█████████████████████████████████████████████████▊                 | 29/39 [3:27:31<1:34:58, 569.82s/批]
# [批次 30] ✅ 写入 81 条。
# 🔥 批处理进度:  77%|███████████████████████████████████████████████████▌               | 30/39 [3:27:32<1:20:20, 535.61s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  77%|███████████████████████████████████████████████████▌               | 30/39 [3:35:31<1:20:20, 535.61s/批]
# [批次 31] ✅ 写入 76 条。
# 🔥 批处理进度:  79%|█████████████████████████████████████████████████████▎             | 31/39 [3:35:32<1:09:12, 519.10s/批]
# ✅ 新增 5 条话题簇至白名单
# 🔥 批处理进度:  79%|█████████████████████████████████████████████████████▎             | 31/39 [3:41:52<1:09:12, 519.10s/批]
# [批次 32] ✅ 写入 34 条。
# 🔥 批处理进度:  82%|████████████████████████████████████████████████████████▌            | 32/39 [3:41:53<55:42, 477.46s/批]
# ✅ 新增 24 条话题簇至白名单
# 🔥 批处理进度:  82%|████████████████████████████████████████████████████████▌            | 32/39 [3:51:23<55:42, 477.46s/批]
# [批次 33] ✅ 写入 79 条。
# 🔥 批处理进度:  85%|██████████████████████████████████████████████████████████▍          | 33/39 [3:51:24<50:33, 505.50s/批]
# ✅ 新增 7 条话题簇至白名单
# 🔥 批处理进度:  85%|██████████████████████████████████████████████████████████▍          | 33/39 [3:58:45<50:33, 505.50s/批]
# [批次 34] ✅ 写入 59 条。
# 🔥 批处理进度:  87%|████████████████████████████████████████████████████████████▏        | 34/39 [3:58:46<40:33, 486.66s/批]
# ✅ 新增 3 条话题簇至白名单
# 🔥 批处理进度:  87%|████████████████████████████████████████████████████████████▏        | 34/39 [4:05:41<40:33, 486.66s/批]
# [批次 35] ✅ 写入 60 条。
# 🔥 批处理进度:  90%|█████████████████████████████████████████████████████████████▉       | 35/39 [4:05:42<31:01, 465.33s/批]
# ✅ 新增 15 条话题簇至白名单
# 🔥 批处理进度:  90%|█████████████████████████████████████████████████████████████▉       | 35/39 [4:16:35<31:01, 465.33s/批]
# [批次 36] ✅ 写入 77 条。
# 🔥 批处理进度:  92%|███████████████████████████████████████████████████████████████▋     | 36/39 [4:16:36<26:06, 522.04s/批]
# ✅ 新增 12 条话题簇至白名单
# 🔥 批处理进度:  92%|███████████████████████████████████████████████████████████████▋     | 36/39 [4:25:27<26:06, 522.04s/批]
# [批次 37] ✅ 写入 36 条。
# 🔥 批处理进度:  95%|█████████████████████████████████████████████████████████████████▍   | 37/39 [4:25:28<17:29, 524.88s/批]
# ✅ 新增 1 条话题簇至白名单
# 🔥 批处理进度:  95%|█████████████████████████████████████████████████████████████████▍   | 37/39 [4:31:19<17:29, 524.88s/批]
# [批次 38] ✅ 写入 52 条。
# 🔥 批处理进度:  97%|███████████████████████████████████████████████████████████████████▏ | 38/39 [4:31:20<07:53, 473.19s/批]
# ✅ 新增 9 条话题簇至白名单
# 🔥 批处理进度:  97%|███████████████████████████████████████████████████████████████████▏ | 38/39 [4:38:58<07:53, 473.19s/批]
# [批次 39] ✅ 写入 74 条。
# 🔥 批处理进度: 100%|█████████████████████████████████████████████████████████████████████| 39/39 [4:38:59<00:00, 429.23s/批]
# ✅ 已完成后处理：稳定话提簇1022.xlsx（gap=60min, NaT策略=skip）
#
# ✅ 全部批次处理完成！
# 输入总数：3892
# 写入总数：2103
