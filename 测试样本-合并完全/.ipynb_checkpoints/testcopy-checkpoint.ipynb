# %% [markdown]
# ## 数据处理

# %%
###引入函数###

import pandas as pd
import io
import re
from datetime import datetime, timedelta
from typing import List, Union, Optional
from datetime import datetime

import os, re, json, time
import typing as T
import requests
from pathlib import Path
from openpyxl import Workbook, load_workbook

from openpyxl.utils import get_column_letter
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from data_processing import load_and_process,build_jsonl_for_range, save_jsonl
from model_classify import postprocess_excel_by_topic

# %%
## 研发字典
speaker_map = {
    "16186514":   "研发peter本尊",
    "1655611808": "运营绾绾",
    "2073820674": "沙利文老师",
}
## 客服字典
MAPPING_FILE = "mapping地球1.xlsx"

##QQ的txt文件
pathtxt      = "sample2_100.txt"

# 1) 拿到 JSONL（列表）
jsonl_lines01 = build_jsonl_for_range(
    pathtxt=pathtxt,
    mapping_file=MAPPING_FILE,
    speaker_map=speaker_map,
    start_time=None,  # 不筛
    end_time=None,    # 不筛
    return_str=False,
)

print(len(jsonl_lines01), "lines")
print(jsonl_lines01[0])
# Out:
# 115 lines
# {"发言日期": "2025-08-06", "发言时间": "16:35:34", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "彩虹源质是其他几个源质的平均值"}

# %% [markdown]
# ## 大模型分析

# %%
"""
批处理 10000 条聊天数据（每批 100 条）：
- 模型#1：过滤非游戏相关（只保留相关 JSON 行，原样输出）
- 模型#2：对保留内容进行 5 类意图分类（输出带“意图分类”的 JSON 行）
- 结果按 sheet（体感反馈/疑惑不解和问题询问/玩家建议和灵感/情绪输出/问题反馈）写入 Excel
"""
from model_classify import (
    load_system_prompt,
    build_user_prompt_filter, build_user_prompt_classify,build_user_prompt_classify2,
    call_ark_chat_completions,
    jsonl_to_dataframe_with_intent,
    create_intent_excel_styled,append_json_to_excel_by_cat_and_tag,
)

# %% [markdown]
# ## 设置参数

# %%
# ============= 你的模型与文件配置（改这里） =============
API_URL   = "https://ark.cn-beijing.volces.com/api/v3/chat/completions" 
API_KEY = "de91deb0-aae6-46cb-bac0-17ac3b6107f5" #API
V3_MODEL_ID= "ep-20251020160142-5d7hp"#接入点
V3_1_MODEL_ID = "ep-20251020160025-9p5tj"#接入点
R1_MODEL_ID = "ep-20251020160103-5n6g2"#接入点

PROMPT_MD_PATH01 = Path("提示词1.md")      # 模型#1 system 提示词（筛相关）
PROMPT_MD_PATH02 = Path("提示词2.md")      # 模型#2 system 提示词（做分类）
PROMPT_MD_PATH03 = Path("提示词3.md")      # 模型#3 system 提示词（做二级标签）
PROMPT_MD_PATH05 = Path ("提示词5_直接话提簇分类.md")
EXCEL_FILE       = Path("testmerge.xlsx")   # 输出 Excel
BATCH_SIZE       = 100
SLEEP_BETWEEN    = 1   # 每批之间的间隔，防止QPS触发限流；按需调整
RETRIES          = 2
TEMPERATURE      = 0.20
MAX_TOKENS       = 16384
TIMEOUT_SEC      = 600
# =====================================================

# %% [markdown]
# ## 开始运行

# %%
from tqdm import tqdm
import time

# ... 前置：系统提示、create_intent_excel_styled(EXCEL_FILE)、jsonl_lines01 等

system_prompt01 = load_system_prompt(PROMPT_MD_PATH01)  # 筛相关
system_prompt02 = load_system_prompt(PROMPT_MD_PATH02)  # 做分类
system_prompt03 = load_system_prompt(PROMPT_MD_PATH03)  # 做分类
system_prompt05 = load_system_prompt(PROMPT_MD_PATH05)
create_intent_excel_styled(EXCEL_FILE)

total = len(jsonl_lines01)
if total == 0:
    print("没有可处理的数据。")
else:
    total_batches = (total + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"准备处理 {total} 条，共 {total_batches} 批（每批 {BATCH_SIZE} 条）。")

written_total = 0

for b in tqdm(range(total_batches), desc="🔥 批处理进度", unit="批"):
    start = b * BATCH_SIZE
    end = min(start + BATCH_SIZE, total)
    batch_lines = jsonl_lines01[start:end]

    try:
        # --- 模型 #1：筛相关 ---
        user_prompt1 = build_user_prompt_filter(batch_lines)
        output_filter = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_MODEL_ID,
            system_prompt=system_prompt01,
            user_prompt=user_prompt1,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_filter:
            tqdm.write(f"[批次 {b+1}] 模型#1 无有效输出，跳过。")
            continue
        # --- 模型 #2：分类 ---
        user_prompt2 = build_user_prompt_classify(output_filter)
        output_classify = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt02,
            user_prompt=user_prompt2,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )
        if not output_classify:
            tqdm.write(f"[批次 {b+1}] 模型#2 无有效输出，跳过。")
            continue
        # --- 模型 #3：二级标签 ---
        user_prompt3 = build_user_prompt_classify2(output_classify)
        output_classify2 = call_ark_chat_completions(
            api_url=API_URL,
            api_key=API_KEY,
            model=V3_1_MODEL_ID,
            system_prompt=system_prompt05,
            user_prompt=user_prompt3,
            temperature=TEMPERATURE,
            max_tokens=MAX_TOKENS,
            timeout=TIMEOUT_SEC,
            retries=RETRIES,
        )

        # 转 DataFrame
        df_batch = jsonl_to_dataframe_with_intent(output_classify2)
        if df_batch is None or df_batch.empty:
            tqdm.write(f"[批次 {b+1}] ⚠️ 无可写入数据（空 DataFrame）。")
            continue

        # ✅ 关键：转为 list[dict] 再写入
        records = df_batch.to_dict(orient="records")
        append_json_to_excel_by_cat_and_tag(records, EXCEL_FILE)

        batch_written = len(records)
        written_total += batch_written
        tqdm.write(f"[批次 {b+1}] ✅ 写入 {batch_written} 条。")
        print(output_filter)
  
    except Exception as e:
        tqdm.write(f"[批次 {b+1}] ❌ 出错：{e}")
        continue

    time.sleep(SLEEP_BETWEEN)
postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=30, nat_policy="skip")

print("\n✅ 全部批次处理完成！")
print(f"输入总数：{total}")
print(f"写入总数：{written_total}")
# Out:
# ✅ 创建并套样式：testmerge.xlsx
# 准备处理 115 条，共 3 批（每批 50 条）。
# 🔥 批处理进度:   0%|                                                                                  | 0/3 [04:13<?, ?批/s]
# [批次 1] ✅ 写入 48 条。
# {"发言时间": "2025-08-06 16:35:34", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "彩虹源质是其他几个源质的平均值", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:35:37", "玩家ID": "ゞ兲迯萊客ゞ(37307559)", "玩家消息": "都不流畅", "分类标签": 1, "话题簇": "性能问题"}
# {"发言时间": "2025-08-06 16:35:43", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "其他源质上去了，彩虹自动就上去了", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:35:58", "玩家ID": "东风(2790800575)", "玩家消息": "不是，彩虹是最低的那个", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:36:04", "玩家ID": "东风(2790800575)", "玩家消息": "不是平均", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:36:11", "玩家ID": "小罗别睡了(814562830)", "玩家消息": "@枫桥夜柏 不是平均，是最低的那个", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:36:12", "玩家ID": "什么(3549173353)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "图片类发言🖼️"}
# {"发言时间": "2025-08-06 16:36:17", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "靠", "分类标签": 4, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:36:24", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "那也还行……吧", "分类标签": 1, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:36:31", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "进度分享🖼️"}
# {"发言时间": "2025-08-06 16:36:39", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "第一个精神崩溃", "分类标签": 1, "话题簇": "进度分享"}
# {"发言时间": "2025-08-06 16:36:40", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "我上一测就是养的希伯特鲎", "分类标签": 1, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:36:42", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "感觉还行", "分类标签": 1, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:36:43", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "才打到84", "分类标签": 1, "话题簇": "进度分享"}
# {"发言时间": "2025-08-06 16:37:24", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "目前摩伽罗基础都是第三回合30伤，不知道第二技能会有啥区别", "分类标签": 2, "话题簇": "殖装技能"}
# {"发言时间": "2025-08-06 16:38:35", "玩家ID": "咒腕哈桑(2762290054)", "玩家消息": "@炎殇魔尊燯弑天 @炎殇魔尊燯弑天 你开局是翼龙？", "分类标签": 2, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:38:43", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "对", "分类标签": 2, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:38:52", "玩家ID": "咒腕哈桑(2762290054)", "玩家消息": "翼龙强吧", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:39:16", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "一周目可以", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:39:21", "玩家ID": "炎殇魔尊燯弑天(1140885081)", "玩家消息": "二周目不推荐", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:39:26", "玩家ID": "木星27(2163386160)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "殖装分享🖼️"}
# {"发言时间": "2025-08-06 16:39:30", "玩家ID": "木星27(2163386160)", "玩家消息": "我这个是不是最废啊", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:39:41", "玩家ID": "伊莉雅～(2463580537)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "关卡求助🖼️"}
# {"发言时间": "2025-08-06 16:39:44", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "不是", "分类标签": 2, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:39:46", "玩家ID": "伊莉雅～(2463580537)", "玩家消息": "完全打不过", "分类标签": 1, "话题簇": "关卡求助"}
# {"发言时间": "2025-08-06 16:40:00", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "阿米巴和怪诞虫二周目还可以的", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:40:02", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "吧", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:40:18", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "问题不大", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:40:18", "玩家ID": "咒腕哈桑(2762290054)", "玩家消息": "怪诞虫感觉没那么好用", "分类标签": 1, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:40:27", "玩家ID": "寒寒(2963056954)", "玩家消息": "我是沙罗", "分类标签": 1, "话题簇": "殖装分享"}
# {"发言时间": "2025-08-06 16:40:31", "玩家ID": "寒寒(2963056954)", "玩家消息": "怎么样", "分类标签": 2, "话题簇": "殖装强度"}
# {"发言时间": "2025-08-06 16:40:34", "玩家ID": "寒寒(2963056954)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "殖装分享🖼️"}
# {"发言时间": "2025-08-06 16:40:34", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "现在殖装更多了", "分类标签": 1, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:40:38", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "有更多选择了", "分类标签": 1, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:40:41", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "慢慢看", "分类标签": 1, "话题簇": "殖装选择"}
# {"发言时间": "2025-08-06 16:40:48", "玩家ID": "Sakamoto(2429896870)", "玩家消息": "桫椤这一块", "分类标签": 1, "话题簇": "殖装讨论"}
# {"发言时间": "2025-08-06 16:40:48", "玩家ID": "。(1020040826)", "玩家消息": "刚刚0精神", "分类标签": 1, "话题簇": "进度分享"}
# {"发言时间": "2025-08-06 16:40:53", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "主要是看你源质到100之后", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:40:55", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "@伊莉雅～ @伊莉雅～ 开始肯定是打不过自己的克隆的，你先发后面的，发育起来了再回头打", "分类标签": 2, "话题簇": "关卡策略"}
# {"发言时间": "2025-08-06 16:40:58", "玩家ID": "。(1020040826)", "玩家消息": "差点把29龙过了", "分类标签": 1, "话题簇": "进度分享"}
# {"发言时间": "2025-08-06 16:41:05", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "100源质第二技能", "分类标签": 2, "话题簇": "源质机制"}
# {"发言时间": "2025-08-06 16:41:13", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "这个可能各个殖装不一样", "分类标签": 2, "话题簇": "殖装技能"}
# {"发言时间": "2025-08-06 16:41:18", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "选择更好的就是了", "分类标签": 2, "话题簇": "殖装技能"}
# {"发言时间": "2025-08-06 16:41:28", "玩家ID": "伊莉雅～(2463580537)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "关卡求助🖼️"}
# {"发言时间": "2025-08-06 16:41:36", "玩家ID": "虞罗(2816328364)", "玩家消息": "怪诞虫玩投掷，一回合杀", "分类标签": 2, "话题簇": "殖装玩法"}
# {"发言时间": "2025-08-06 16:41:37", "玩家ID": "伊莉雅～(2463580537)", "玩家消息": "@你在阻抗，要听我的 @你在阻抗，要听我的 我感觉哪个都打不过呢", "分类标签": 1, "话题簇": "关卡求助"}
# {"发言时间": "2025-08-06 16:41:52", "玩家ID": "Sakamoto(2429896870)", "玩家消息": "@伊莉雅～ 你给克隆填充的东西会被克隆反过来利用，给它填充些很废物的", "分类标签": 2, "话题簇": "关卡策略"}
# {"发言时间": "2025-08-06 16:41:58", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "@虞罗 @虞罗 阿米巴嘞，阿米巴我上测没玩过", "分类标签": 2, "话题簇": "殖装玩法"}
# 🔥 批处理进度:  33%|████████████████████████▎                                                | 1/3 [07:36<08:29, 254.64s/批]
# [批次 2] ✅ 写入 34 条。
# {"发言时间": "2025-08-06 16:42:08", "玩家ID": "Release My Soul(383496798)", "玩家消息": "断开链接，上不去了呢", "分类标签": 5, "话题簇": "连接异常"}
# {"发言时间": "2025-08-06 16:42:10", "玩家ID": "阿赞啊(1794253925)", "玩家消息": "[图片] 🖼️🖼️", "分类标签": 1, "话题簇": "开局体验🖼️"}
# {"发言时间": "2025-08-06 16:42:17", "玩家ID": "阿赞啊(1794253925)", "玩家消息": "受不了了这垃圾开局", "分类标签": 4, "话题簇": "开局体验"}
# {"发言时间": "2025-08-06 16:42:18", "玩家ID": "舜丶息(2687300218)", "玩家消息": "我是第二次初始了", "分类标签": 1, "话题簇": "开局体验"}
# {"发言时间": "2025-08-06 16:42:18", "玩家ID": "虞罗(2816328364)", "玩家消息": "阿米巴中规中矩", "分类标签": 1, "话题簇": "角色强度"}
# {"发言时间": "2025-08-06 16:42:30", "玩家ID": "阿赞啊(1794253925)", "玩家消息": "13级的都打不过", "分类标签": 2, "话题簇": "关卡难度"}
# {"发言时间": "2025-08-06 16:42:39", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "那我大概知道了", "分类标签": 1, "话题簇": "角色强度"}
# {"发言时间": "2025-08-06 16:42:41", "玩家ID": "舜丶息(2687300218)", "玩家消息": "这测好像比较容易病变", "分类标签": 1, "话题簇": "病变机制"}
# {"发言时间": "2025-08-06 16:43:02", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "这测阿米巴变中度了", "分类标签": 1, "话题簇": "角色强度"}
# {"发言时间": "2025-08-06 16:43:12", "玩家ID": "枫桥夜柏(854411209)", "玩家消息": "上测好像是轻度", "分类标签": 1, "话题簇": "角色强度"}
# {"发言时间": "2025-08-06 16:43:59", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "@伊莉雅～ @伊莉雅～ 东西上了么，等级升了么", "分类标签": 2, "话题簇": "装备升级"}
# {"发言时间": "2025-08-06 16:44:21", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "有些需要链接的记得链接", "分类标签": 2, "话题簇": "装备升级"}
# {"发言时间": "2025-08-06 16:45:15", "玩家ID": "舜丶息(2687300218)", "玩家消息": "我记得上一测我根本没玩到病变就换人了", "分类标签": 1, "话题簇": "病变机制"}
# {"发言时间": "2025-08-06 16:45:39", "玩家ID": "舜丶息(2687300218)", "玩家消息": "这测这么快病变了", "分类标签": 1, "话题簇": "病变机制"}
# {"发言时间": "2025-08-06 16:46:01", "玩家ID": "虞罗(2816328364)", "玩家消息": "精神确实更容易掉了", "分类标签": 1, "话题簇": "精神机制"}
# {"发言时间": "2025-08-06 16:46:07", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "@伊莉雅～ 一次性物品也利用起来", "分类标签": 2, "话题簇": "道具使用"}
# {"发言时间": "2025-08-06 16:46:12", "玩家ID": "舜丶息(2687300218)", "玩家消息": "w没提示我打不过", "分类标签": 2, "话题簇": "关卡难度"}
# {"发言时间": "2025-08-06 16:46:18", "玩家ID": "舜丶息(2687300218)", "玩家消息": "我还以为打的过", "分类标签": 1, "话题簇": "关卡难度"}
# {"发言时间": "2025-08-06 16:46:20", "玩家ID": "虞罗(2816328364)", "玩家消息": "我中度，已经快见底了", "分类标签": 1, "话题簇": "精神机制"}
# {"发言时间": "2025-08-06 16:47:14", "玩家ID": "舜丶息(2687300218)", "玩家消息": "以前低精神", "分类标签": 1, "话题簇": "精神机制"}
# {"发言时间": "2025-08-06 16:47:16", "玩家ID": "虞罗(2816328364)", "玩家消息": "跟他爆了", "分类标签": 4, "话题簇": "战斗策略"}
# {"发言时间": "2025-08-06 16:47:20", "玩家ID": "舜丶息(2687300218)", "玩家消息": "打不过也会说的", "分类标签": 1, "话题簇": "关卡难度"}
# {"发言时间": "2025-08-06 16:47:23", "玩家ID": "ツ笙歌绝丶何以笙箫默(2723600969)", "玩家消息": "根本打不过怎么办", "分类标签": 2, "话题簇": "关卡难度"}
# {"发言时间": "2025-08-06 16:47:24", "玩家ID": "舜丶息(2687300218)", "玩家消息": "只是看不到血", "分类标签": 1, "话题簇": "界面显示"}
# {"发言时间": "2025-08-06 16:47:40", "玩家ID": "舜丶息(2687300218)", "玩家消息": "我都没进发狂状态呢", "分类标签": 1, "话题簇": "战斗状态"}
# {"发言时间": "2025-08-06 16:47:45", "玩家ID": "舜丶息(2687300218)", "玩家消息": "浪费两次爆发", "分类标签": 1, "话题簇": "战斗策略"}
# {"发言时间": "2025-08-06 16:47:47", "玩家ID": "舜丶息(2687300218)", "玩家消息": "我服了", "分类标签": 4, "话题簇": "战斗受挫"}
# {"发言时间": "2025-08-06 16:47:55", "玩家ID": "舜丶息(2687300218)", "玩家消息": "本来能换掉两个小boss的", "分类标签": 1, "话题簇": "战斗策略"}
# {"发言时间": "2025-08-06 16:48:54", "玩家ID": "ゞ兲迯萊客ゞ(37307559)", "玩家消息": "这个怎么操作", "分类标签": 2, "话题簇": "操作指引"}
# {"发言时间": "2025-08-06 16:49:14", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "@伊莉雅～ @伊莉雅～ 那个秒表打怪没用，可以带一个一次性投掷的加点伤害", "分类标签": 2, "话题簇": "道具使用"}
# {"发言时间": "2025-08-06 16:49:16", "玩家ID": "舜丶息(2687300218)", "玩家消息": "换人换人", "分类标签": 1, "话题簇": "角色切换"}
# {"发言时间": "2025-08-06 16:49:22", "玩家ID": "舜丶息(2687300218)", "玩家消息": "刚好试试新角色", "分类标签": 1, "话题簇": "角色切换"}
# {"发言时间": "2025-08-06 16:49:56", "玩家ID": "你在阻抗，要听我的(365624958)", "玩家消息": "@伊莉雅～ @伊莉雅～ 然后战后回血的也用处不大，带点加防御加伤害的", "分类标签": 2, "话题簇": "道具使用"}
# {"发言时间": "2025-08-06 16:50:01", "玩家ID": "虞罗(2816328364)", "玩家消息": "@ゞ兲迯萊客ゞ @ゞ兲迯萊客ゞ 拖到右上角的精神病格子", "分类标签": 2, "话题簇": "操作指引"}
# 🔥 批处理进度:  67%|████████████████████████████████████████████████▋                        | 2/3 [08:49<03:44, 224.04s/批]
# [批次 3] ✅ 写入 14 条。
# {"发言时间": "2025-08-06 16:50:24", "玩家ID": "虞罗(2816328364)", "玩家消息": "这个是固定的", "分类标签": 1, "话题簇": "机制特性"}
# {"发言时间": "2025-08-06 16:50:34", "玩家ID": "虞罗(2816328364)", "玩家消息": "有可能可以升级", "分类标签": 1, "话题簇": "机制特性"}
# {"发言时间": "2025-08-06 16:51:02", "玩家ID": "ツ笙歌绝丶何以笙箫默(2723600969)", "玩家消息": "我升到四级，但是好像没什么变化", "分类标签": 1, "话题簇": "机制特性"}
# {"发言时间": "2025-08-06 16:51:15", "玩家ID": "吾辈是猫君莫笑(2317313105)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "机制特性🖼️"}
# {"发言时间": "2025-08-06 16:51:31", "玩家ID": "虞罗(2816328364)", "玩家消息": "开荒好用", "分类标签": 1, "话题簇": "机制特性"}
# {"发言时间": "2025-08-06 16:51:36", "玩家ID": "虞罗(2816328364)", "玩家消息": "后面就不行了", "分类标签": 1, "话题簇": "机制特性"}
# {"发言时间": "2025-08-06 16:51:43", "玩家ID": "东风(2790800575)", "玩家消息": "[图片]", "分类标签": 1, "话题簇": "陷阱机制🖼️"}
# {"发言时间": "2025-08-06 16:52:00", "玩家ID": "✨(2806047279)", "玩家消息": "玩不懂", "分类标签": 2, "话题簇": "玩法理解"}
# {"发言时间": "2025-08-06 16:52:02", "玩家ID": "虞罗(2816328364)", "玩家消息": "陷阱改成第一回合了？", "分类标签": 2, "话题簇": "陷阱机制"}
# {"发言时间": "2025-08-06 16:52:04", "玩家ID": "东风(2790800575)", "玩家消息": "这个狠，扛一次伤害就行", "分类标签": 1, "话题簇": "陷阱机制"}
# {"发言时间": "2025-08-06 16:52:11", "玩家ID": "舜丶息(2687300218)", "玩家消息": "是的", "分类标签": 1, "话题簇": "陷阱机制"}
# {"发言时间": "2025-08-06 16:52:17", "玩家ID": "舜丶息(2687300218)", "玩家消息": "现在陷阱一看就猛", "分类标签": 1, "话题簇": "陷阱机制"}
# {"发言时间": "2025-08-06 16:52:20", "玩家ID": "舜丶息(2687300218)", "玩家消息": "尤其是前期", "分类标签": 1, "话题簇": "陷阱机制"}
# {"发言时间": "2025-08-06 16:52:22", "玩家ID": "东风(2790800575)", "玩家消息": "敌人打的时候生效", "分类标签": 1, "话题簇": "陷阱机制"}
# 🔥 批处理进度: 100%|█████████████████████████████████████████████████████████████████████████| 3/3 [08:50<00:00, 176.78s/批]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 95
#      92         continue
#      94     time.sleep(SLEEP_BETWEEN)
# ---> 95 postprocess_excel_by_topic(EXCEL_FILE, gap_minutes=15)
#      96 print("\n✅ 全部批次处理完成！")
#      97 print(f"输入总数：{total}")
#
# File E:\项目\玩家社群分析智能体\测试样本-合并完全\model_classify.py:468, in postprocess_excel_by_topic(excel_path, gap_minutes)
#     466 for sheet_name in wb.sheetnames:
#     467     ws = wb[sheet_name]
# --> 468     _sort_and_merge_topic_column(ws, gap_minutes)
#     470 wb.save(excel_path)
#     471 print(f"✅ 已完成后处理（排序+合并）：{excel_path}")
#
# File E:\项目\玩家社群分析智能体\测试样本-合并完全\model_classify.py:522, in _sort_and_merge_topic_column(ws, gap_minutes)
#     520 # 合并“话题簇”列
#     521 _clear_topic_merges(ws)
# --> 522 _merge_topic_runs(ws, df[["发言时间", "话题簇"]].copy(), gap_minutes)
#
# File E:\项目\玩家社群分析智能体\测试样本-合并完全\model_classify.py:563, in _merge_topic_runs(ws, df_topic, gap_minutes, topic_col_idx, time_col_idx, start_row)
#     561         to_unmerge.append(rng)
#     562 for rng in to_unmerge:
# --> 563     ws.unmerge_cells(range_string=str(rng))
#     565 # 工具：去掉两个媒体表情
#     566 def _strip_two_emojis(s: str) -> str:
#
# File E:\anaconda3\Lib\site-packages\openpyxl\worksheet\worksheet.py:638, in Worksheet.unmerge_cells(self, range_string, start_row, start_column, end_row, end_column)
#     636 next(cells) # skip first cell
#     637 for row, col in cells:
# --> 638     del self._cells[(row, col)]
#
# KeyError: (24, 4)
